# %% [markdown]
# # Ecological models: relevant?
# ## NIOZ Master Thesis Project
#
# This Jupyter Notebook contains a detailed description and workflow to train two machine learning models for my thesis. Every section is denoted with a second level heading to keep track of my experiments. First the data from the EBT Tool is imported - a deterministic population model resembling a tri-trophic system in the Baltic Sea (Van Leeuwen et al., 2008). This data is used to train two machine learning models (TCDF and PCMCI respectively) to infer (ecological) causal relations. Both are convolutional machine learning models, and able to handle non-stationary temporal data.
#
# Author: R. Draaijer

# %% [markdown]
# ## Enabling notebook to be run on any device

# %%
import os

# Create universally (i.e. across various operating systems) recognized paths

notebook_path = os.path.abspath('MSc Thesis 1.ipynb')                  # Jupyter notebook path
TCDF_path = os.path.join(os.path.dirname(notebook_path), 'TCDF')       # TCDF folder path
TCDFdata_path = os.path.join(TCDF_path, 'data')                        # TCDF/data folder path
EBT_path = os.path.join(os.path.dirname(notebook_path), 'EBT Data')    # EBT folder path
DefaultCod_path = os.path.join(EBT_path, 'Modified Default Cod')       # EBT/Modified Default Cod folder path
Cod_path = os.path.join(DefaultCod_path, 'Modified Default.out')       # EBT/Modified Default Cod/Modified Default.out file path

# %% [markdown]
# ## EBT Tool

# %% [markdown]
# ### Import EBT Tool Data with NumPy
# Two different datasets can be distinguished: Default Cod and Cannibalistic Cod. See paper (2008) and EBT Tutorial (2020) by Anieke van Leeuwen et al.
#
# *Note that objects with uppercase namespaces are solely used for raw data files

# %%
# Get path for EBT data (.txt file)
path = Cod_path

# Check first entries of data
with open(path) as Default_Cod:
    print(Default_Cod.readline())
# Out:
# 0.00	0.000000E+00	54.8212970000	0.2682070000	0.9892870000	8.5112130000	9.9553140000	50.0338940000	8.1868890000	0.8092280000	0.8422930000	0.000000E+00	0.000000E+00	0.000000E+00	0.000000E+00	0.000000E+00	56.6028346684	22.6730919259	25.9887468408	0.8307394959	0.1492078213	0.3078741160	9.8384100000	0.000000E+00

# %%
# Convert dataset to ndarray
import numpy as np

with open(path) as Default_Cod:
    default_cod = np.loadtxt(Default_Cod)

# Check (dimensions of) array
print(default_cod) 
print(default_cod.shape)           # Must be identical to ('Maximum integration time' + 1, OUTPUT_VAR_NR + 1) in EBT tool
print(default_cod.dtype)           # Should be float64
# Out:
# [[0.00000000e+00 0.00000000e+00 5.48212970e+01 ... 3.07874116e-01
#   9.83841000e+00 0.00000000e+00]
#  [1.00000000e+00 2.73972600e-03 5.48213227e+01 ... 3.07874682e-01
#   9.83841208e+00 0.00000000e+00]
#  [2.00000000e+00 5.47945210e-03 5.48213485e+01 ... 3.07875243e-01
#   9.83841413e+00 0.00000000e+00]
#  ...
#  [3.64980000e+04 9.99945205e+01 6.25598481e+00 ... 2.24811300e-08
#   6.26818600e-07 0.00000000e+00]
#  [3.64990000e+04 9.99972603e+01 6.25598481e+00 ... 2.24691700e-08
#   6.26477700e-07 0.00000000e+00]
#  [3.65000000e+04 1.00000000e+02 6.25598481e+00 ... 2.24572100e-08
#   6.26137000e-07 0.00000000e+00]]
# (36501, 24)
# float64

# %% [markdown]
# In hindsight the library pandas can be highly useful for loading data, therefore:
#
# ### Import EBT Tool Data with pandas
# Two different datasets can be distinguished: Default Cod and Cannibalistic Cod. See paper (2008) and EBT Tutorial (2020) by Anieke van Leeuwen et al.
#
# *Note that objects with uppercase namespaces are solely used for raw data files*

# %%
import pandas as pd

# Get path for EBT data (.txt file)
path = Cod_path

# Define column names (see EBT .c file in output variables section) for multilevel indexing
variables = ['Time', 'Years', 'RS', 'RJ', 'RA', 'SJ', 'SA', 'SB', 'CJ', 'CA', 'CB', 'Fc', 'ΔCJ with Fc', 'ΔCS with Fc',
             'ΔCA with Fc', 'ΔC with Fc', 'ΔSB', 'ΔSJ', 'ΔSA', 'ΔCB', 'ΔCJ', 'ΔCA', 'ΣC', 'Fs']
units = ['[day]', '[year]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]',
         '[g V-1]', '[-]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]',
         '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1]', '[-]']

with open(path) as Default_Cod:
    default_cod = pd.read_csv(Default_Cod, delimiter = '\t', header=None)

# Set column names and index
#columns = pd.MultiIndex.set_codes([[variables, units]], names = ['Output variable', 'Unit'])
default_cod.columns = variables
#default_cod.columns = columns
default_cod = default_cod.set_index('Time')

# Check (dimensions of) array
print(default_cod.shape)           # Must be identical to ('Maximum integration time' + 1, OUTPUT_VAR_NR + 1) in EBT tool

default_cod.head()
# Out:
# (36501, 23)
#          Years         RS        RJ        RA        SJ        SA         SB  \
# Time
# 0.0   0.000000  54.821297  0.268207  0.989287  8.511213  9.955314  50.033894
# 1.0   0.002740  54.821323  0.268207  0.989287  8.511207  9.955310  50.033881
# 2.0   0.005479  54.821349  0.268207  0.989287  8.511201  9.955306  50.033867
# 3.0   0.008219  54.821374  0.268207  0.989287  8.511194  9.955302  50.033854
# 4.0   0.010959  54.821401  0.268207  0.989287  8.511188  9.955297  50.033840
#
#             CJ        CA        CB  ...  ΔCA with Fc  ΔC with Fc        ΔSB  \
# Time                                ...
# 0.0   8.186889  0.809228  0.842293  ...          0.0         0.0  56.602835
# 1.0   8.186888  0.809230  0.842294  ...          0.0         0.0  56.602823
# 2.0   8.186887  0.809231  0.842295  ...          0.0         0.0  56.602811
# 3.0   8.186887  0.809233  0.842297  ...          0.0         0.0  56.602799
# 4.0   8.186886  0.809235  0.842298  ...          0.0         0.0  56.602787
#
#             ΔSJ        ΔSA       ΔCB       ΔCJ       ΔCA        ΣC   Fs
# Time
# 0.0   22.673092  25.988747  0.830739  0.149208  0.307874  9.838410  0.0
# 1.0   22.673058  25.988736  0.830741  0.149204  0.307875  9.838412  0.0
# 2.0   22.673023  25.988726  0.830742  0.149200  0.307875  9.838414  0.0
# 3.0   22.672989  25.988715  0.830743  0.149195  0.307876  9.838416  0.0
# 4.0   22.672955  25.988704  0.830744  0.149191  0.307876  9.838418  0.0
#
# [5 rows x 23 columns]

# %%
# Visualize default_cod as is visualized by the EBT tool
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Make figure to visualize plots in
fig, axes = plt.subplots(2, 1, sharex=True)
plt.subplots_adjust(hspace=0)

# Select the biomass columns
# Cod biomass
cod_fig = fig.add_subplot(axes[0])
cod_fig.plot(default_cod['Years'], default_cod[['CJ','CA','CB']])

cod_fig.set_xticks(np.arange(0,110,20))
cod_fig.set_yticks(np.arange(0,12,2))


# Sprat biomass
sprat_fig = fig.add_subplot(axes[1])
sprat_fig.plot(default_cod['Years'], default_cod[['SJ','SA','SB']])

cod_fig.set_xticks(np.arange(0,110,20))
cod_fig.set_yticks(np.arange(0,12,2))
sprat_fig.set_xlabel('Time [year]')
# Out:
# Text(0.5, 0, 'Time [year]')

# %% [markdown]
# ## TCDF Demo
#
# This is a short demo for the first machine learning model, to get familiar with the training and testing of data.

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# Load data from EBT tool into DataFrame
path = Cod_path
ebt = pd.read_csv(path, delimiter = '\t', header = None)

# Show first 10 rows of dataset
ebt.head(10)
# Out:
#     0         1          2         3         4         5         6   \
# 0  0.0  0.000000  54.821297  0.268207  0.989287  8.511213  9.955314
# 1  1.0  0.002740  54.821323  0.268207  0.989287  8.511207  9.955310
# 2  2.0  0.005479  54.821349  0.268207  0.989287  8.511201  9.955306
# 3  3.0  0.008219  54.821374  0.268207  0.989287  8.511194  9.955302
# 4  4.0  0.010959  54.821401  0.268207  0.989287  8.511188  9.955297
# 5  5.0  0.013699  54.821427  0.268207  0.989287  8.511182  9.955293
# 6  6.0  0.016438  54.821453  0.268207  0.989287  8.511175  9.955289
# 7  7.0  0.019178  54.821479  0.268207  0.989287  8.511169  9.955284
# 8  8.0  0.021918  54.821506  0.268206  0.989287  8.511163  9.955279
# 9  9.0  0.024658  54.821533  0.268206  0.989287  8.511157  9.955275
#
#           7         8         9   ...   14   15         16         17  \
# 0  50.033894  8.186889  0.809228  ...  0.0  0.0  56.602835  22.673092
# 1  50.033881  8.186888  0.809230  ...  0.0  0.0  56.602823  22.673058
# 2  50.033867  8.186887  0.809231  ...  0.0  0.0  56.602811  22.673023
# 3  50.033854  8.186887  0.809233  ...  0.0  0.0  56.602799  22.672989
# 4  50.033840  8.186886  0.809235  ...  0.0  0.0  56.602787  22.672955
# 5  50.033827  8.186885  0.809236  ...  0.0  0.0  56.602775  22.672921
# 6  50.033813  8.186884  0.809238  ...  0.0  0.0  56.602763  22.672887
# 7  50.033799  8.186883  0.809240  ...  0.0  0.0  56.602751  22.672853
# 8  50.033786  8.186882  0.809241  ...  0.0  0.0  56.602739  22.672819
# 9  50.033772  8.186881  0.809243  ...  0.0  0.0  56.602727  22.672785
#
#           18        19        20        21        22   23
# 0  25.988747  0.830739  0.149208  0.307874  9.838410  0.0
# 1  25.988736  0.830741  0.149204  0.307875  9.838412  0.0
# 2  25.988726  0.830742  0.149200  0.307875  9.838414  0.0
# 3  25.988715  0.830743  0.149195  0.307876  9.838416  0.0
# 4  25.988704  0.830744  0.149191  0.307876  9.838418  0.0
# 5  25.988692  0.830745  0.149187  0.307877  9.838420  0.0
# 6  25.988681  0.830747  0.149183  0.307877  9.838422  0.0
# 7  25.988669  0.830748  0.149179  0.307878  9.838424  0.0
# 8  25.988657  0.830749  0.149175  0.307879  9.838426  0.0
# 9  25.988645  0.830750  0.149171  0.307879  9.838428  0.0
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Rename columns (see file /Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/Explanation Output Parameters.docx)
labels = ['Time (day)', 'Time (year)',                    # Time labels
          'Rs', 'Rj', 'Ra',                               # Shared resources biomass
          'Sj', 'Sa', 'Sb',                               # Sprat stages biomass
          'Cj', 'Ca', 'Cb',                               # Cod stages biomass
          'Fc',                                           # Fishing imposed on cod
          'ΔCj + Fc', 'ΔCa + Fc', 'ΔCb + Fc', 'ΔC + Fc', # Changes in cod biomass when fishing present
          'ΔSb', 'ΔSj', 'ΔSa',                           # Changes in sprat biomass
          'ΔCb', 'ΔCj', 'ΔCa',                           # Changes in cod biomass
          'ΣC',                                           # Sum of cod biomass
          'Fs']                                           # Fishing imposed on sprat
ebt.columns = labels

# Show new column labels
print(ebt.columns)
# Out:
# Index(['Time (day)', 'Time (year)', 'Rs', 'Rj', 'Ra', 'Sj', 'Sa', 'Sb', 'Cj',
#        'Ca', 'Cb', 'Fc', 'ΔCj + Fc', 'ΔCa + Fc', 'ΔCb + Fc', 'ΔC + Fc', 'ΔSb',
#        'ΔSj', 'ΔSa', 'ΔCb', 'ΔCj', 'ΔCa', 'ΣC', 'Fs'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = ebt[['Cj', 'Ca', 'Cb']]
sprat = ebt[['Sj', 'Sa', 'Sb']]
time = ebt['Time (year)']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center right')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center right')

# Draw vertical line at 20 years and 30 years to visualize data selection
cod_plt.plot([20] * 10, np.arange(0,10), '--k')
sprat_plt.plot([20] * 150, np.arange(0,150), '--k')

cod_plt.plot([30] * 10, np.arange(0,10), '--k')
sprat_plt.plot([30] * 150, np.arange(0,150), '--k')

# %% [markdown]
# In the above figure dashed lines represent the data I have selected to carry out a demo of the TCDF machine learning model. For the purpose of this demo I have aditionally selected a low resolution of 30 day timesteps over 100 years. Next I will clean the data for this demo purpose too, with the following characteristics:
# > - Data between year 20 and 30 (i.e. 120 datapoints)
# > - Inclusion of the columns representing sprat- and cod stages
# > - Inclusion of the shared resources columns
#
# The data needs to be converted into a .csv file with every column representative of a (continuous) timeseries and the header needs explanatory column names (for eventually we will create a temporal causal graph with each node representing a timeseries).

# %%
# Select information of datapoints between year 20 and 30
demo_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 30)]

# Select only the necessary biomass columns as timeseries
demo_ebt = demo_ebt[['Rs', 'Rj', 'Ra',
                     'Sj', 'Sa', 'Sb',
                     'Cj', 'Ca', 'Cb',
                     'Fc']]

# Reset index
demo_ebt.reset_index(inplace = True)
demo_ebt.drop('index', axis = 'columns', inplace = True)

# Show first and last five columns of clean dataframe
demo_ebt.head(-5)
# Out:
#              Rs        Rj        Ra         Sj         Sa         Sb  \
# 0     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 1     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 2     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 3     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 4     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# ...         ...       ...       ...        ...        ...        ...
# 3641  25.940005  0.290546  0.969713  11.992235  20.165629  69.478724
# 3642  25.957505  0.290461  0.969712  11.986605  20.150119  69.483323
# 3643  25.975086  0.290377  0.969711  11.980978  20.134557  69.487854
# 3644  25.992747  0.290292  0.969711  11.975354  20.118942  69.492318
# 3645  26.010489  0.290208  0.969711  11.969734  20.103275  69.496714
#
#             Cj        Ca        Cb        Fc
# 0     8.184919  0.809400  0.843533  0.000000
# 1     8.184919  0.809399  0.843532  0.001027
# 2     8.184919  0.809399  0.843530  0.002055
# 3     8.184918  0.809398  0.843527  0.003082
# 4     8.184917  0.809396  0.843522  0.004110
# ...        ...       ...       ...       ...
# 3641  8.987906  3.973822  0.076795  3.740753
# 3642  8.989210  3.972971  0.076769  3.741781
# 3643  8.990512  3.972101  0.076743  3.742808
# 3644  8.991813  3.971212  0.076716  3.743836
# 3645  8.993112  3.970304  0.076689  3.744863
#
# [3646 rows x 10 columns]

# %% [markdown]
# ### Low Resolution Dataset
# Run these cells when performing machine learning model with low res dataset

# %%
# Compress dataset to lower resolution (~365 datapoints)
low_demo_ebt = demo_ebt.iloc[::10, :]
low_demo_ebt.reset_index(drop = True, inplace = True)
low_demo_ebt['Time'] = np.linspace(20, 30, 366)

# Check format of low resolution dataset
low_demo_ebt
# Out:
#             Rs        Rj        Ra         Sj         Sa         Sb        Cj  \
# 0    54.838332  0.268238  0.989280   8.510205   9.956561  50.013244  8.184919
# 1    54.838330  0.268238  0.989280   8.510207   9.956563  50.013248  8.184903
# 2    54.838303  0.268239  0.989280   8.510224   9.956576  50.013281  8.184851
# 3    54.838202  0.268241  0.989282   8.510272   9.956614  50.013370  8.184762
# 4    54.837966  0.268244  0.989284   8.510369   9.956694  50.013544  8.184634
# ..         ...       ...       ...        ...        ...        ...       ...
# 361  25.440350  0.293186  0.969794  12.167928  20.617554  69.302405  8.946928
# 362  25.592090  0.292331  0.969755  12.111058  20.478283  69.366466  8.960258
# 363  25.753000  0.291479  0.969728  12.054347  20.332621  69.423668  8.973486
# 364  25.922587  0.290631  0.969713  11.997868  20.181086  69.474057  8.986601
# 365  26.100388  0.289787  0.969711  11.941679  20.024186  69.517690  8.999591
#
#            Ca        Cb        Fc       Time
# 0    0.809400  0.843533  0.000000  20.000000
# 1    0.809379  0.843464  0.010274  20.027397
# 2    0.809317  0.843258  0.020548  20.054795
# 3    0.809213  0.842916  0.030822  20.082192
# 4    0.809070  0.842440  0.041096  20.109589
# ..        ...       ...       ...        ...
# 361  3.990450  0.077369  3.708904  29.890411
# 362  3.987189  0.077231  3.719178  29.917808
# 363  3.981907  0.077048  3.729452  29.945205
# 364  3.974654  0.076820  3.739726  29.972603
# 365  3.965480  0.076547  3.750000  30.000000
#
# [366 rows x 11 columns]

# %%
# Visualize data from lower resolution dataset 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = low_demo_ebt[['Cj', 'Ca', 'Cb']]
sprat = low_demo_ebt[['Sj', 'Sa', 'Sb']]
time = low_demo_ebt['Time']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics 20-30 years')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')

# Remove Time column
low_demo_ebt.drop(['Time'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled = scaler.fit_transform(low_demo_ebt)

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
demo_ebt_scaled = pd.DataFrame(ebt_scaled, columns = labels)

# Check the scaled DataFrame
demo_ebt_scaled.head(-10)
# Out:
#            Rs        Rj        Ra            Sj        Sa            Sb  \
# 0    1.000000  0.165405  0.984417  0.000000e+00  0.000123  0.000000e+00
# 1    1.000000  0.165409  0.984422  5.055820e-07  0.000123  2.369050e-07
# 2    0.999999  0.165428  0.984450  4.195656e-06  0.000124  1.907222e-06
# 3    0.999996  0.165470  0.984512  1.458505e-05  0.000128  6.462716e-06
# 4    0.999988  0.165540  0.984610  3.547577e-05  0.000135  1.537952e-05
# ..        ...       ...       ...           ...       ...           ...
# 351  0.000394  0.834836  0.058395  9.102274e-01  0.994137  9.365301e-01
# 352  0.001315  0.818991  0.050148  8.991905e-01  0.990120  9.433765e-01
# 353  0.002741  0.802812  0.042518  8.878420e-01  0.985123  9.498690e-01
# 354  0.004649  0.786351  0.035513  8.762325e-01  0.979184  9.560058e-01
# 355  0.007018  0.769659  0.029136  8.644091e-01  0.972341  9.617859e-01
#
#            Cj        Ca        Cb        Fc
# 0    0.011209  0.002429  1.000000  0.000000
# 1    0.011189  0.002423  0.999912  0.002740
# 2    0.011126  0.002403  0.999650  0.005479
# 3    0.011018  0.002371  0.999214  0.008219
# 4    0.010862  0.002326  0.998606  0.010959
# ..        ...       ...       ...       ...
# 351  0.771108  0.972165  0.021485  0.961644
# 352  0.787616  0.978138  0.021878  0.964384
# 353  0.804167  0.983378  0.022219  0.967123
# 354  0.820744  0.987887  0.022505  0.969863
# 355  0.837330  0.991670  0.022736  0.972603
#
# [356 rows x 10 columns]

# %% [markdown]
# ### High Resolution Dataset
# Run these cells when performing machine learning model with high res dataset

# %%
# Visualize data from lower resolution dataset 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = demo_ebt[['Cj', 'Ca', 'Cb']]
sprat = demo_ebt[['Sj', 'Sa', 'Sb']]
demo_ebt['Time'] = np.linspace(20, 30, 3651)
time = demo_ebt['Time']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics 20-30 years')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')

# Remove Time column
demo_ebt.drop(['Time'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled = scaler.fit_transform(demo_ebt)

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
demo_ebt_scaled = pd.DataFrame(ebt_scaled, columns = labels)

# Check the scaled DataFrame
demo_ebt_scaled.head(-10)
# Out:
#             Rs        Rj        Ra            Sj        Sa            Sb  \
# 0     1.000000  0.165474  0.984412  0.000000e+00  0.000190  0.000000e+00
# 1     1.000000  0.165474  0.984412  3.460767e-10  0.000190  1.384297e-10
# 2     1.000000  0.165474  0.984412  3.655434e-09  0.000190  1.697049e-09
# 3     1.000000  0.165474  0.984412  1.286972e-08  0.000190  6.111426e-09
# 4     1.000000  0.165474  0.984413  3.110363e-08  0.000190  1.480175e-08
# ...        ...       ...       ...           ...       ...           ...
# 3636  0.043359  0.622474  0.000372  7.592537e-01  0.882482  9.967713e-01
# 3637  0.043923  0.620770  0.000308  7.580328e-01  0.881175  9.970244e-01
# 3638  0.044489  0.619066  0.000250  7.568126e-01  0.879863  9.972741e-01
# 3639  0.045059  0.617363  0.000198  7.555930e-01  0.878546  9.975202e-01
# 3640  0.045631  0.615661  0.000152  7.543740e-01  0.877225  9.977629e-01
#
#             Cj        Ca        Cb        Fc
# 0     0.011218  0.002431  1.000000  0.000000
# 1     0.011218  0.002431  0.999999  0.000274
# 2     0.011217  0.002431  0.999996  0.000548
# 3     0.011216  0.002430  0.999992  0.000822
# 4     0.011215  0.002430  0.999986  0.001096
# ...        ...       ...       ...       ...
# 3636  0.977885  0.995656  0.022334  0.996164
# 3637  0.979474  0.995420  0.022304  0.996438
# 3638  0.981062  0.995177  0.022273  0.996712
# 3639  0.982649  0.994929  0.022242  0.996986
# 3640  0.984234  0.994674  0.022211  0.997260
#
# [3641 rows x 10 columns]

# %% [markdown]
# ### Continue here after selection of dataset resolution

# %%
# Define function for visualisation of scaled data 

def visualise_scaled(ebt_scaled, years):
    # Select data to be visualized
    cod = ebt_scaled[['Cj', 'Ca', 'Cb']]
    sprat = ebt_scaled[['Sj', 'Sa', 'Sb']]
    resource = ebt_scaled[['Rj', 'Rs', 'Ra']]
    ebt_scaled['Time'] = np.linspace(years[0], years[1], len(ebt_scaled))
    time = ebt_scaled['Time']

    # Set subplot figure defaults
    fig, [cod_plt, sprat_plt, resource_plt] = plt.subplots(3, 1, sharex = True)
    fig.subplots_adjust(hspace = 0)
    fig.suptitle('Cod-sprat-resource dynamics {start}-{stop} years (scaled min-max)'.format(start=years[0],stop=years[1]))

    # Set labels for shared x-axis and individual y-axes
    cod_plt.set(ylabel = 'Cod biomass')
    sprat_plt.set(ylabel = 'Sprat biomass')
    resource_plt.set(ylabel = 'Resource biomass')
    plt.xlabel('Time (years)')

    # Visualize data
    cod_plt.plot(time, cod)
    sprat_plt.plot(time, sprat)
    resource_plt.plot(time, resource)

    # Add legends
    cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
    sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')
    resource_plt.legend(['Rj', 'Rs', 'Ra'], loc = 'center left')

    # Remove Time column
    ebt_scaled.drop(['Time'], axis = 1, inplace = True)

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(demo_ebt_scaled, [20,30])

# %%
# Create file path for new file
DemoEBTScaled_path = os.path.join(TCDFdata_path, 'EBT_demo_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
demo_ebt_scaled.to_csv(DemoEBTScaled_path, index = False)

# %% [markdown]
# For implementation of the first machine model (i.e. TCDF) we have to create a reference to the 'groundtruth' of the model. This makes it possible to compare the found relations by the model to the true relations we have defined in the dataset.
#
# The groundtruth file needs to be .csv file, have no heading and contains three columns. The first column consists of the index of the cause (corresponds to the columnnumber in the EBT_demo_dataset.csv file), index of effect (idem dito), and time delay between index and cause.
#
# For the corresponding causes and effects see the paper by A. van Leeuwen et al. (2008).

# %%
# Create list of lists for the rows to the groundtruth.csv file
groundtruth_rows = [[9, 7, 0],  # Fc - Ca
                    [9, 8, 0],  # Fc - Cb
                    [6, 1, 0],  # Cj - Rj
                    [6, 3, 0],  # Cj - Sj
                    [7, 3, 0],  # Ca - Sj
                    [7, 4, 0],  # Ca - Sa
                    [7, 5, 0],  # Ca - Sb
                    [8, 3, 0],  # Cb - Sj
                    [8, 4, 0],  # Cb - Sa
                    [8, 5, 0],  # Cb - Sb
                    [8, 2, 0],  # Cb - Ra
                    [3, 0, 0],  # Sj - Rs
                    [4, 0, 0],  # Sa - Rs
                    [5, 0, 0]]  # Sb - Rs

# Convert list into DataFrame
groundtruth = pd.DataFrame(groundtruth_rows)

# Create file path for new file
DemoEBTGroundtruth_path = os.path.join(TCDFdata_path, 'EBT_demo_groundtruth.csv')

# Write DataFrame to .csv
groundtruth.to_csv(DemoEBTGroundtruth_path, index = False, header = False)

# %% [markdown]
# Performing the TCDF requires a different directory (where the TCDF is located). Check if the current directory is set at `'/.../TCDF'`.

# %%
# Define needed directory
directory = TCDF_path

# Check current working directory
current_directory = os.getcwd()

# Change working directory to perform TCDF
if current_directory != directory:
    os.chdir(TCDF_path)

# Check new current working directory
os.getcwd()
# Out:
# '/Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/GitHub/thesis/TCDF'

# %% [markdown]
# This part shows the functionality of TCDF.
#
# See the corresponding paper for more detail: ["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19).

# %%
# Install conda- and pip packages in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} git
# !{sys.executable} -m pip install torchvision
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: pillow>=4.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (8.0.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.19.2)
# Requirement already satisfied: torch==1.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.8.1)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch==1.8.1->torchvision) (3.7.4.3)

# %% [markdown]
# # TCDF
#
# These next code cells perform the analysis of the (demo) dataset with the TCDF. In the utils.py file you are able to adjust parameters for adaptive learning rate and early stopping. These parameters include type of optimizer (specified in runTCDF.py arguments), number of epochs before adapting learning rate, minimum learning rate, and size of decreasing learning rate factor. For early stopping two parameters are given, the number of epochs before stopping when loss is not improving and the minimum difference in loss improvement.

# %%
# Show all argument options

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#                   [--lr_scheduler] [--early_stopping]
#
# TCDF: Temporal Causal Discovery Framework
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series
#   --lr_scheduler        Train model with adaptive learning rate (default:
#                         True). Optional to tweak parameters in utensils.py
#                         (default: patience=5, min_lr=1e-6, factor=0.1).
#   --early_stopping      Train model with early stopping (default: True).
#                         Optional to tweak parameters in utensils.py (default:
#                         patience=150, min_delta=0).

# %% [markdown]
# ### Function for plotting

# %%
# This function is to be used to plot the model's loss or accuracy (i.e. performance) after running 
def plot_performance(losses_or_accuracy):
    """Plots the losses for each trained variable for the TCDF model.
    Takes a dictionary with either losses or accuracy for each variable as input"""
    # Preallocate plots in subplots
    fig, axs = plt.subplots(3, 3, sharex = True)
    for ax in axs.flat:
        ax.set(xlabel='Epochs', ylabel='Performance measure')

    # Iterate over each key in dictionary
    keys = list(losses_or_accuracy.keys())
    
    # Plot every variable in different subplot
    axs[0, 0].plot(np.arange(len(losses_or_accuracy[keys[0]])), losses_or_accuracy[keys[0]])
    axs[0, 0].set_title('Performance Rs')
    axs[0, 1].plot(np.arange(len(losses_or_accuracy[keys[1]])), losses_or_accuracy[keys[1]])
    axs[0, 1].set_title('Performance Rj')
    axs[0, 2].plot(np.arange(len(losses_or_accuracy[keys[2]])), losses_or_accuracy[keys[2]])
    axs[0, 2].set_title('Performance Ra')
    axs[1, 0].plot(np.arange(len(losses_or_accuracy[keys[3]])), losses_or_accuracy[keys[3]])
    axs[1, 0].set_title('Performance Sj')
    axs[1, 1].plot(np.arange(len(losses_or_accuracy[keys[4]])), losses_or_accuracy[keys[4]])
    axs[1, 1].set_title('Performance Sa')
    axs[1, 2].plot(np.arange(len(losses_or_accuracy[keys[5]])), losses_or_accuracy[keys[5]])
    axs[1, 2].set_title('Performance Sb')
    axs[2, 0].plot(np.arange(len(losses_or_accuracy[keys[6]])), losses_or_accuracy[keys[6]])
    axs[2, 0].set_title('Performance Cj')
    axs[2, 1].plot(np.arange(len(losses_or_accuracy[keys[7]])), losses_or_accuracy[keys[7]])
    axs[2, 1].set_title('Performance Ca')
    axs[2, 2].plot(np.arange(len(losses_or_accuracy[keys[8]])), losses_or_accuracy[keys[8]])
    axs[2, 2].set_title('Performance Cb')

# %% [markdown]
# ## TCDF Training
#
# In this section I will tweak (hyper)parameters and save the best outcomes thus far. After implementation of a learning rate scheduler and early stopping to help the process of training the model (see the ~.py files in the TCDF folder, any adjustments are highlighted by '# Adjusted implementation by Draaijer, R.'). Besides, I have also implemented some extra code to save predictive accuracy of the model to plot the performance of the model after the run. Each run is accompanied by two plots (losses and accuracy) to keep track of training the model.

# %% [markdown]
# ### TCDF with EBT demo data
# #### TCDF: first run

# %%
# %matplotlib inline

# Run TCDF with the selected demo dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.315483
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000042
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.088744
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 4, 2]
# Validated causes:  [0]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.309657
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000125
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 2]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.091067
# Epoch   138: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   149: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   160: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   171: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   182: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 4]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.079456
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8]
# Validated causes:  [0]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.076466
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000465
# Epoch  1885: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 2000 [40%] 	Loss: 0.000101
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0]
# Validated causes:  [0]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.090259
# Epoch    30: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.003199
# Epoch: 2000 [40%] 	Loss: 0.001516
# Epoch: 3000 [60%] 	Loss: 0.001304
# Epoch: 4000 [80%] 	Loss: 0.000578
# Epoch: 5000 [100%] 	Loss: 0.000371
# Potential causes:  [8, 0]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.080412
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0]
# Validated causes:  []
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.130652
# Epoch    70: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.001200
# Epoch  1556: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 2000 [40%] 	Loss: 0.000965
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 4, 7]
# Validated causes:  [9]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.173820
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000127
# Epoch: 2000 [40%] 	Loss: 0.000016
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 2, 9]
# Validated causes:  [9]
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Sa causes Rs with a delay of 0 time steps.
# Rs causes Rj with a delay of 19 time steps.
# Ra causes Ra with a delay of 51 time steps.
# Rs causes Sa with a delay of 19 time steps.
# Rs causes Sb with a delay of 23 time steps.
# Fc causes Cb with a delay of 12 time steps.
# Fc causes Fc with a delay of 13 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  2
# Total False Negatives:  12
# Total Direct False Positives:  5
# Total Direct True Positives:  2
# TPs':  [(0, 4), (8, 9)]
# FPs':  [(1, 0), (2, 2), (4, 0), (5, 0), (9, 9)]
# TPs direct:  [(0, 4), (8, 9)]
# FPs direct:  [(1, 0), (2, 2), (4, 0), (5, 0), (9, 9)]
# FNs:  [(0, 3), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9)]
# Precision':  0.2857142857142857
# Recall':  0.14285714285714285
# F1' score:  0.19047619047619047 (includes direct and indirect causal relationships)
# Precision:  0.2857142857142857
# Recall:  0.14285714285714285
# F1 score:  0.19047619047619047 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  50.0 %
# ==================================================================================

# %% [markdown]
# #### TCDF: second run (1 extra hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected demo dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.944516
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.418263
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   459: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000196
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 2, 3, 4]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.933834
# Epoch    86: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 1, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.371063
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.002543
# Epoch: 2000 [40%] 	Loss: 0.000316
# Epoch: 3000 [60%] 	Loss: 0.000167
# Epoch  3238: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.301430
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6]
# Validated causes:  [9]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.382139
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   711: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000191
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 8, 2, 4]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.441266
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   311: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.003479
# Epoch: 2000 [40%] 	Loss: 0.002997
# Epoch: 3000 [60%] 	Loss: 0.000923
# Epoch  3759: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 4000 [80%] 	Loss: 0.000234
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 9]
# Validated causes:  [1, 9]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.361514
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.002432
# Epoch: 2000 [40%] 	Loss: 0.000432
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 2]
# Validated causes:  []
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.469285
# Epoch   181: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   192: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   203: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   214: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   225: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 6]
# Validated causes:  [6]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.636449
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    26: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 6]
# Validated causes:  []
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Fc causes Sa with a delay of 0 time steps.
# Rj causes Cj with a delay of 64 time steps.
# Fc causes Cj with a delay of 0 time steps.
# Cj causes Cb with a delay of 241 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  3
# Total True Positives':  1
# Total False Negatives:  14
# Total Direct False Positives:  4
# Total Direct True Positives:  0
# TPs':  [(4, 9)]
# FPs':  [(6, 1), (6, 9), (8, 6)]
# TPs direct:  []
# FPs direct:  [(4, 9), (6, 1), (6, 9), (8, 6)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.25
# Recall':  0.06666666666666667
# F1' score:  0.10526315789473685 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.271688
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.215972
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   642: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000050
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.283262
# Epoch   501: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   512: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   523: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   534: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   545: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.128814
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.098214
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   692: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000069
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.151669
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   216: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.220153
# Epoch   375: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   394: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   405: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   416: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   427: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.124031
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.819749
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.264319
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 475.03923302678515 with standard deviation 523.8502483206635

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF: third run (different seed)

# %%
# %matplotlib inline

# Run TCDF and evaluate by comparing the results to the ground truth

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.493696
# Epoch   352: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   363: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   374: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   385: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   396: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000106
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 3, 6, 8, 2]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.160939
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.000220
# Epoch   576: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000180
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8, 6]
# Validated causes:  [7, 8, 6]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.486154
# Epoch    47: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    91: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.075919
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 8, 6, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.145745
# Epoch   257: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   268: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   279: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   290: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   301: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000524
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8]
# Validated causes:  [7, 8]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.113504
# Epoch   166: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.000681
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8]
# Validated causes:  [7, 8]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.140269
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.016042
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 6, 0, 2]
# Validated causes:  [8]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.170167
# Epoch    95: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   106: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   117: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   128: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   139: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.006512
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5]
# Validated causes:  [8]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.135478
# Epoch    55: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   101: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   112: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   123: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   134: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.002527
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 6]
# Validated causes:  [8, 6]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.205626
# Epoch   213: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   224: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   243: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   254: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   265: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000112
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 7, 8]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.293416
# Epoch   230: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   241: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   252: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   263: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   274: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000152
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 6, 2, 9]
# Validated causes:  [8]
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Ca causes Rj with a delay of 192 time steps.
# Cb causes Rj with a delay of 114 time steps.
# Cj causes Rj with a delay of 59 time steps.
# Ca causes Sj with a delay of 192 time steps.
# Cb causes Sj with a delay of 242 time steps.
# Ca causes Sa with a delay of 204 time steps.
# Cb causes Sa with a delay of 242 time steps.
# Cb causes Sb with a delay of 250 time steps.
# Cb causes Cj with a delay of 98 time steps.
# Cb causes Ca with a delay of 250 time steps.
# Cj causes Ca with a delay of 179 time steps.
# Cb causes Cb with a delay of 59 time steps.
# Cb causes Fc with a delay of 242 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  7
# Total True Positives':  6
# Total False Negatives:  8
# Total Direct False Positives:  7
# Total Direct True Positives:  6
# TPs':  [(1, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 8)]
# FPs':  [(1, 7), (1, 8), (6, 8), (7, 8), (7, 6), (8, 8), (9, 8)]
# TPs direct:  [(1, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 8)]
# FPs direct:  [(1, 7), (1, 8), (6, 8), (7, 8), (7, 6), (8, 8), (9, 8)]
# FNs:  [(0, 3), (0, 4), (0, 5), (2, 8), (3, 6), (5, 7), (7, 9), (8, 9)]
# Precision':  0.46153846153846156
# Recall':  0.42857142857142855
# F1' score:  0.4444444444444445 (includes direct and indirect causal relationships)
# Precision:  0.46153846153846156
# Recall:  0.42857142857142855
# F1 score:  0.4444444444444445 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.710360
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.001426
# Epoch   776: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.001194
# Epoch: 1500 [30%] 	Loss: 0.001058
# Epoch: 2000 [40%] 	Loss: 0.000692
# Epoch: 2500 [50%] 	Loss: 0.000584
# Epoch: 3000 [60%] 	Loss: 0.000504
# Epoch: 3500 [70%] 	Loss: 0.000096
# Epoch: 4000 [80%] 	Loss: 0.000021
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.033598
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.005485
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.719528
# Epoch   146: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.000584
# Epoch: 1000 [20%] 	Loss: 0.000376
# Epoch: 1500 [30%] 	Loss: 0.000081
# Epoch: 2000 [40%] 	Loss: 0.000026
# Epoch  2018: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.009420
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [10%] 	Loss: 0.002948
# Epoch: 1000 [20%] 	Loss: 0.001379
# Epoch: 1500 [30%] 	Loss: 0.000661
# Epoch: 2000 [40%] 	Loss: 0.000362
# Epoch: 2500 [50%] 	Loss: 0.000273
# Epoch: 3000 [60%] 	Loss: 0.000218
# Epoch: 3500 [70%] 	Loss: 0.000165
# Epoch: 4000 [80%] 	Loss: 0.000115
# Epoch: 4500 [90%] 	Loss: 0.000072
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.002514
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    23: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.005399
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.017686
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [10%] 	Loss: 0.003807
# Epoch: 1000 [20%] 	Loss: 0.000362
# Epoch: 1500 [30%] 	Loss: 0.000280
# Epoch: 2000 [40%] 	Loss: 0.000230
# Epoch: 2500 [50%] 	Loss: 0.000192
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.047620
# Epoch    23: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.018236
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.009529
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.006290
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.402405
# Epoch    92: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.004595
# Epoch: 1000 [20%] 	Loss: 0.000793
# Epoch  1043: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1500 [30%] 	Loss: 0.000613
# Epoch: 2000 [40%] 	Loss: 0.000492
# Epoch: 2500 [50%] 	Loss: 0.000342
# Epoch: 3000 [60%] 	Loss: 0.000086
# Epoch: 3500 [70%] 	Loss: 0.000054
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.064163
# Epoch   166: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   190: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   210: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   221: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   232: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000011
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 660.9578524893209 with standard deviation 960.9862357532132

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF: fourth run (different seed)

# %%
# %matplotlib inline

# Run TCDF and evaluate by comparing the results to the ground truth

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 25942 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=25942, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.811492
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.086143
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5, 7, 9]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.335554
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.068902
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8, 5, 7]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.801631
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.086242
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5, 7, 9]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.296673
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.079427
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 8, 4, 2, 5]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.236779
# Epoch    65: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.000608
# Epoch   667: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000346
# Epoch: 1500 [30%] 	Loss: 0.000280
# Epoch: 2000 [40%] 	Loss: 0.000210
# Epoch: 2500 [50%] 	Loss: 0.000146
# Epoch: 3000 [60%] 	Loss: 0.000100
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 8]
# Validated causes:  [1]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.303435
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.058930
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 4]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.354950
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.001705
# Epoch   712: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   732: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   754: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   765: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.001590
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 7]
# Validated causes:  [5, 7]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.286932
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.000287
# Epoch: 1000 [20%] 	Loss: 0.000241
# Epoch  1007: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1018: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1039: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1050: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 3, 8]
# Validated causes:  [1]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.385008
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    23: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.104602
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 7, 5]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.531397
# Epoch   256: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   267: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   278: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   289: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   300: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000585
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8]
# Validated causes:  [8]
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Rj causes Sa with a delay of 142 time steps.
# Sb causes Cj with a delay of 72 time steps.
# Ca causes Cj with a delay of 158 time steps.
# Rj causes Ca with a delay of 198 time steps.
# Cb causes Fc with a delay of 128 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  5
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(4, 1), (6, 5), (6, 7), (7, 1), (9, 8)]
# TPs direct:  []
# FPs direct:  [(4, 1), (6, 5), (6, 7), (7, 1), (9, 8)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --dilation_coefficient 4 --kernel_size 4 --seed 25942 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=25942, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.110013
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.005689
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.152828
# Epoch    31: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    84: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.002263
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.120961
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.008022
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.082042
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [10%] 	Loss: 0.001022
# Epoch: 1000 [20%] 	Loss: 0.000077
# Epoch: 1500 [30%] 	Loss: 0.000028
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057608
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.001786
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.101098
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.008620
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.159548
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.016561
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.078530
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.005206
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.695548
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   425: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [10%] 	Loss: 0.000533
# Epoch: 1000 [20%] 	Loss: 0.000470
# Epoch: 1500 [30%] 	Loss: 0.000403
# Epoch: 2000 [40%] 	Loss: 0.000342
# Epoch: 2500 [50%] 	Loss: 0.000284
# Epoch: 3000 [60%] 	Loss: 0.000224
# Epoch: 3500 [70%] 	Loss: 0.000173
# Epoch: 4000 [80%] 	Loss: 0.000139
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.196528
# Epoch   190: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   201: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   212: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   223: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   234: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [10%] 	Loss: 0.000074
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 648.238896895335 with standard deviation 654.3400844945764

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# There seems to be big differences in performance and loss when changing the seed, this indicates an unstable pattern and have to find better (hyper)parameters. Or maybe because there is too little data for now?

# %% [markdown]
# ### TCDF with EBT total dynamics
#
# This data represents the tritrophic biomasses including the total dynamics (shift change). The system first is at its equilibrium and remains stable for ~20 years, fishing pressure is introduced and a new equilibrium is to be found (at 70 years it is stable again). Data is split into two 'total dynamics', 0 - 100 years and 20 - 70 years respectively.
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints between year 20 and 70
total_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 70)]
total_ebt_2 = ebt[(ebt['Time (year)'] >= 0) & (ebt['Time (year)'] <= 100)]


# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(total_ebt[['Rs', 'Rj', 'Ra',
                                             'Sj', 'Sa', 'Sb',
                                             'Cj', 'Ca', 'Cb',
                                             'Fc']])
ebt_scaled_2 = scaler.fit_transform(total_ebt_2[['Rs', 'Rj', 'Ra',
                                             'Sj', 'Sa', 'Sb',
                                             'Cj', 'Ca', 'Cb',
                                             'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))
# Out:
#             Rs        Rj        Ra        Sj        Sa        Sb        Cj  \
# 0      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 1      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 2      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 3      1.00000  0.018127  0.646079  0.441177  0.000017  0.459337  0.879586
# 4      1.00000  0.018127  0.646079  0.441177  0.000017  0.459337  0.879586
# ...        ...       ...       ...       ...       ...       ...       ...
# 18236  0.00003  0.999801  0.999999  0.000081  0.999837  0.000260  0.000056
# 18237  0.00003  0.999815  0.999999  0.000075  0.999849  0.000241  0.000052
# 18238  0.00003  0.999829  0.999999  0.000069  0.999861  0.000222  0.000048
# 18239  0.00003  0.999844  0.999999  0.000063  0.999872  0.000204  0.000044
# 18240  0.00003  0.999858  0.999999  0.000058  0.999884  0.000185  0.000040
#
#                  Ca        Cb        Fc
# 0      2.027708e-01  1.000000  0.000000
# 1      2.027707e-01  0.999999  0.000068
# 2      2.027705e-01  0.999997  0.000137
# 3      2.027703e-01  0.999993  0.000205
# 4      2.027699e-01  0.999987  0.000274
# ...             ...       ...       ...
# 18236  3.579564e-07  0.000043  0.000000
# 18237  3.559397e-07  0.000043  0.000000
# 18238  3.539230e-07  0.000043  0.000000
# 18239  3.519088e-07  0.000043  0.000000
# 18240  3.498946e-07  0.000043  0.000000
#
# [18241 rows x 10 columns]
#              Rs        Rj        Ra            Sj        Sa            Sb  \
# 0      0.999640  0.017874  0.646314  4.437391e-01  0.000014  4.672258e-01
# 1      0.999641  0.017874  0.646314  4.437384e-01  0.000014  4.672257e-01
# 2      0.999642  0.017874  0.646314  4.437376e-01  0.000014  4.672255e-01
# 3      0.999642  0.017873  0.646313  4.437369e-01  0.000014  4.672253e-01
# 4      0.999643  0.017873  0.646313  4.437361e-01  0.000014  4.672251e-01
# ...         ...       ...       ...           ...       ...           ...
# 36486  0.000066  1.000000  1.000000  4.452738e-10  1.000000  9.053616e-10
# 36487  0.000066  1.000000  1.000000  4.091706e-10  1.000000  8.397362e-10
# 36488  0.000066  1.000000  1.000000  3.730672e-10  1.000000  7.754502e-10
# 36489  0.000066  1.000000  1.000000  3.489984e-10  1.000000  7.098249e-10
# 36490  0.000066  1.000000  1.000000  3.128952e-10  1.000000  6.455388e-10
#
#                  Cj            Ca            Cb   Fc
# 0      8.801519e-01  2.027305e-01  9.985097e-01  0.0
# 1      8.801518e-01  2.027309e-01  9.985112e-01  0.0
# 2      8.801517e-01  2.027313e-01  9.985126e-01  0.0
# 3      8.801516e-01  2.027317e-01  9.985140e-01  0.0
# 4      8.801515e-01  2.027321e-01  9.985154e-01  0.0
# ...             ...           ...           ...  ...
# 36486  3.735778e-10  8.290317e-11  1.568844e-07  0.0
# 36487  3.467977e-10  7.696076e-11  1.568010e-07  0.0
# 36488  3.200283e-10  7.102085e-11  1.567177e-07  0.0
# 36489  2.932697e-10  6.508596e-11  1.566344e-07  0.0
# 36490  2.665326e-10  5.915356e-11  1.565511e-07  0.0
#
# [36491 rows x 10 columns]

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(ebt_scaled_1, [20,70])

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(ebt_scaled_2, [0,100])

# %%
# Create file path for new file
EBTScaled_path_1 = os.path.join(TCDFdata_path, 'EBT_20_70_dataset.csv')
EBTScaled_path_2 = os.path.join(TCDFdata_path, 'EBT_0_100_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path_1, index = False)
ebt_scaled_2.to_csv(EBTScaled_path_2, index = False)

# %% [markdown]
# #### TCDF 20-70 years: first run

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 2000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.389573
# Epoch    50: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    83: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    94: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8]
# Validated causes:  [4]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.346638
# Epoch   189: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   200: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   211: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   222: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   233: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 9]
# Validated causes:  [6]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.000301
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 2, 8]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.781407
# Epoch   300: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   311: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   322: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   333: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   344: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8]
# Validated causes:  [4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.371778
# Epoch   183: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000198
# Epoch  1535: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 9]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.922205
# Epoch   114: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   158: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 0]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.999226
# Epoch    42: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   101: reducing learning rate of group 0 to 1.0000e-05.
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.308558
# Epoch   116: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   127: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   150: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   161: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   172: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 4]
# Validated causes:  [2]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.151539
# Epoch    68: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    79: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   101: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   112: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.520986
# Epoch   127: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   142: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.003713
# Epoch: 2000 [100%] 	Loss: 0.001246
# Potential causes:  [4, 9, 0, 2]
# Validated causes:  [9]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Sa causes Rs with a delay of 96 time steps.
# Cj causes Rj with a delay of 65 time steps.
# Sa causes Sj with a delay of 224 time steps.
# Sa causes Cj with a delay of 96 time steps.
# Ra causes Ca with a delay of 130 time steps.
# Cb causes Cb with a delay of 245 time steps.
# Fc causes Fc with a delay of 2 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  2
# Total False Negatives:  12
# Total Direct False Positives:  5
# Total Direct True Positives:  2
# TPs':  [(0, 4), (1, 6)]
# FPs':  [(3, 4), (6, 4), (7, 2), (8, 8), (9, 9)]
# TPs direct:  [(0, 4), (1, 6)]
# FPs direct:  [(3, 4), (6, 4), (7, 2), (8, 8), (9, 9)]
# FNs:  [(0, 3), (0, 5), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.2857142857142857
# Recall':  0.14285714285714285
# F1' score:  0.19047619047619047 (includes direct and indirect causal relationships)
# Precision:  0.2857142857142857
# Recall:  0.14285714285714285
# F1 score:  0.19047619047619047 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_20_70_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_20_70_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.690430
# Epoch    48: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000287
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.084581
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.584549
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.996650
# Epoch    63: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   107: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.084001
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.923356
# Epoch    55: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    66: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    77: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    88: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    99: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.433030
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    27: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.515112
# Epoch   266: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   277: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   288: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   299: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   310: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.243675
# Epoch    63: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000495
# Epoch: 2000 [100%] 	Loss: 0.000316
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.341878
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_20_70_dataset.csv : 123412.61112145956 with standard deviation 332719.09695754555

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF 20-70 years: second run (1 less hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.107181
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.104555
# Epoch   195: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   206: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   217: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   228: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   239: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 9]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.341133
# Epoch   197: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   208: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   219: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   230: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   241: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.241640
# Epoch   156: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   167: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   178: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   189: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   200: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.114193
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 7, 9]
# Validated causes:  [1]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.310394
# Epoch    75: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000023
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.369104
# Epoch   291: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   302: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   313: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   324: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   335: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.060603
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000221
# Epoch  1101: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8, 2, 4]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057252
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000060
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 9]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.146941
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 0, 2]
# Validated causes:  [4]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Sa causes Rs with a delay of 0 time steps.
# Ra causes Ra with a delay of 51 time steps.
# Sa causes Sj with a delay of 0 time steps.
# Rj causes Sa with a delay of 4 time steps.
# Sb causes Sb with a delay of 1 time steps.
# Sa causes Cj with a delay of 0 time steps.
# Ca causes Ca with a delay of 2 time steps.
# Cb causes Cb with a delay of 5 time steps.
# Sa causes Fc with a delay of 0 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  8
# Total Direct True Positives:  1
# TPs':  [(0, 4)]
# FPs':  [(2, 2), (3, 4), (4, 1), (5, 5), (6, 4), (7, 7), (8, 8), (9, 4)]
# TPs direct:  [(0, 4)]
# FPs direct:  [(2, 2), (3, 4), (4, 1), (5, 5), (6, 4), (7, 7), (8, 8), (9, 4)]
# FNs:  [(0, 3), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.1111111111111111
# Recall':  0.07142857142857142
# F1' score:  0.08695652173913043 (includes direct and indirect causal relationships)
# Precision:  0.1111111111111111
# Recall:  0.07142857142857142
# F1 score:  0.08695652173913043 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_20_70_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_20_70_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.649728
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   102: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000660
# Epoch: 2000 [100%] 	Loss: 0.000219
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.070026
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.546163
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.945541
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000907
# Epoch  1218: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1232: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1243: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1254: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.069531
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.874145
# Epoch   103: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.370805
# Epoch    78: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000386
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.479237
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.222763
# Epoch   111: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   155: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.313301
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.003439
# Epoch: 2000 [100%] 	Loss: 0.000533
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_20_70_dataset.csv : 2359476.4868942625 with standard deviation 7050172.042921902

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF 20-70 years: third run (different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.361850
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   406: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000402
# Epoch: 2000 [100%] 	Loss: 0.000145
# Potential causes:  [6, 1, 5]
# Validated causes:  [6, 1, 5]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.321213
# Epoch    53: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000121
# Epoch   999: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 8]
# Validated causes:  [6]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.950099
# Epoch    21: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.738358
# Epoch    43: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 1]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.345428
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 5, 3, 8]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.874865
# Epoch   120: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000565
# Epoch  1337: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1352: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1363: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1374: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 0]
# Validated causes:  [4]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.950823
# Epoch   166: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   177: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   188: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   199: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   210: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.282848
# Epoch   153: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   164: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   183: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   194: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   205: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 6]
# Validated causes:  [6]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.134997
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   365: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000083
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 1]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.487771
# Epoch    68: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000467
# Epoch: 2000 [100%] 	Loss: 0.000258
# Potential causes:  [9, 8, 5]
# Validated causes:  [9]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Cj causes Rs with a delay of 59 time steps.
# Rj causes Rs with a delay of 4 time steps.
# Sb causes Rs with a delay of 6 time steps.
# Cj causes Rj with a delay of 57 time steps.
# Sa causes Sb with a delay of 8 time steps.
# Sa causes Cj with a delay of 8 time steps.
# Cj causes Ca with a delay of 19 time steps.
# Fc causes Fc with a delay of 22 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  3
# Total False Negatives:  12
# Total Direct False Positives:  6
# Total Direct True Positives:  2
# TPs':  [(0, 6), (0, 5), (1, 6)]
# FPs':  [(0, 1), (5, 4), (6, 4), (7, 6), (9, 9)]
# TPs direct:  [(0, 5), (1, 6)]
# FPs direct:  [(0, 6), (0, 1), (5, 4), (6, 4), (7, 6), (9, 9)]
# FNs:  [(0, 3), (0, 4), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.375
# Recall':  0.2
# F1' score:  0.26086956521739135 (includes direct and indirect causal relationships)
# Precision:  0.25
# Recall:  0.14285714285714285
# F1 score:  0.18181818181818182 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_20_70_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_20_70_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.649728
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   102: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000660
# Epoch: 2000 [100%] 	Loss: 0.000219
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.070026
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.546163
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.945541
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000907
# Epoch  1218: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1232: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1243: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1254: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.069531
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.874145
# Epoch   103: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.370805
# Epoch    78: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000386
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.479237
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.222763
# Epoch   111: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   155: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.313301
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.003439
# Epoch: 2000 [100%] 	Loss: 0.000533
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_20_70_dataset.csv : 2359476.4868942625 with standard deviation 7050172.042921902

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF 0-100 years: first run

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_0_100_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_0_100_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, significance=0.95)
#
#  Dataset:  EBT_0_100_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.491470
# Epoch    31: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 1, 0, 4]
# Validated causes:  [8]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.613383
# Epoch   170: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   181: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   200: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   211: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   222: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 8, 0, 6]
# Validated causes:  [5, 0]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.068679
# Epoch    86: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.002989
# Epoch  1420: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1431: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1443: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1465: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 4, 9]
# Validated causes:  [9]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.471824
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   993: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.002471
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 1]
# Validated causes:  [5]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.624121
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000074
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 0, 6]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.548282
# Epoch    64: reducing learning rate of group 0 to 1.0000e-02.
# INFO: Early stopping at epoch 500
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.730880
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.001111
# Epoch  1569: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1580: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1591: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1602: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 4]
# Validated causes:  [1, 4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.190895
# Epoch   123: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   902: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000481
# Epoch: 2000 [100%] 	Loss: 0.000143
# Potential causes:  [4, 3, 6, 2]
# Validated causes:  []
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.377966
# Epoch    48: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   380: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.267504
# Epoch    30: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   436: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.002750
# Epoch: 2000 [100%] 	Loss: 0.000386
# Potential causes:  [8, 6, 4]
# Validated causes:  [6, 4]
#
# ===================Results for EBT_0_100_dataset.csv ==================================
# Cb causes Rs with a delay of 48 time steps.
# Sb causes Rj with a delay of 62 time steps.
# Rs causes Rj with a delay of 45 time steps.
# Fc causes Ra with a delay of 59 time steps.
# Sb causes Sj with a delay of 2 time steps.
# Sb causes Sb with a delay of 51 time steps.
# Rj causes Cj with a delay of 4 time steps.
# Sa causes Cj with a delay of 8 time steps.
# Cb causes Cb with a delay of 1 time steps.
# Cj causes Fc with a delay of 59 time steps.
# Sa causes Fc with a delay of 8 time steps.
#
# ===================Evaluation for EBT_0_100_dataset.csv ===============================
# Total False Positives':  9
# Total True Positives':  2
# Total False Negatives:  14
# Total Direct False Positives:  11
# Total Direct True Positives:  0
# TPs':  [(0, 8), (2, 9)]
# FPs':  [(1, 5), (1, 0), (3, 5), (5, 5), (6, 1), (6, 4), (8, 8), (9, 6), (9, 4)]
# TPs direct:  []
# FPs direct:  [(0, 8), (1, 5), (1, 0), (2, 9), (3, 5), (5, 5), (6, 1), (6, 4), (8, 8), (9, 6), (9, 4)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.18181818181818182
# Recall':  0.125
# F1' score:  0.14814814814814814 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF 0-100 years: second run (1 extra hidden layer, different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_0_100_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 2000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_0_100_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, significance=0.95)
#
#  Dataset:  EBT_0_100_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.265422
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   477: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.005009
# Epoch: 2000 [100%] 	Loss: 0.001651
# Potential causes:  [2, 8]
# Validated causes:  [2, 8]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.346345
# Epoch   178: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000344
# Epoch  1420: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 7]
# Validated causes:  [5]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.613716
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   359: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   370: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 1000 [50%] 	Loss: 0.001872
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 7, 0]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.227712
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 5, 2, 6]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.354324
# Epoch   143: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000582
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 5, 7]
# Validated causes:  [8, 5, 7]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.279832
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   429: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000273
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 9]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.415329
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   952: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000800
# Epoch: 2000 [100%] 	Loss: 0.000632
# Potential causes:  [4, 0]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057617
# Epoch   200: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   211: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   222: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   233: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   244: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 2, 6]
# Validated causes:  [0]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.206956
# Epoch    88: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    99: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   110: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   121: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   132: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 6, 9]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.118390
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   113: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   124: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   135: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   146: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0, 6, 8]
# Validated causes:  [9, 6]
#
# ===================Results for EBT_0_100_dataset.csv ==================================
# Ra causes Rs with a delay of 225 time steps.
# Cb causes Rs with a delay of 250 time steps.
# Sb causes Rj with a delay of 62 time steps.
# Cb causes Sa with a delay of 250 time steps.
# Sb causes Sa with a delay of 14 time steps.
# Ca causes Sa with a delay of 204 time steps.
# Sb causes Sb with a delay of 63 time steps.
# Sa causes Cj with a delay of 253 time steps.
# Rs causes Ca with a delay of 13 time steps.
# Cb causes Cb with a delay of 59 time steps.
# Fc causes Fc with a delay of 237 time steps.
# Cj causes Fc with a delay of 187 time steps.
#
# ===================Evaluation for EBT_0_100_dataset.csv ===============================
# Total False Positives':  9
# Total True Positives':  3
# Total False Negatives:  12
# Total Direct False Positives:  10
# Total Direct True Positives:  2
# TPs':  [(0, 8), (4, 8), (4, 7)]
# FPs':  [(0, 2), (1, 5), (4, 5), (5, 5), (6, 4), (7, 0), (8, 8), (9, 9), (9, 6)]
# TPs direct:  [(4, 8), (4, 7)]
# FPs direct:  [(0, 2), (0, 8), (1, 5), (4, 5), (5, 5), (6, 4), (7, 0), (8, 8), (9, 9), (9, 6)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.25
# Recall':  0.2
# F1' score:  0.22222222222222224 (includes direct and indirect causal relationships)
# Precision:  0.16666666666666666
# Recall:  0.14285714285714285
# F1 score:  0.15384615384615383 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# ### TCDF with EBT equilibrium dynamics
#
# This data represents the tritrophic biomasses before the introduced fishing pressure on cod. The system first finds it equilibrium and remains stable for ~20 years. Therefore, no relations should be found by the machine learning model.
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints for each equilibrium state (i.e. between year 0 and 20 & 70 and 100)
first_eq_ebt = ebt[(ebt['Time (year)'] >= 0) & (ebt['Time (year)'] <= 20)]
second_eq_ebt = ebt[(ebt['Time (year)'] >= 70) & (ebt['Time (year)'] <= 100)]

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(first_eq_ebt[['Rs', 'Rj', 'Ra',
                                                  'Sj', 'Sa', 'Sb',
                                                  'Cj', 'Ca', 'Cb',
                                                  'Fc']])
ebt_scaled_2 = scaler.fit_transform(second_eq_ebt[['Rs', 'Rj', 'Ra',
                                                   'Sj', 'Sa', 'Sb',
                                                   'Cj', 'Ca', 'Cb',
                                                   'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))
# Out:
#             Rs        Rj        Ra        Sj        Sa        Sb        Cj  \
# 0     0.000000  0.131344  1.000000  1.000000  0.581963  1.000000  1.000000
# 1     0.001472  0.129474  0.999045  0.994492  0.580667  0.999367  0.999595
# 2     0.002950  0.127661  0.997911  0.988974  0.579345  0.998731  0.999181
# 3     0.004435  0.125893  0.996598  0.983445  0.578000  0.998092  0.998761
# 4     0.005927  0.124165  0.995130  0.977906  0.576631  0.997451  0.998333
# ...        ...       ...       ...       ...       ...       ...       ...
# 7286  0.975182  0.974437  0.140148  0.108347  0.980676  0.020865  0.023301
# 7287  0.975182  0.974437  0.140148  0.108346  0.980676  0.020865  0.023301
# 7288  0.975182  0.974437  0.140148  0.108346  0.980675  0.020865  0.023301
# 7289  0.975183  0.974437  0.140136  0.108345  0.980674  0.020865  0.023301
# 7290  0.975183  0.974437  0.140136  0.108345  0.980674  0.020865  0.023301
#
#             Ca        Cb   Fc
# 0     0.000000  0.000000  0.0
# 1     0.004732  0.000953  0.0
# 2     0.009430  0.001906  0.0
# 3     0.014094  0.002860  0.0
# 4     0.018724  0.003813  0.0
# ...        ...       ...  ...
# 7286  0.478209  0.986265  0.0
# 7287  0.478209  0.986265  0.0
# 7288  0.478210  0.986265  0.0
# 7289  0.478211  0.986265  0.0
# 7290  0.478211  0.986265  0.0
#
# [7291 rows x 10 columns]
#              Rs        Rj        Ra            Sj        Sa            Sb  \
# 0      0.000000  0.000000  0.000000  1.000000e+00  0.000000  1.000000e+00
# 1      0.000995  0.001330  0.000812  9.986979e-01  0.001290  9.987132e-01
# 2      0.001989  0.002659  0.000812  9.973975e-01  0.002579  9.974280e-01
# 3      0.002983  0.003986  0.001623  9.960987e-01  0.003867  9.961444e-01
# 4      0.003977  0.005311  0.002435  9.948016e-01  0.005152  9.948624e-01
# ...         ...       ...       ...           ...       ...           ...
# 10936  0.999885  1.000000  1.000000  1.019384e-07  1.000000  6.430193e-08
# 10937  0.999885  1.000000  1.000000  9.367312e-08  1.000000  5.964099e-08
# 10938  0.999885  1.000000  1.000000  8.540783e-08  1.000000  5.507518e-08
# 10939  0.999885  1.000000  1.000000  7.989766e-08  1.000000  5.041424e-08
# 10940  0.999885  1.000000  1.000000  7.163237e-08  1.000000  4.584842e-08
#
#                  Cj        Ca        Cb   Fc
# 0      1.000000e+00  1.000000  1.000000  0.0
# 1      9.986586e-01  0.999466  0.999572  0.0
# 2      9.973190e-01  0.998933  0.999143  0.0
# 3      9.959811e-01  0.998401  0.998715  0.0
# 4      9.946450e-01  0.997868  0.998287  0.0
# ...             ...       ...       ...  ...
# 10936  1.270168e-07  0.000022  0.000027  0.0
# 10937  1.179115e-07  0.000021  0.000025  0.0
# 10938  1.088099e-07  0.000019  0.000023  0.0
# 10939  9.971195e-08  0.000017  0.000021  0.0
# 10940  9.062131e-08  0.000016  0.000019  0.0
#
# [10941 rows x 10 columns]

# %%
# Visualize scaled data first equilibrium
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_1, [0,20])

# %%
# Visualize scaled data second equilibrium
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_2, [70,100])

# %%
# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_first_eq_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path, index = False)

# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_second_eq_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_2.to_csv(EBTScaled_path, index = False)

# %% [markdown]
# #### TCDF first equilibrium: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=4000, ground_truth={'data/EBT_first_eq_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, significance=0.9)
#
#  Dataset:  EBT_first_eq_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.295842
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 2]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.275175
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 2]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.167391
# Epoch    91: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   102: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   113: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   124: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   135: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 2]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.139135
# Epoch    46: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    79: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 4, 1]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.253684
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   509: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   520: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   531: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   542: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 5, 4]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.146586
# Epoch    23: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   902: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000030
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 0, 1, 4]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.137754
# Epoch   101: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   810: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000019
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 4, 0]
# Validated causes:  [5]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.635728
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 8, 4, 0]
# Validated causes:  []
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.261510
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 2]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.047210
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 1, 7, 5]
# Validated causes:  []
#
# ===================Results for EBT_first_eq_dataset.csv ==================================
# Ra causes Ra with a delay of 31 time steps.
# Sb causes Sb with a delay of 4 time steps.
# Sb causes Cj with a delay of 0 time steps.
#
# ===================Evaluation for EBT_first_eq_dataset.csv ===============================
# Total False Positives':  3
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  3
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(2, 2), (5, 5), (6, 5)]
# TPs direct:  []
# FPs direct:  [(2, 2), (5, 5), (6, 5)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_first_eq_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=4000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=37519, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.163000
# Epoch   185: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   196: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   207: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   218: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   229: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.122508
# Epoch   162: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   173: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   184: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   195: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   206: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.209044
# Epoch    84: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    95: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   106: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   117: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   128: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.173169
# Epoch    95: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   106: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   117: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   128: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   139: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.064174
# Epoch   166: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   177: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   188: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   199: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   210: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.238040
# Epoch   215: reducing learning rate of group 0 to 1.0000e-02.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.219095
# Epoch   162: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   173: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   184: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   195: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   206: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.785543
# Epoch    85: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   107: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   118: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   129: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.065903
# Epoch   112: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000887
# Epoch  1327: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 2000 [50%] 	Loss: 0.000087
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.047213
# Epoch    25: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_first_eq_dataset.csv : 4776.1088480126145 with standard deviation 5284.097315165489

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF first equilibrium: second run (different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=4000, ground_truth={'data/EBT_first_eq_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, significance=0.9)
#
#  Dataset:  EBT_first_eq_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.741566
# Epoch   109: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   120: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   131: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   142: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   153: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 5, 0]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.729700
# Epoch    23: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   428: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000954
# Epoch: 2000 [50%] 	Loss: 0.000731
# Epoch  2940: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 3000 [75%] 	Loss: 0.000235
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 0, 5]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.035095
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000138
# Epoch  1616: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 2000 [50%] 	Loss: 0.000031
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 7, 5, 9, 6]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.019897
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6, 2, 5, 3]
# Validated causes:  [2]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.714650
# Epoch    23: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.001407
# Epoch: 2000 [50%] 	Loss: 0.000509
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 3]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.044441
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    24: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 9, 6, 3]
# Validated causes:  [2]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.038891
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    24: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 9, 3, 6]
# Validated causes:  [2, 9, 6]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.276003
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   405: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000578
# Epoch: 2000 [50%] 	Loss: 0.000452
# Epoch: 3000 [75%] 	Loss: 0.000275
# Epoch  3425: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 2, 5, 3]
# Validated causes:  [2]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.720692
# Epoch    44: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000169
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 0]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.004148
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 5]
# Validated causes:  []
#
# ===================Results for EBT_first_eq_dataset.csv ==================================
# Ra causes Ra with a delay of 33 time steps.
# Ra causes Sj with a delay of 58 time steps.
# Ra causes Sb with a delay of 58 time steps.
# Ra causes Cj with a delay of 58 time steps.
# Fc causes Cj with a delay of 44 time steps.
# Cj causes Cj with a delay of 4 time steps.
# Ra causes Ca with a delay of 0 time steps.
#
# ===================Evaluation for EBT_first_eq_dataset.csv ===============================
# Total False Positives':  7
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  7
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(2, 2), (3, 2), (5, 2), (6, 2), (6, 9), (6, 6), (7, 2)]
# TPs direct:  []
# FPs direct:  [(2, 2), (3, 2), (5, 2), (6, 2), (6, 9), (6, 6), (7, 2)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_first_eq_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=4000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.648462
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.625375
# Epoch   115: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   126: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   158: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   169: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.064854
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000171
# Epoch: 2000 [50%] 	Loss: 0.000033
# Epoch  2017: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.037984
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [25%] 	Loss: 0.028613
# Epoch: 2000 [50%] 	Loss: 0.028397
# Epoch: 3000 [75%] 	Loss: 0.028216
# Epoch: 4000 [100%] 	Loss: 0.028090
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.583533
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   387: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000665
# Epoch: 2000 [50%] 	Loss: 0.000517
# Epoch: 3000 [75%] 	Loss: 0.000280
# Epoch  3742: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.086682
# Epoch   141: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   152: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   163: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   174: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   185: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.075830
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.007799
# Epoch: 2000 [50%] 	Loss: 0.003822
# Epoch: 3000 [75%] 	Loss: 0.000114
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.379433
# Epoch    74: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.003933
# Epoch: 2000 [50%] 	Loss: 0.002782
# Epoch: 3000 [75%] 	Loss: 0.001168
# Epoch: 4000 [100%] 	Loss: 0.000762
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.584952
# Epoch    62: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    99: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.004149
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_first_eq_dataset.csv : 4755.567061764012 with standard deviation 3135.8573401308645

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second equilibrium: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 34321 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=4000, ground_truth={'data/EBT_second_eq_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=34321, significance=0.9)
#
#  Dataset:  EBT_second_eq_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.778420
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.790172
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 6, 9]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.647151
# Epoch   100: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   111: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 6, 9, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.030120
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   317: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000055
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 4]
# Validated causes:  [1]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.788582
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   100: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   111: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 6, 9]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.030375
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000217
# Epoch: 2000 [50%] 	Loss: 0.000028
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 4]
# Validated causes:  [1]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.029475
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   341: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000039
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 4]
# Validated causes:  [1]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.068846
# Epoch    62: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    86: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000253
# Epoch: 2000 [50%] 	Loss: 0.000115
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.079010
# Epoch    48: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8]
# Validated causes:  [7]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.003534
# Epoch    70: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    91: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   102: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   113: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   124: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 7, 5, 0, 8]
# Validated causes:  []
#
# ===================Results for EBT_second_eq_dataset.csv ==================================
# Rj causes Sj with a delay of 60 time steps.
# Rj causes Sb with a delay of 60 time steps.
# Rj causes Cj with a delay of 60 time steps.
# Ca causes Ca with a delay of 4 time steps.
# Ca causes Cb with a delay of 3 time steps.
#
# ===================Evaluation for EBT_second_eq_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  5
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(3, 1), (5, 1), (6, 1), (7, 7), (8, 7)]
# TPs direct:  []
# FPs direct:  [(3, 1), (5, 1), (6, 1), (7, 7), (8, 7)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 34321 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_second_eq_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=4000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=34321, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.672349
# Epoch    43: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000311
# Epoch: 2000 [50%] 	Loss: 0.000134
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.696007
# Epoch    43: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.438263
# Epoch    43: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.002172
# Epoch: 2000 [50%] 	Loss: 0.000784
# Epoch: 3000 [75%] 	Loss: 0.000673
# Epoch: 4000 [100%] 	Loss: 0.000022
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.056727
# Epoch    68: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   477: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   492: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   515: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   526: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.692768
# Epoch    64: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    86: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057233
# Epoch    42: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.002120
# Epoch: 2000 [50%] 	Loss: 0.000044
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.055438
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.001518
# Epoch: 2000 [50%] 	Loss: 0.000049
# Epoch  2582: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.135508
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   509: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [25%] 	Loss: 0.000408
# Epoch: 2000 [50%] 	Loss: 0.000304
# Epoch: 3000 [75%] 	Loss: 0.000182
# Epoch  3155: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.156020
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.003532
# Epoch    59: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_second_eq_dataset.csv : 182102.25366695606 with standard deviation 269014.93484258914

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second equilibrium: second run (different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 1238 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=4000, ground_truth={'data/EBT_second_eq_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=1238, significance=0.9)
#
#  Dataset:  EBT_second_eq_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.286641
# Epoch   324: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   335: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   346: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   357: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   368: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.291193
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.223822
# Epoch   133: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   155: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   166: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   177: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.152993
# Epoch   155: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   166: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   177: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   188: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   199: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.290534
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.152941
# Epoch   127: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   138: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   149: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   160: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   171: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.153250
# Epoch   144: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   155: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   179: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   190: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   201: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.120079
# Epoch   120: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   131: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   152: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   163: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   174: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 1, 7, 8, 3]
# Validated causes:  [8]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.117668
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 1, 8, 5]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.176477
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6, 8, 3]
# Validated causes:  []
#
# ===================Results for EBT_second_eq_dataset.csv ==================================
# Sb causes Rs with a delay of 32 time steps.
# Sb causes Rj with a delay of 18 time steps.
# Sb causes Ra with a delay of 34 time steps.
# Sj causes Sj with a delay of 1 time steps.
# Sb causes Sa with a delay of 18 time steps.
# Sj causes Sb with a delay of 0 time steps.
# Sj causes Cj with a delay of 32 time steps.
# Cb causes Ca with a delay of 41 time steps.
# Cb causes Cb with a delay of 42 time steps.
#
# ===================Evaluation for EBT_second_eq_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  8
# Total Direct True Positives:  1
# TPs':  [(0, 5)]
# FPs':  [(1, 5), (2, 5), (3, 3), (4, 5), (5, 3), (6, 3), (7, 8), (8, 8)]
# TPs direct:  [(0, 5)]
# FPs direct:  [(1, 5), (2, 5), (3, 3), (4, 5), (5, 3), (6, 3), (7, 8), (8, 8)]
# FNs:  [(0, 3), (0, 4), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.1111111111111111
# Recall':  0.07142857142857142
# F1' score:  0.08695652173913043 (includes direct and indirect causal relationships)
# Precision:  0.1111111111111111
# Recall:  0.07142857142857142
# F1 score:  0.08695652173913043 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 1238 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_second_eq_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=4000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=1238, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.237060
# Epoch   387: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   398: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   409: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   420: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   431: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.246258
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000076
# Epoch  1811: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.128793
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000266
# Epoch  1483: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.129635
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000043
# Epoch  1490: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1501: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1521: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1532: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.244904
# Epoch   361: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   372: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   383: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   394: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   405: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.129512
# Epoch   297: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   308: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   319: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   330: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   341: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.130159
# Epoch    96: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [25%] 	Loss: 0.000023
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.075636
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.073267
# Epoch   177: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   188: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   199: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   210: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   221: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.176485
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_second_eq_dataset.csv : 25650.202239062673 with standard deviation 17298.370562304888

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# ### TCDF with EBT transient dynamics
#
# This data represents the tritrophic biomasses during the introduced fishing pressure on cod. At 20 years Fc increases and is put to a halt on 40 years. Therefore I split the transient dynamics into two separate transient phases: 20-40 years (fishing pressure increases linearly) and 40-70 years (searching for a new equilibrium).
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints for each transient state (i.e. between year 20 and 60 & 60 and 70)
first_trans_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 60)]
second_trans_ebt = ebt[(ebt['Time (year)'] >= 60) & (ebt['Time (year)'] <= 70)]

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(first_trans_ebt[['Rs', 'Rj', 'Ra',
                                                  'Sj', 'Sa', 'Sb',
                                                  'Cj', 'Ca', 'Cb',
                                                  'Fc']])
ebt_scaled_2 = scaler.fit_transform(second_trans_ebt[['Rs', 'Rj', 'Ra',
                                                   'Sj', 'Sa', 'Sb',
                                                   'Cj', 'Ca', 'Cb',
                                                   'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))
# Out:
#              Rs        Rj        Ra        Sj        Sa            Sb  \
# 0      1.000000  0.033376  0.646078  0.242979  0.000029  0.000000e+00
# 1      1.000000  0.033376  0.646078  0.242979  0.000029  6.783751e-11
# 2      1.000000  0.033376  0.646078  0.242979  0.000029  8.316388e-10
# 3      1.000000  0.033376  0.646079  0.242979  0.000029  2.994905e-09
# 4      1.000000  0.033376  0.646079  0.242979  0.000029  7.253600e-09
# ...         ...       ...       ...       ...       ...           ...
# 14586  0.000199  0.990540  0.999999  0.005217  0.992639  2.539723e-01
# 14587  0.000185  0.991214  0.999999  0.004844  0.993164  2.532034e-01
# 14588  0.000170  0.991888  0.999999  0.004471  0.993689  2.524342e-01
# 14589  0.000156  0.992562  0.999999  0.004098  0.994215  2.516648e-01
# 14590  0.000142  0.993237  1.000000  0.003725  0.994740  2.508950e-01
#
#              Cj            Ca            Cb        Fc
# 0      0.849141  2.027708e-01  1.000000e+00  0.000000
# 1      0.849141  2.027707e-01  9.999992e-01  0.000068
# 2      0.849141  2.027705e-01  9.999967e-01  0.000137
# 3      0.849141  2.027703e-01  9.999926e-01  0.000205
# 4      0.849141  2.027699e-01  9.999869e-01  0.000274
# ...         ...           ...           ...       ...
# 14586  0.004501  7.451691e-07  1.905467e-12  0.999110
# 14587  0.004179  6.870500e-07  1.758313e-12  0.999178
# 14588  0.003857  6.297251e-07  1.612938e-12  0.999247
# 14589  0.003534  5.731792e-07  1.469318e-12  0.999315
# 14590  0.003212  5.174076e-07  1.327437e-12  0.999384
#
# [14591 rows x 10 columns]
#             Rs        Rj        Ra        Sj        Sa        Sb        Cj  \
# 0     1.000000  0.000000  0.999206  1.000000  0.000000  1.000000  1.000000
# 1     0.997404  0.000770  1.000000  0.998947  0.000796  0.999293  0.999491
# 2     0.994830  0.001473  0.997617  0.997888  0.001592  0.998585  0.998982
# 3     0.992291  0.002119  0.992454  0.996824  0.002387  0.997878  0.998472
# 4     0.989796  0.002715  0.984512  0.995753  0.003181  0.997170  0.997961
# ...        ...       ...       ...       ...       ...       ...       ...
# 3636  0.005638  0.999563  0.942017  0.000308  0.999590  0.000440  0.000277
# 3637  0.005644  0.999595  0.942216  0.000286  0.999620  0.000408  0.000257
# 3638  0.005651  0.999626  0.942415  0.000264  0.999649  0.000376  0.000237
# 3639  0.005658  0.999658  0.942415  0.000242  0.999679  0.000345  0.000217
# 3640  0.005664  0.999689  0.942613  0.000220  0.999708  0.000313  0.000198
#
#             Ca        Cb   Fc
# 0     0.000000  0.000000  0.0
# 1     0.033854  0.000299  0.0
# 2     0.066969  0.000654  0.0
# 3     0.099327  0.001063  0.0
# 4     0.130918  0.001525  0.0
# ...        ...       ...  ...
# 3636  0.016949  0.522800  0.0
# 3637  0.016854  0.522577  0.0
# 3638  0.016758  0.522355  0.0
# 3639  0.016663  0.522132  0.0
# 3640  0.016568  0.521909  0.0
#
# [3641 rows x 10 columns]

# %%
# Visualize scaled data first transient
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_1, [20,60])

# %%
# Visualize scaled data second transient
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_2, [60,70])

# %%
# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_first_trans_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path, index = False)

# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_second_trans_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_2.to_csv(EBTScaled_path, index = False)

# %% [markdown]
# #### TCDF first transient: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_first_trans_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=24310, significance=0.9)
#
#  Dataset:  EBT_first_trans_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.175847
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   864: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.001302
# Epoch: 2000 [40%] 	Loss: 0.001149
# Epoch: 3000 [60%] 	Loss: 0.000983
# Epoch: 4000 [80%] 	Loss: 0.000491
# Epoch  4640: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 5000 [100%] 	Loss: 0.000270
# Potential causes:  [7, 2, 9]
# Validated causes:  [7, 9]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.045181
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 7]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.383610
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 1, 2, 3]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.335630
# Epoch   103: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   358: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.002183
# Epoch: 2000 [40%] 	Loss: 0.000239
# Epoch  2627: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 5]
# Validated causes:  [5]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.053093
# Epoch   100: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   111: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 2, 4]
# Validated causes:  [9, 4]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.384008
# Epoch    47: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    91: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 8]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.580326
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.054527
# Epoch: 2000 [40%] 	Loss: 0.054410
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 4, 2]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.107351
# Epoch   213: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   250: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [7]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.053216
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 0]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.256223
# Epoch   154: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   165: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   176: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   187: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   198: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 4, 9]
# Validated causes:  [9]
#
# ===================Results for EBT_first_trans_dataset.csv ==================================
# Ca causes Rs with a delay of 141 time steps.
# Fc causes Rs with a delay of 3 time steps.
# Sb causes Sj with a delay of 224 time steps.
# Fc causes Sa with a delay of 67 time steps.
# Sa causes Sa with a delay of 130 time steps.
# Ca causes Ca with a delay of 2 time steps.
# Fc causes Fc with a delay of 87 time steps.
#
# ===================Evaluation for EBT_first_trans_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  2
# Total False Negatives:  14
# Total Direct False Positives:  7
# Total Direct True Positives:  0
# TPs':  [(0, 7), (4, 9)]
# FPs':  [(0, 9), (3, 5), (4, 4), (7, 7), (9, 9)]
# TPs direct:  []
# FPs direct:  [(0, 7), (0, 9), (3, 5), (4, 9), (4, 4), (7, 7), (9, 9)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.2857142857142857
# Recall':  0.125
# F1' score:  0.17391304347826086 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_trans_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_first_trans_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=24310, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.343798
# Epoch    69: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   623: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000480
# Epoch: 2000 [40%] 	Loss: 0.000314
# Epoch: 3000 [60%] 	Loss: 0.000189
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.001896
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    33: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    44: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    55: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    66: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.164969
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.322244
# Epoch    95: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   106: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   117: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   128: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   139: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.002645
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.134670
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.729355
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.192423
# Epoch    82: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   683: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.009403
# Epoch: 2000 [40%] 	Loss: 0.009141
# Epoch: 3000 [60%] 	Loss: 0.000929
# Epoch  3649: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.099362
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.048337
# Epoch    52: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_first_trans_dataset.csv : 241903.46729436034 with standard deviation 715427.9563609598

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF first transient: second run (1 less hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_first_trans_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=24310, significance=0.9)
#
#  Dataset:  EBT_first_trans_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.298889
# Epoch   122: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000101
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 0]
# Validated causes:  [0]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.107679
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   300: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.002700
# Epoch: 2000 [40%] 	Loss: 0.000959
# Epoch  2254: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 0]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.602312
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   674: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   703: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   724: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   735: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 2, 0]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.542336
# Epoch    48: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000278
# Epoch  1018: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 5]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.116861
# Epoch    97: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   141: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 0, 9, 8, 1]
# Validated causes:  [2]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.589742
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 1]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.851573
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 1, 8]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.215256
# Epoch    40: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    89: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   100: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1, 7, 9, 0]
# Validated causes:  [2]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.088472
# Epoch    87: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   109: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   120: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   131: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.423802
# Epoch   162: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   173: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   191: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   202: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   213: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0, 1]
# Validated causes:  [9]
#
# ===================Results for EBT_first_trans_dataset.csv ==================================
# Rs causes Rs with a delay of 6 time steps.
# Ra causes Sa with a delay of 57 time steps.
# Ra causes Ca with a delay of 57 time steps.
# Fc causes Fc with a delay of 36 time steps.
#
# ===================Evaluation for EBT_first_trans_dataset.csv ===============================
# Total False Positives':  4
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  4
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(0, 0), (4, 2), (7, 2), (9, 9)]
# TPs direct:  []
# FPs direct:  [(0, 0), (4, 2), (7, 2), (9, 9)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF first transient: third run (1 more hidden layer, different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 568943 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_first_trans_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=568943, significance=0.9)
#
#  Dataset:  EBT_first_trans_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.103654
# Epoch   143: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   154: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   176: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   187: reducing learning rate of group 0 to 1.0000e-05.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 9, 5, 8]
# Validated causes:  [4, 9]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.043175
# Epoch    47: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 9]
# Validated causes:  [4]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.200382
# Epoch   113: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   124: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   135: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   146: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   157: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.166227
# Epoch   138: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   587: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.001283
# Epoch: 2000 [40%] 	Loss: 0.001027
# Epoch: 3000 [60%] 	Loss: 0.000873
# Epoch: 4000 [80%] 	Loss: 0.000693
# Epoch: 5000 [100%] 	Loss: 0.000325
# Potential causes:  [4, 7, 0]
# Validated causes:  [4, 0]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.049610
# Epoch    60: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    77: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    88: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    99: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   110: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 9]
# Validated causes:  [4]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.215723
# Epoch   109: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   639: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000243
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 2]
# Validated causes:  [0]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.336086
# Epoch    31: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 4]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.052622
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000168
# Epoch  1317: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1328: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1349: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1360: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  [4]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.082899
# Epoch    87: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   109: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   120: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   131: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.132254
# Epoch    63: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   101: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   112: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   123: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 2, 0]
# Validated causes:  [0]
#
# ===================Results for EBT_first_trans_dataset.csv ==================================
# Sa causes Rs with a delay of 131 time steps.
# Fc causes Rs with a delay of 97 time steps.
# Sa causes Rj with a delay of 67 time steps.
# Ra causes Ra with a delay of 9 time steps.
# Sa causes Sj with a delay of 0 time steps.
# Rs causes Sj with a delay of 96 time steps.
# Sa causes Sa with a delay of 132 time steps.
# Rs causes Sb with a delay of 79 time steps.
# Sa causes Ca with a delay of 16 time steps.
# Cb causes Cb with a delay of 256 time steps.
# Rs causes Fc with a delay of 111 time steps.
#
# ===================Evaluation for EBT_first_trans_dataset.csv ===============================
# Total False Positives':  10
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  10
# Total Direct True Positives:  1
# TPs':  [(0, 4)]
# FPs':  [(0, 9), (1, 4), (2, 2), (3, 4), (3, 0), (4, 4), (5, 0), (7, 4), (8, 8), (9, 0)]
# TPs direct:  [(0, 4)]
# FPs direct:  [(0, 9), (1, 4), (2, 2), (3, 4), (3, 0), (4, 4), (5, 0), (7, 4), (8, 8), (9, 0)]
# FNs:  [(0, 3), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.09090909090909091
# Recall':  0.07142857142857142
# F1' score:  0.08 (includes direct and indirect causal relationships)
# Precision:  0.09090909090909091
# Recall:  0.07142857142857142
# F1 score:  0.08 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF second transient: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_second_trans_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=2369, significance=0.9)
#
#  Dataset:  EBT_second_trans_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.134290
# Epoch   784: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   795: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   815: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   826: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   837: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.000044
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 7, 8]
# Validated causes:  [5]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.605316
# Epoch    48: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000217
# Epoch: 2000 [40%] 	Loss: 0.000040
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [2]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.431330
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   890: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   901: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   922: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   933: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.000089
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 2]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.160480
# Epoch   100: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   111: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 1, 6, 5, 9]
# Validated causes:  [7]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.643293
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   827: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000077
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.199587
# Epoch    81: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000102
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 1]
# Validated causes:  [3]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.183614
# Epoch   127: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   138: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   149: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   160: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   171: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 1, 6, 9, 5]
# Validated causes:  [7]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.258137
# Epoch    46: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000644
# Epoch: 2000 [40%] 	Loss: 0.000176
# Epoch  2786: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 3000 [60%] 	Loss: 0.000095
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 1]
# Validated causes:  [5]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.690886
# Epoch   165: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000101
# Epoch  1798: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1809: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1829: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1840: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 7, 8]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.001711
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 5, 9]
# Validated causes:  [1, 5, 9]
#
# ===================Results for EBT_second_trans_dataset.csv ==================================
# Sb causes Rs with a delay of 177 time steps.
# Ra causes Rj with a delay of 33 time steps.
# Ra causes Ra with a delay of 162 time steps.
# Ca causes Sj with a delay of 173 time steps.
# Sj causes Sb with a delay of 194 time steps.
# Ca causes Cj with a delay of 173 time steps.
# Sb causes Ca with a delay of 193 time steps.
# Rj causes Fc with a delay of 248 time steps.
# Sb causes Fc with a delay of 225 time steps.
# Fc causes Fc with a delay of 225 time steps.
#
# ===================Evaluation for EBT_second_trans_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  2
# Total False Negatives:  12
# Total Direct False Positives:  8
# Total Direct True Positives:  2
# TPs':  [(0, 5), (3, 7)]
# FPs':  [(1, 2), (2, 2), (5, 3), (6, 7), (7, 5), (9, 1), (9, 5), (9, 9)]
# TPs direct:  [(0, 5), (3, 7)]
# FPs direct:  [(1, 2), (2, 2), (5, 3), (6, 7), (7, 5), (9, 1), (9, 5), (9, 9)]
# FNs:  [(0, 3), (0, 4), (1, 6), (2, 8), (3, 6), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.2
# Recall':  0.14285714285714285
# F1' score:  0.16666666666666666 (includes direct and indirect causal relationships)
# Precision:  0.2
# Recall:  0.14285714285714285
# F1 score:  0.16666666666666666 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_trans_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_second_trans_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=2369, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.266462
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   107: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   118: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.264974
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   725: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   750: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   761: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   775: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.000087
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.158402
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.311220
# Epoch   134: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000034
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.325931
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.384549
# Epoch    62: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000061
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.357831
# Epoch    80: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    91: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   102: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   113: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   124: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.476981
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   748: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000311
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.749990
# Epoch   130: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   165: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   186: reducing learning rate of group 0 to 1.0000e-04.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.001703
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    30: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_second_trans_dataset.csv : 3257.7212261584064 with standard deviation 3373.9650759367255

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second transient: second run (1 less hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/EBT_second_trans_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=2369, significance=0.95)
#
#  Dataset:  EBT_second_trans_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.090089
# Epoch    90: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000049
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 2]
# Validated causes:  [7]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.241913
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 0, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.148329
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 0]
# Validated causes:  [3]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.072964
# Epoch    64: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    86: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 7, 2]
# Validated causes:  [7]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.255081
# Epoch    40: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000630
# Epoch: 2000 [40%] 	Loss: 0.000322
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 9, 7, 2, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.083171
# Epoch   114: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   158: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 4, 9, 5]
# Validated causes:  [3]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.085302
# Epoch   160: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   171: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   182: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   193: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   204: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 2, 4]
# Validated causes:  [7]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.090177
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000165
# Epoch: 2000 [40%] 	Loss: 0.000092
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 4, 8]
# Validated causes:  [3]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.268311
# Epoch    39: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    83: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 3]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.084932
# Epoch    50: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6, 7, 3, 0]
# Validated causes:  []
#
# ===================Results for EBT_second_trans_dataset.csv ==================================
# Ca causes Rs with a delay of 34 time steps.
# Sj causes Rj with a delay of 42 time steps.
# Sj causes Ra with a delay of 46 time steps.
# Ca causes Sj with a delay of 50 time steps.
# Sj causes Sa with a delay of 34 time steps.
# Sj causes Sb with a delay of 34 time steps.
# Ca causes Cj with a delay of 18 time steps.
# Sj causes Ca with a delay of 18 time steps.
# Cb causes Cb with a delay of 30 time steps.
#
# ===================Evaluation for EBT_second_trans_dataset.csv ===============================
# Total False Positives':  7
# Total True Positives':  2
# Total False Negatives:  13
# Total Direct False Positives:  8
# Total Direct True Positives:  1
# TPs':  [(0, 7), (3, 7)]
# FPs':  [(1, 3), (2, 3), (4, 3), (5, 3), (6, 7), (7, 3), (8, 8)]
# TPs direct:  [(3, 7)]
# FPs direct:  [(0, 7), (1, 3), (2, 3), (4, 3), (5, 3), (6, 7), (7, 3), (8, 8)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.2222222222222222
# Recall':  0.13333333333333333
# F1' score:  0.16666666666666669 (includes direct and indirect causal relationships)
# Precision:  0.1111111111111111
# Recall:  0.07142857142857142
# F1 score:  0.08695652173913043 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_trans_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_second_trans_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=5000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=2369, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.098052
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000368
# Epoch  1100: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.073594
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   614: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   634: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   645: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   669: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.000192
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.036271
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   500: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.000138
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.085388
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000040
# Epoch  1194: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1205: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1226: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1237: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.090357
# Epoch   128: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [20%] 	Loss: 0.000161
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.112875
# Epoch   157: reducing learning rate of group 0 to 1.0000e-02.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.109258
# Epoch   159: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   183: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   203: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   214: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   225: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.149983
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.316028
# Epoch   100: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   111: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   122: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   133: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   144: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.084937
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_second_trans_dataset.csv : 1189.601389038553 with standard deviation 735.64316034759

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# ## Adding white noise (Additive White Gaussian Noise)
#
# Training the model with additive noise might be helpful in avoiding overfitting of the model. Data in this section is augmented by adding noise with additive white Gaussian noise.

# %%
# Out:
#        Time (day)  Time (year)         Rs        Rj        Ra        Sj  \
# 0             0.0     0.000000  54.821297  0.268207  0.989287  8.511213
# 1             1.0     0.002740  54.821323  0.268207  0.989287  8.511207
# 2             2.0     0.005479  54.821349  0.268207  0.989287  8.511201
# 3             3.0     0.008219  54.821374  0.268207  0.989287  8.511194
# 4             4.0     0.010959  54.821401  0.268207  0.989287  8.511188
# ...           ...          ...        ...       ...       ...       ...
# 36496     36496.0    99.989041   6.255985  0.750000  1.000000  4.823965
# 36497     36497.0    99.991781   6.255985  0.750000  1.000000  4.823965
# 36498     36498.0    99.994521   6.255985  0.750000  1.000000  4.823965
# 36499     36499.0    99.997260   6.255985  0.750000  1.000000  4.823965
# 36500     36500.0   100.000000   6.255985  0.750000  1.000000  4.823965
#
#                Sa         Sb            Cj            Ca  ...  ΔCb + Fc  \
# 0        9.955314  50.033894  8.186889e+00  8.092280e-01  ...       0.0
# 1        9.955310  50.033881  8.186888e+00  8.092297e-01  ...       0.0
# 2        9.955306  50.033867  8.186887e+00  8.092314e-01  ...       0.0
# 3        9.955302  50.033854  8.186887e+00  8.092331e-01  ...       0.0
# 4        9.955297  50.033840  8.186886e+00  8.092347e-01  ...       0.0
# ...           ...        ...           ...           ...  ...       ...
# 36496  139.763065  15.147868  4.515074e-07  4.434723e-08  ...       0.0
# 36497  139.763065  15.147868  4.512597e-07  4.432364e-08  ...       0.0
# 36498  139.763065  15.147868  4.510121e-07  4.430006e-08  ...       0.0
# 36499  139.763065  15.147868  4.507647e-07  4.427649e-08  ...       0.0
# 36500  139.763065  15.147868  4.505174e-07  4.425294e-08  ...       0.0
#
#        ΔC + Fc        ΔSb        ΔSj        ΔSa           ΔCb       ΔCj  \
# 0          0.0  56.602835  22.673092  25.988747  8.307395e-01  0.149208
# 1          0.0  56.602823  22.673058  25.988736  8.307407e-01  0.149204
# 2          0.0  56.602811  22.673023  25.988726  8.307419e-01  0.149200
# 3          0.0  56.602799  22.672989  25.988715  8.307431e-01  0.149195
# 4          0.0  56.602787  22.672955  25.988704  8.307443e-01  0.149191
# ...        ...        ...        ...        ...           ...       ...
# 36496      0.0   2.754238  49.397500   5.528970  1.332750e-07  0.000000
# 36497      0.0   2.754238  49.397500   5.528970  1.332041e-07  0.000000
# 36498      0.0   2.754238  49.397500   5.528970  1.331333e-07  0.000000
# 36499      0.0   2.754238  49.397500   5.528970  1.330626e-07  0.000000
# 36500      0.0   2.754238  49.397500   5.528970  1.329918e-07  0.000000
#
#                 ΔCa            ΣC   Fs
# 0      3.078741e-01  9.838410e+00  0.0
# 1      3.078747e-01  9.838412e+00  0.0
# 2      3.078752e-01  9.838414e+00  0.0
# 3      3.078758e-01  9.838416e+00  0.0
# 4      3.078764e-01  9.838418e+00  0.0
# ...             ...           ...  ...
# 36496  2.250507e-08  6.275009e-07  0.0
# 36497  2.249309e-08  6.271597e-07  0.0
# 36498  2.248113e-08  6.268186e-07  0.0
# 36499  2.246917e-08  6.264777e-07  0.0
# 36500  2.245721e-08  6.261370e-07  0.0
#
# [36501 rows x 24 columns]

# %%
# Adding noise using target SNR

# Set a target SNR
target_snr = 0.001
# Calculate signal power and convert to dB 
average_ca = np.mean(ebt['Ca'])

# Calculate noise according to [2] then convert to watts
noise = abs(average_ca - target_snr)

# Generate an sample of white noise
mean_noise = 0
noise_volts = np.random.normal(mean_noise, np.sqrt(noise), len(ebt['Ca']))
# Noise up the original signal
ca_noise = ebt['Ca'] + noise_volts

plt.plot(np.arange(len(ca_noise)), ca_noise)
plt.plot(np.arange(len(ebt['Ca'])), ebt['Ca'])
ca_noise
# Out:
# 0        0.550554
# 1        2.120715
# 2        0.505832
# 3        0.954307
# 4        0.803839
#            ...
# 36496    0.088693
# 36497   -0.772581
# 36498    0.484205
# 36499    0.346887
# 36500    0.113177
# Name: Ca, Length: 36501, dtype: float64
