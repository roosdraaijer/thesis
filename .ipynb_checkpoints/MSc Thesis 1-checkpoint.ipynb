# %% [markdown]
# # Ecological models: relevant?
# ## NIOZ Master Thesis Project
#
# This Jupyter Notebook contains a detailed description and workflow to train two machine learning models for my thesis. Every section is denoted with a second level heading to keep track of my experiments. First the data from the EBT Tool is imported - a deterministic population model resembling a tri-trophic system in the Baltic Sea (Van Leeuwen et al., 2008). This data is used to train two machine learning models (TCDF and PCMCI respectively) to infer (ecological) causal relations. Both are convolutional machine learning models, and able to handle non-stationary temporal data.
#
# Author: R. Draaijer

# %% [markdown]
# ## Enabling notebook to be run on any device

# %%
import os

# Create universally (i.e. across various operating systems) recognized paths

notebook_path = os.path.abspath('MSc Thesis 1.ipynb')                  # Jupyter notebook path
TCDF_path = os.path.join(os.path.dirname(notebook_path), 'TCDF')       # TCDF folder path
TCDFdata_path = os.path.join(TCDF_path, 'data')                        # TCDF/data folder path
EBT_path = os.path.join(os.path.dirname(notebook_path), 'EBT Data')    # EBT folder path
DefaultCod_path = os.path.join(EBT_path, 'Modified Default Cod')       # EBT/Modified Default Cod folder path
Cod_path = os.path.join(DefaultCod_path, 'Modified Default.out')       # EBT/Modified Default Cod/Modified Default.out file path

# %% [markdown]
# ## EBT Tool

# %% [markdown]
# ### Import EBT Tool Data with NumPy
# Two different datasets can be distinguished: Default Cod and Cannibalistic Cod. See paper (2008) and EBT Tutorial (2020) by Anieke van Leeuwen et al.
#
# *Note that objects with uppercase namespaces are solely used for raw data files

# %%
# Get path for EBT data (.txt file)
path = Cod_path

# Check first entries of data
with open(path) as Default_Cod:
    print(Default_Cod.readline())

# %%
# Convert dataset to ndarray
import numpy as np

with open(path) as Default_Cod:
    default_cod = np.loadtxt(Default_Cod)

# Check (dimensions of) array
print(default_cod) 
print(default_cod.shape)           # Must be identical to ('Maximum integration time' + 1, OUTPUT_VAR_NR + 1) in EBT tool
print(default_cod.dtype)           # Should be float64
# Out:
# [[0.00000000e+00 0.00000000e+00 5.48212970e+01 ... 3.07874116e-01
#   9.83841000e+00 0.00000000e+00]
#  [1.00000000e+00 2.73972600e-03 5.48213227e+01 ... 3.07874682e-01
#   9.83841208e+00 0.00000000e+00]
#  [2.00000000e+00 5.47945210e-03 5.48213485e+01 ... 3.07875243e-01
#   9.83841413e+00 0.00000000e+00]
#  ...
#  [3.64980000e+04 9.99945205e+01 6.25598481e+00 ... 2.24811300e-08
#   6.26818600e-07 0.00000000e+00]
#  [3.64990000e+04 9.99972603e+01 6.25598481e+00 ... 2.24691700e-08
#   6.26477700e-07 0.00000000e+00]
#  [3.65000000e+04 1.00000000e+02 6.25598481e+00 ... 2.24572100e-08
#   6.26137000e-07 0.00000000e+00]]
# (36501, 24)
# float64

# %% [markdown]
# In hindsight the library pandas can be highly useful for loading data, therefore:
#
# ### Import EBT Tool Data with pandas
# Two different datasets can be distinguished: Default Cod and Cannibalistic Cod. See paper (2008) and EBT Tutorial (2020) by Anieke van Leeuwen et al.
#
# *Note that objects with uppercase namespaces are solely used for raw data files*

# %%
import pandas as pd

# Get path for EBT data (.txt file)
path = Cod_path

# Define column names (see EBT .c file in output variables section) for multilevel indexing
variables = ['Time', 'Years', 'RS', 'RJ', 'RA', 'SJ', 'SA', 'SB', 'CJ', 'CA', 'CB', 'Fc', 'ΔCJ with Fc', 'ΔCS with Fc',
             'ΔCA with Fc', 'ΔC with Fc', 'ΔSB', 'ΔSJ', 'ΔSA', 'ΔCB', 'ΔCJ', 'ΔCA', 'ΣC', 'Fs']
units = ['[day]', '[year]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]', '[g V-1]',
         '[g V-1]', '[-]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]',
         '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1 year-1]', '[g V-1]', '[-]']

with open(path) as Default_Cod:
    default_cod = pd.read_csv(Default_Cod, delimiter = '\t', header=None)

# Set column names and index
#columns = pd.MultiIndex.set_codes([[variables, units]], names = ['Output variable', 'Unit'])
default_cod.columns = variables
#default_cod.columns = columns
default_cod = default_cod.set_index('Time')

# Check (dimensions of) array
print(default_cod.shape)           # Must be identical to ('Maximum integration time' + 1, OUTPUT_VAR_NR + 1) in EBT tool

default_cod.head()
# Out:
# (36501, 23)
#          Years         RS        RJ        RA        SJ        SA         SB  \
# Time
# 0.0   0.000000  54.821297  0.268207  0.989287  8.511213  9.955314  50.033894
# 1.0   0.002740  54.821323  0.268207  0.989287  8.511207  9.955310  50.033881
# 2.0   0.005479  54.821349  0.268207  0.989287  8.511201  9.955306  50.033867
# 3.0   0.008219  54.821374  0.268207  0.989287  8.511194  9.955302  50.033854
# 4.0   0.010959  54.821401  0.268207  0.989287  8.511188  9.955297  50.033840
#
#             CJ        CA        CB  ...  ΔCA with Fc  ΔC with Fc        ΔSB  \
# Time                                ...
# 0.0   8.186889  0.809228  0.842293  ...          0.0         0.0  56.602835
# 1.0   8.186888  0.809230  0.842294  ...          0.0         0.0  56.602823
# 2.0   8.186887  0.809231  0.842295  ...          0.0         0.0  56.602811
# 3.0   8.186887  0.809233  0.842297  ...          0.0         0.0  56.602799
# 4.0   8.186886  0.809235  0.842298  ...          0.0         0.0  56.602787
#
#             ΔSJ        ΔSA       ΔCB       ΔCJ       ΔCA        ΣC   Fs
# Time
# 0.0   22.673092  25.988747  0.830739  0.149208  0.307874  9.838410  0.0
# 1.0   22.673058  25.988736  0.830741  0.149204  0.307875  9.838412  0.0
# 2.0   22.673023  25.988726  0.830742  0.149200  0.307875  9.838414  0.0
# 3.0   22.672989  25.988715  0.830743  0.149195  0.307876  9.838416  0.0
# 4.0   22.672955  25.988704  0.830744  0.149191  0.307876  9.838418  0.0
#
# [5 rows x 23 columns]

# %%
# Visualize default_cod as is visualized by the EBT tool
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Make figure to visualize plots in
fig, axes = plt.subplots(2, 1, sharex=True)
plt.subplots_adjust(hspace=0)

# Select the biomass columns
# Cod biomass
cod_fig = fig.add_subplot(axes[0])
cod_fig.plot(default_cod['Years'], default_cod[['CJ','CA','CB']])

cod_fig.set_xticks(np.arange(0,110,20))
cod_fig.set_yticks(np.arange(0,12,2))


# Sprat biomass
sprat_fig = fig.add_subplot(axes[1])
sprat_fig.plot(default_cod['Years'], default_cod[['SJ','SA','SB']])

cod_fig.set_xticks(np.arange(0,110,20))
cod_fig.set_yticks(np.arange(0,12,2))
sprat_fig.set_xlabel('Time [year]')
# Out:
# Text(0.5, 0, 'Time [year]')

# %% [markdown]
# ## TCDF Demo
#
# This is a short demo for the first machine learning model, to get familiar with the training and testing of data.

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# Load data from EBT tool into DataFrame
path = Cod_path
ebt = pd.read_csv(path, delimiter = '\t', header = None)

# Show first 10 rows of dataset
ebt.head(10)
# Out:
#     0         1          2         3         4         5         6   \
# 0  0.0  0.000000  54.821297  0.268207  0.989287  8.511213  9.955314
# 1  1.0  0.002740  54.821323  0.268207  0.989287  8.511207  9.955310
# 2  2.0  0.005479  54.821349  0.268207  0.989287  8.511201  9.955306
# 3  3.0  0.008219  54.821374  0.268207  0.989287  8.511194  9.955302
# 4  4.0  0.010959  54.821401  0.268207  0.989287  8.511188  9.955297
# 5  5.0  0.013699  54.821427  0.268207  0.989287  8.511182  9.955293
# 6  6.0  0.016438  54.821453  0.268207  0.989287  8.511175  9.955289
# 7  7.0  0.019178  54.821479  0.268207  0.989287  8.511169  9.955284
# 8  8.0  0.021918  54.821506  0.268206  0.989287  8.511163  9.955279
# 9  9.0  0.024658  54.821533  0.268206  0.989287  8.511157  9.955275
#
#           7         8         9   ...   14   15         16         17  \
# 0  50.033894  8.186889  0.809228  ...  0.0  0.0  56.602835  22.673092
# 1  50.033881  8.186888  0.809230  ...  0.0  0.0  56.602823  22.673058
# 2  50.033867  8.186887  0.809231  ...  0.0  0.0  56.602811  22.673023
# 3  50.033854  8.186887  0.809233  ...  0.0  0.0  56.602799  22.672989
# 4  50.033840  8.186886  0.809235  ...  0.0  0.0  56.602787  22.672955
# 5  50.033827  8.186885  0.809236  ...  0.0  0.0  56.602775  22.672921
# 6  50.033813  8.186884  0.809238  ...  0.0  0.0  56.602763  22.672887
# 7  50.033799  8.186883  0.809240  ...  0.0  0.0  56.602751  22.672853
# 8  50.033786  8.186882  0.809241  ...  0.0  0.0  56.602739  22.672819
# 9  50.033772  8.186881  0.809243  ...  0.0  0.0  56.602727  22.672785
#
#           18        19        20        21        22   23
# 0  25.988747  0.830739  0.149208  0.307874  9.838410  0.0
# 1  25.988736  0.830741  0.149204  0.307875  9.838412  0.0
# 2  25.988726  0.830742  0.149200  0.307875  9.838414  0.0
# 3  25.988715  0.830743  0.149195  0.307876  9.838416  0.0
# 4  25.988704  0.830744  0.149191  0.307876  9.838418  0.0
# 5  25.988692  0.830745  0.149187  0.307877  9.838420  0.0
# 6  25.988681  0.830747  0.149183  0.307877  9.838422  0.0
# 7  25.988669  0.830748  0.149179  0.307878  9.838424  0.0
# 8  25.988657  0.830749  0.149175  0.307879  9.838426  0.0
# 9  25.988645  0.830750  0.149171  0.307879  9.838428  0.0
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Rename columns (see file /Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/Explanation Output Parameters.docx)
labels = ['Time (day)', 'Time (year)',                    # Time labels
          'Rs', 'Rj', 'Ra',                               # Shared resources biomass
          'Sj', 'Sa', 'Sb',                               # Sprat stages biomass
          'Cj', 'Ca', 'Cb',                               # Cod stages biomass
          'Fc',                                           # Fishing imposed on cod
          'ΔCj + Fc', 'ΔCa + Fc', 'ΔCb + Fc', 'ΔC + Fc', # Changes in cod biomass when fishing present
          'ΔSb', 'ΔSj', 'ΔSa',                           # Changes in sprat biomass
          'ΔCb', 'ΔCj', 'ΔCa',                           # Changes in cod biomass
          'ΣC',                                           # Sum of cod biomass
          'Fs']                                           # Fishing imposed on sprat
ebt.columns = labels

# Show new column labels
print(ebt.columns)
# Out:
# Index(['Time (day)', 'Time (year)', 'Rs', 'Rj', 'Ra', 'Sj', 'Sa', 'Sb', 'Cj',
#        'Ca', 'Cb', 'Fc', 'ΔCj + Fc', 'ΔCa + Fc', 'ΔCb + Fc', 'ΔC + Fc', 'ΔSb',
#        'ΔSj', 'ΔSa', 'ΔCb', 'ΔCj', 'ΔCa', 'ΣC', 'Fs'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = ebt[['Cj', 'Ca', 'Cb']]
sprat = ebt[['Sj', 'Sa', 'Sb']]
time = ebt['Time (year)']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center right')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center right')

# Draw vertical line at 20 years and 30 years to visualize data selection
cod_plt.plot([20] * 10, np.arange(0,10), '--k')
sprat_plt.plot([20] * 150, np.arange(0,150), '--k')

cod_plt.plot([30] * 10, np.arange(0,10), '--k')
sprat_plt.plot([30] * 150, np.arange(0,150), '--k')

# %% [markdown]
# In the above figure dashed lines represent the data I have selected to carry out a demo of the TCDF machine learning model. For the purpose of this demo I have aditionally selected a low resolution of 30 day timesteps over 100 years. Next I will clean the data for this demo purpose too, with the following characteristics:
# > - Data between year 20 and 30 (i.e. 120 datapoints)
# > - Inclusion of the columns representing sprat- and cod stages
# > - Inclusion of the shared resources columns
#
# The data needs to be converted into a .csv file with every column representative of a (continuous) timeseries and the header needs explanatory column names (for eventually we will create a temporal causal graph with each node representing a timeseries).

# %%
# Select information of datapoints between year 20 and 30
demo_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 30)]

# Select only the necessary biomass columns as timeseries
demo_ebt = demo_ebt[['Rs', 'Rj', 'Ra',
                     'Sj', 'Sa', 'Sb',
                     'Cj', 'Ca', 'Cb',
                     'Fc']]

# Reset index
demo_ebt.reset_index(inplace = True)
demo_ebt.drop('index', axis = 'columns', inplace = True)

# Show first and last five columns of clean dataframe
demo_ebt.head(-5)
# Out:
#              Rs        Rj        Ra         Sj         Sa         Sb  \
# 0     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 1     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 2     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 3     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# 4     54.838332  0.268238  0.989280   8.510205   9.956561  50.013244
# ...         ...       ...       ...        ...        ...        ...
# 3641  25.940005  0.290546  0.969713  11.992235  20.165629  69.478724
# 3642  25.957505  0.290461  0.969712  11.986605  20.150119  69.483323
# 3643  25.975086  0.290377  0.969711  11.980978  20.134557  69.487854
# 3644  25.992747  0.290292  0.969711  11.975354  20.118942  69.492318
# 3645  26.010489  0.290208  0.969711  11.969734  20.103275  69.496714
#
#             Cj        Ca        Cb        Fc
# 0     8.184919  0.809400  0.843533  0.000000
# 1     8.184919  0.809399  0.843532  0.001027
# 2     8.184919  0.809399  0.843530  0.002055
# 3     8.184918  0.809398  0.843527  0.003082
# 4     8.184917  0.809396  0.843522  0.004110
# ...        ...       ...       ...       ...
# 3641  8.987906  3.973822  0.076795  3.740753
# 3642  8.989210  3.972971  0.076769  3.741781
# 3643  8.990512  3.972101  0.076743  3.742808
# 3644  8.991813  3.971212  0.076716  3.743836
# 3645  8.993112  3.970304  0.076689  3.744863
#
# [3646 rows x 10 columns]

# %% [markdown]
# ### Low Resolution Dataset
# Run these cells when performing machine learning model with low res dataset

# %%
# Compress dataset to lower resolution (~365 datapoints)
low_demo_ebt = demo_ebt.iloc[::10, :]
low_demo_ebt.reset_index(drop = True, inplace = True)
low_demo_ebt['Time'] = np.linspace(20, 30, 366)

# Check format of low resolution dataset
low_demo_ebt
# Out:
#             Rs        Rj        Ra         Sj         Sa         Sb        Cj  \
# 0    54.838332  0.268238  0.989280   8.510205   9.956561  50.013244  8.184919
# 1    54.838330  0.268238  0.989280   8.510207   9.956563  50.013248  8.184903
# 2    54.838303  0.268239  0.989280   8.510224   9.956576  50.013281  8.184851
# 3    54.838202  0.268241  0.989282   8.510272   9.956614  50.013370  8.184762
# 4    54.837966  0.268244  0.989284   8.510369   9.956694  50.013544  8.184634
# ..         ...       ...       ...        ...        ...        ...       ...
# 361  25.440350  0.293186  0.969794  12.167928  20.617554  69.302405  8.946928
# 362  25.592090  0.292331  0.969755  12.111058  20.478283  69.366466  8.960258
# 363  25.753000  0.291479  0.969728  12.054347  20.332621  69.423668  8.973486
# 364  25.922587  0.290631  0.969713  11.997868  20.181086  69.474057  8.986601
# 365  26.100388  0.289787  0.969711  11.941679  20.024186  69.517690  8.999591
#
#            Ca        Cb        Fc       Time
# 0    0.809400  0.843533  0.000000  20.000000
# 1    0.809379  0.843464  0.010274  20.027397
# 2    0.809317  0.843258  0.020548  20.054795
# 3    0.809213  0.842916  0.030822  20.082192
# 4    0.809070  0.842440  0.041096  20.109589
# ..        ...       ...       ...        ...
# 361  3.990450  0.077369  3.708904  29.890411
# 362  3.987189  0.077231  3.719178  29.917808
# 363  3.981907  0.077048  3.729452  29.945205
# 364  3.974654  0.076820  3.739726  29.972603
# 365  3.965480  0.076547  3.750000  30.000000
#
# [366 rows x 11 columns]

# %%
# Visualize data from lower resolution dataset 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = low_demo_ebt[['Cj', 'Ca', 'Cb']]
sprat = low_demo_ebt[['Sj', 'Sa', 'Sb']]
time = low_demo_ebt['Time']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics 20-30 years')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')

# Remove Time column
low_demo_ebt.drop(['Time'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled = scaler.fit_transform(low_demo_ebt)

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
demo_ebt_scaled = pd.DataFrame(ebt_scaled, columns = labels)

# Check the scaled DataFrame
demo_ebt_scaled.head(-10)
# Out:
#            Rs        Rj        Ra            Sj        Sa            Sb  \
# 0    1.000000  0.165405  0.984417  0.000000e+00  0.000123  0.000000e+00
# 1    1.000000  0.165409  0.984422  5.055820e-07  0.000123  2.369050e-07
# 2    0.999999  0.165428  0.984450  4.195656e-06  0.000124  1.907222e-06
# 3    0.999996  0.165470  0.984512  1.458505e-05  0.000128  6.462716e-06
# 4    0.999988  0.165540  0.984610  3.547577e-05  0.000135  1.537952e-05
# ..        ...       ...       ...           ...       ...           ...
# 351  0.000394  0.834836  0.058395  9.102274e-01  0.994137  9.365301e-01
# 352  0.001315  0.818991  0.050148  8.991905e-01  0.990120  9.433765e-01
# 353  0.002741  0.802812  0.042518  8.878420e-01  0.985123  9.498690e-01
# 354  0.004649  0.786351  0.035513  8.762325e-01  0.979184  9.560058e-01
# 355  0.007018  0.769659  0.029136  8.644091e-01  0.972341  9.617859e-01
#
#            Cj        Ca        Cb        Fc
# 0    0.011209  0.002429  1.000000  0.000000
# 1    0.011189  0.002423  0.999912  0.002740
# 2    0.011126  0.002403  0.999650  0.005479
# 3    0.011018  0.002371  0.999214  0.008219
# 4    0.010862  0.002326  0.998606  0.010959
# ..        ...       ...       ...       ...
# 351  0.771108  0.972165  0.021485  0.961644
# 352  0.787616  0.978138  0.021878  0.964384
# 353  0.804167  0.983378  0.022219  0.967123
# 354  0.820744  0.987887  0.022505  0.969863
# 355  0.837330  0.991670  0.022736  0.972603
#
# [356 rows x 10 columns]

# %% [markdown]
# ### High Resolution Dataset
# Run these cells when performing machine learning model with high res dataset

# %%
# Visualize data from lower resolution dataset 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Select data to be visualized
cod = demo_ebt[['Cj', 'Ca', 'Cb']]
sprat = demo_ebt[['Sj', 'Sa', 'Sb']]
demo_ebt['Time'] = np.linspace(20, 30, 3651)
time = demo_ebt['Time']

# Set subplot figure defaults
fig, [cod_plt, sprat_plt] = plt.subplots(2, 1, sharex = True)
fig.subplots_adjust(hspace = 0)
fig.suptitle('Cod-sprat dynamics 20-30 years')

# Set labels for shared x-axis and individual y-axes
cod_plt.set(ylabel = 'Cod biomass ($\mathregular{g^V}$)')
sprat_plt.set(ylabel = 'Sprat biomass ($\mathregular{g^V}$)')
plt.xlabel('Time (years)')

# Visualize data
cod_plt.plot(time, cod)
sprat_plt.plot(time, sprat)

# Add legends
cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')

# Remove Time column
demo_ebt.drop(['Time'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled = scaler.fit_transform(demo_ebt)

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
demo_ebt_scaled = pd.DataFrame(ebt_scaled, columns = labels)

# Check the scaled DataFrame
demo_ebt_scaled.head(-10)
# Out:
#             Rs        Rj        Ra            Sj        Sa            Sb  \
# 0     1.000000  0.165474  0.984412  0.000000e+00  0.000190  0.000000e+00
# 1     1.000000  0.165474  0.984412  3.460767e-10  0.000190  1.384297e-10
# 2     1.000000  0.165474  0.984412  3.655434e-09  0.000190  1.697049e-09
# 3     1.000000  0.165474  0.984412  1.286972e-08  0.000190  6.111426e-09
# 4     1.000000  0.165474  0.984413  3.110363e-08  0.000190  1.480175e-08
# ...        ...       ...       ...           ...       ...           ...
# 3636  0.043359  0.622474  0.000372  7.592537e-01  0.882482  9.967713e-01
# 3637  0.043923  0.620770  0.000308  7.580328e-01  0.881175  9.970244e-01
# 3638  0.044489  0.619066  0.000250  7.568126e-01  0.879863  9.972741e-01
# 3639  0.045059  0.617363  0.000198  7.555930e-01  0.878546  9.975202e-01
# 3640  0.045631  0.615661  0.000152  7.543740e-01  0.877225  9.977629e-01
#
#             Cj        Ca        Cb        Fc
# 0     0.011218  0.002431  1.000000  0.000000
# 1     0.011218  0.002431  0.999999  0.000274
# 2     0.011217  0.002431  0.999996  0.000548
# 3     0.011216  0.002430  0.999992  0.000822
# 4     0.011215  0.002430  0.999986  0.001096
# ...        ...       ...       ...       ...
# 3636  0.977885  0.995656  0.022334  0.996164
# 3637  0.979474  0.995420  0.022304  0.996438
# 3638  0.981062  0.995177  0.022273  0.996712
# 3639  0.982649  0.994929  0.022242  0.996986
# 3640  0.984234  0.994674  0.022211  0.997260
#
# [3641 rows x 10 columns]

# %% [markdown]
# ### Continue here after selection of dataset resolution

# %%
# Define function for visualisation of scaled data 

def visualise_scaled(ebt_scaled, years):
    # Select data to be visualized
    cod = ebt_scaled[['Cj', 'Ca', 'Cb']]
    sprat = ebt_scaled[['Sj', 'Sa', 'Sb']]
    resource = ebt_scaled[['Rj', 'Rs', 'Ra']]
    ebt_scaled['Time'] = np.linspace(years[0], years[1], len(ebt_scaled))
    time = ebt_scaled['Time']

    # Set subplot figure defaults
    fig, [cod_plt, sprat_plt, resource_plt] = plt.subplots(3, 1, sharex = True)
    fig.subplots_adjust(hspace = 0)
    fig.suptitle('Cod-sprat-resource dynamics {start}-{stop} years (scaled min-max)'.format(start=years[0],stop=years[1]))

    # Set labels for shared x-axis and individual y-axes
    cod_plt.set(ylabel = 'Cod biomass')
    sprat_plt.set(ylabel = 'Sprat biomass')
    resource_plt.set(ylabel = 'Resource biomass')
    plt.xlabel('Time (years)')

    # Visualize data
    cod_plt.plot(time, cod)
    sprat_plt.plot(time, sprat)
    resource_plt.plot(time, resource)

    # Add legends
    cod_plt.legend(['Cj', 'Ca', 'Cb'], loc = 'center left')
    sprat_plt.legend(['Sj', 'Sa', 'Sb'], loc = 'center left')
    resource_plt.legend(['Rj', 'Rs', 'Ra'], loc = 'center left')

    # Remove Time column
    ebt_scaled.drop(['Time'], axis = 1, inplace = True)

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(demo_ebt_scaled, [20,30])

# %%
# Create file path for new file
DemoEBTScaled_path = os.path.join(TCDFdata_path, 'EBT_demo_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
demo_ebt_scaled.to_csv(DemoEBTScaled_path, index = False)

# %% [markdown]
# For implementation of the first machine model (i.e. TCDF) we have to create a reference to the 'groundtruth' of the model. This makes it possible to compare the found relations by the model to the true relations we have defined in the dataset.
#
# The groundtruth file needs to be .csv file, have no heading and contains three columns. The first column consists of the index of the cause (corresponds to the columnnumber in the EBT_demo_dataset.csv file), index of effect (idem dito), and time delay between index and cause.
#
# For the corresponding causes and effects see the paper by A. van Leeuwen et al. (2008).

# %%
# Create list of lists for the rows to the groundtruth.csv file
groundtruth_rows = [[9, 7, 0],  # Fc - Ca
                    [9, 8, 0],  # Fc - Cb
                    [6, 1, 0],  # Cj - Rj
                    [6, 3, 0],  # Cj - Sj
                    [7, 3, 0],  # Ca - Sj
                    [7, 4, 0],  # Ca - Sa
                    [7, 5, 0],  # Ca - Sb
                    [8, 3, 0],  # Cb - Sj
                    [8, 4, 0],  # Cb - Sa
                    [8, 5, 0],  # Cb - Sb
                    [8, 2, 0],  # Cb - Ra
                    [3, 0, 0],  # Sj - Rs
                    [4, 0, 0],  # Sa - Rs
                    [5, 0, 0]]  # Sb - Rs

# Convert list into DataFrame
groundtruth = pd.DataFrame(groundtruth_rows)

# Create file path for new file
DemoEBTGroundtruth_path = os.path.join(TCDFdata_path, 'EBT_demo_groundtruth.csv')

# Write DataFrame to .csv
groundtruth.to_csv(DemoEBTGroundtruth_path, index = False, header = False)

# %% [markdown]
# Performing the TCDF requires a different directory (where the TCDF is located). Check if the current directory is set at `'/.../TCDF'`.

# %%
# Define needed directory
directory = TCDF_path

# Check current working directory
current_directory = os.getcwd()

# Change working directory to perform TCDF
if current_directory != directory:
    os.chdir(TCDF_path)

# Check new current working directory
os.getcwd()
# Out:
# '/Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/GitHub/thesis/TCDF'

# %% [markdown]
# This part shows the functionality of TCDF.
#
# See the corresponding paper for more detail: ["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19).

# %%
# Install conda- and pip packages in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} git
# !{sys.executable} -m pip install torchvision
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.19.2)
# Requirement already satisfied: torch==1.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.8.1)
# Requirement already satisfied: pillow>=4.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (8.0.1)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch==1.8.1->torchvision) (3.7.4.3)

# %% [markdown]
# # TCDF
#
# These next code cells perform the analysis of the (demo) dataset with the TCDF. In the utils.py file you are able to adjust parameters for adaptive learning rate and early stopping. These parameters include type of optimizer (specified in runTCDF.py arguments), number of epochs before adapting learning rate, minimum learning rate, and size of decreasing learning rate factor. For early stopping two parameters are given, the number of epochs before stopping when loss is not improving and the minimum difference in loss improvement.

# %%
# Show all argument options

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#                   [--lr_scheduler] [--early_stopping]
#
# TCDF: Temporal Causal Discovery Framework
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series
#   --lr_scheduler        Train model with adaptive learning rate (default:
#                         True). Optional to tweak parameters in utensils.py
#                         (default: patience=5, min_lr=1e-6, factor=0.1).
#   --early_stopping      Train model with early stopping (default: True).
#                         Optional to tweak parameters in utensils.py (default:
#                         patience=150, min_delta=0).

# %% [markdown]
# ### Function for plotting

# %%
# This function is to be used to plot the model's loss or accuracy (i.e. performance) after running 
def plot_performance(losses_or_accuracy):
    """Plots the losses for each trained variable for the TCDF model.
    Takes a dictionary with either losses or accuracy for each variable as input"""
    # Preallocate plots in subplots
    fig, axs = plt.subplots(3, 3, sharex = True)
    for ax in axs.flat:
        ax.set(xlabel='Epochs', ylabel='Performance measure')

    # Iterate over each key in dictionary
    keys = list(losses_or_accuracy.keys())
    
    # Plot every variable in different subplot
    axs[0, 0].plot(np.arange(len(losses_or_accuracy[keys[0]])), losses_or_accuracy[keys[0]])
    axs[0, 0].set_title('Performance Rs')
    axs[0, 1].plot(np.arange(len(losses_or_accuracy[keys[1]])), losses_or_accuracy[keys[1]])
    axs[0, 1].set_title('Performance Rj')
    axs[0, 2].plot(np.arange(len(losses_or_accuracy[keys[2]])), losses_or_accuracy[keys[2]])
    axs[0, 2].set_title('Performance Ra')
    axs[1, 0].plot(np.arange(len(losses_or_accuracy[keys[3]])), losses_or_accuracy[keys[3]])
    axs[1, 0].set_title('Performance Sj')
    axs[1, 1].plot(np.arange(len(losses_or_accuracy[keys[4]])), losses_or_accuracy[keys[4]])
    axs[1, 1].set_title('Performance Sa')
    axs[1, 2].plot(np.arange(len(losses_or_accuracy[keys[5]])), losses_or_accuracy[keys[5]])
    axs[1, 2].set_title('Performance Sb')
    axs[2, 0].plot(np.arange(len(losses_or_accuracy[keys[6]])), losses_or_accuracy[keys[6]])
    axs[2, 0].set_title('Performance Cj')
    axs[2, 1].plot(np.arange(len(losses_or_accuracy[keys[7]])), losses_or_accuracy[keys[7]])
    axs[2, 1].set_title('Performance Ca')
    axs[2, 2].plot(np.arange(len(losses_or_accuracy[keys[8]])), losses_or_accuracy[keys[8]])
    axs[2, 2].set_title('Performance Cb')

# %% [markdown]
# ## TCDF Training
#
# In this section I will tweak (hyper)parameters and save the best outcomes thus far. After implementation of a learning rate scheduler and early stopping to help the process of training the model (see the ~.py files in the TCDF folder, any adjustments are highlighted by '# Adjusted implementation by Draaijer, R.'). Besides, I have also implemented some extra code to save predictive accuracy of the model to plot the performance of the model after the run. Each run is accompanied by two plots (losses and accuracy) to keep track of training the model.

# %% [markdown]
# ### TCDF with EBT demo data
# #### TCDF: first run

# %%
# %matplotlib inline

# Run TCDF with the selected demo dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 1000 --log_interval 250 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=1000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.95)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.315483
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.001292
# Epoch: 500 [50%] 	Loss: 0.000129
# Epoch: 750 [75%] 	Loss: 0.000053
# Epoch: 1000 [100%] 	Loss: 0.000042
# Potential causes:  [4, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.088744
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.029289
# Epoch: 500 [50%] 	Loss: 0.029226
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 4, 2]
# Validated causes:  [0]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.309657
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000183
# Epoch: 500 [50%] 	Loss: 0.000161
# Epoch: 750 [75%] 	Loss: 0.000142
# Epoch: 1000 [100%] 	Loss: 0.000125
# Potential causes:  [4, 2]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.091067
# Epoch   138: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   149: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   160: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   171: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   182: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.002102
# Epoch: 500 [50%] 	Loss: 0.002098
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8, 4]
# Validated causes:  [0, 4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.079456
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.005236
# Epoch: 500 [50%] 	Loss: 0.005234
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 8]
# Validated causes:  [0]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.076466
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.001419
# Epoch: 500 [50%] 	Loss: 0.000564
# Epoch: 750 [75%] 	Loss: 0.000504
# Epoch: 1000 [100%] 	Loss: 0.000465
# Potential causes:  [8, 0]
# Validated causes:  [0]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.090259
# Epoch    30: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.018719
# Epoch: 500 [50%] 	Loss: 0.013476
# Epoch: 750 [75%] 	Loss: 0.007510
# Epoch: 1000 [100%] 	Loss: 0.003199
# Potential causes:  [8, 0]
# Validated causes:  [8]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.080412
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.077331
# Epoch: 500 [50%] 	Loss: 0.077307
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0]
# Validated causes:  []
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.130652
# Epoch    70: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.002317
# Epoch: 500 [50%] 	Loss: 0.002204
# Epoch: 750 [75%] 	Loss: 0.001505
# Epoch: 1000 [100%] 	Loss: 0.001200
# Potential causes:  [9, 4, 7]
# Validated causes:  [9, 7]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.173820
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.036908
# Epoch: 500 [50%] 	Loss: 0.017386
# Epoch: 750 [75%] 	Loss: 0.000450
# Epoch: 1000 [100%] 	Loss: 0.000127
# Potential causes:  [1, 2, 9]
# Validated causes:  [9]
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Sa causes Rs with a delay of 0 time steps.
# Rs causes Rj with a delay of 19 time steps.
# Ra causes Ra with a delay of 51 time steps.
# Rs causes Sj with a delay of 19 time steps.
# Sa causes Sj with a delay of 0 time steps.
# Rs causes Sa with a delay of 19 time steps.
# Rs causes Sb with a delay of 19 time steps.
# Cb causes Cj with a delay of 4 time steps.
# Fc causes Cb with a delay of 12 time steps.
# Ca causes Cb with a delay of 5 time steps.
# Fc causes Fc with a delay of 13 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  9
# Total True Positives':  2
# Total False Negatives:  12
# Total Direct False Positives:  9
# Total Direct True Positives:  2
# TPs':  [(0, 4), (8, 9)]
# FPs':  [(1, 0), (2, 2), (3, 0), (3, 4), (4, 0), (5, 0), (6, 8), (8, 7), (9, 9)]
# TPs direct:  [(0, 4), (8, 9)]
# FPs direct:  [(1, 0), (2, 2), (3, 0), (3, 4), (4, 0), (5, 0), (6, 8), (8, 7), (9, 9)]
# FNs:  [(0, 3), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9)]
# Precision':  0.18181818181818182
# Recall':  0.14285714285714285
# F1' score:  0.16 (includes direct and indirect causal relationships)
# Precision:  0.18181818181818182
# Recall:  0.14285714285714285
# F1 score:  0.16 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  50.0 %
# ==================================================================================

# %% [markdown]
# #### TCDF: second run (1 extra hidden layer; dilation coefficient and kernel size incremented with 1)

# %%
# %matplotlib inline

# Run TCDF with the selected demo dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=1000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.944516
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.004019
# Epoch: 500 [50%] 	Loss: 0.004012
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.418263
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.001030
# Epoch   459: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.000236
# Epoch: 750 [75%] 	Loss: 0.000216
# Epoch: 1000 [100%] 	Loss: 0.000196
# Potential causes:  [9, 2, 3, 4]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.933834
# Epoch    86: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.001349
# Epoch: 500 [50%] 	Loss: 0.001343
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 1, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.371063
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.025786
# Epoch: 500 [50%] 	Loss: 0.006216
# Epoch: 750 [75%] 	Loss: 0.003945
# Epoch: 1000 [100%] 	Loss: 0.002543
# Potential causes:  [9, 4, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.301430
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.049053
# Epoch: 500 [50%] 	Loss: 0.048926
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6]
# Validated causes:  [9]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.382139
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000812
# Epoch: 500 [50%] 	Loss: 0.000322
# Epoch   711: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [75%] 	Loss: 0.000201
# Epoch: 1000 [100%] 	Loss: 0.000191
# Potential causes:  [1, 8, 2, 4]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.441266
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.003798
# Epoch   311: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.003625
# Epoch: 750 [75%] 	Loss: 0.003558
# Epoch: 1000 [100%] 	Loss: 0.003479
# Potential causes:  [1, 9]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.361514
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.021721
# Epoch: 500 [50%] 	Loss: 0.014075
# Epoch: 750 [75%] 	Loss: 0.005393
# Epoch: 1000 [100%] 	Loss: 0.002432
# Potential causes:  [9, 4, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.469285
# Epoch   181: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   192: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   203: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   214: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   225: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.000358
# Epoch: 500 [50%] 	Loss: 0.000349
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 6]
# Validated causes:  [6]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.636449
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    26: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.080752
# Epoch: 500 [50%] 	Loss: 0.080715
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 6]
# Validated causes:  []
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Sa causes Sj with a delay of 96 time steps.
# Fc causes Sa with a delay of 0 time steps.
# Sa causes Ca with a delay of 99 time steps.
# Cj causes Cb with a delay of 241 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  3
# Total True Positives':  1
# Total False Negatives:  14
# Total Direct False Positives:  4
# Total Direct True Positives:  0
# TPs':  [(4, 9)]
# FPs':  [(3, 4), (7, 4), (8, 6)]
# TPs direct:  []
# FPs direct:  [(3, 4), (4, 9), (7, 4), (8, 6)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.25
# Recall':  0.06666666666666667
# F1' score:  0.10526315789473685 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %% [markdown]
# #### TCDF: third run (kernel size & dilation coefficient decreased with 1)

# %%
# %matplotlib inline

# Run TCDF with the selected demo dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.236470
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [25%] 	Loss: 0.005152
# Epoch: 500 [50%] 	Loss: 0.004916
# Epoch: 750 [75%] 	Loss: 0.004668
# Epoch: 1000 [100%] 	Loss: 0.004433
# Potential causes:  [3, 6]
# Validated causes:  [3]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.069906
# Epoch    47: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    91: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.065986
# Epoch: 500 [50%] 	Loss: 0.065975
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 3, 2, 9]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.231622
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000767
# Epoch: 500 [50%] 	Loss: 0.000531
# Epoch: 750 [75%] 	Loss: 0.000473
# Epoch: 1000 [100%] 	Loss: 0.000445
# Potential causes:  [6, 3]
# Validated causes:  [6]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.082183
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.084703
# Epoch: 500 [50%] 	Loss: 0.084613
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 2, 9]
# Validated causes:  [3, 2, 9]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.082189
# Epoch   204: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   215: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   226: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   237: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   248: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.006236
# Epoch: 500 [50%] 	Loss: 0.006228
# INFO: Early stopping at epoch 500
# Potential causes:  [7]
# Validated causes:  [7]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.062437
# Epoch    63: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   107: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.014169
# Epoch: 500 [50%] 	Loss: 0.014081
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 3]
# Validated causes:  [0]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.067144
# Epoch    97: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   141: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.063942
# Epoch: 500 [50%] 	Loss: 0.063910
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 7, 3]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.071302
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.073944
# Epoch: 500 [50%] 	Loss: 0.073842
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 3, 0, 9]
# Validated causes:  [2, 3, 0, 9]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.109791
# Epoch   136: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.043998
# Epoch: 500 [50%] 	Loss: 0.006278
# Epoch: 750 [75%] 	Loss: 0.004828
# Epoch   963: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [100%] 	Loss: 0.002176
# Potential causes:  [1, 7]
# Validated causes:  [1]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.128362
# Epoch    46: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    79: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.083972
# Epoch: 500 [50%] 	Loss: 0.083964
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 4, 9, 3]
# Validated causes:  []
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Sj causes Rs with a delay of 2 time steps.
# Cj causes Ra with a delay of 10 time steps.
# Sj causes Sj with a delay of 30 time steps.
# Ra causes Sj with a delay of 36 time steps.
# Fc causes Sj with a delay of 7 time steps.
# Ca causes Sa with a delay of 7 time steps.
# Rs causes Sb with a delay of 5 time steps.
# Ra causes Ca with a delay of 36 time steps.
# Sj causes Ca with a delay of 29 time steps.
# Rs causes Ca with a delay of 5 time steps.
# Fc causes Ca with a delay of 7 time steps.
# Rj causes Cb with a delay of 51 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  4
# Total False Negatives:  11
# Total Direct False Positives:  9
# Total Direct True Positives:  3
# TPs':  [(0, 3), (3, 9), (4, 7), (7, 9)]
# FPs':  [(2, 6), (3, 3), (3, 2), (5, 0), (7, 2), (7, 3), (7, 0), (8, 1)]
# TPs direct:  [(0, 3), (4, 7), (7, 9)]
# FPs direct:  [(2, 6), (3, 3), (3, 2), (3, 9), (5, 0), (7, 2), (7, 3), (7, 0), (8, 1)]
# FNs:  [(0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 8), (5, 7), (5, 8), (8, 9)]
# Precision':  0.3333333333333333
# Recall':  0.26666666666666666
# F1' score:  0.2962962962962963 (includes direct and indirect causal relationships)
# Precision:  0.25
# Recall:  0.21428571428571427
# F1 score:  0.23076923076923075 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --dilation_coefficient 3 --kernel_size 3 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=3, early_stopping=True, epochs=1000, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.8)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.281191
# Epoch   192: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   203: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   222: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   233: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   244: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.000036
# Epoch: 500 [50%] 	Loss: 0.000036
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.014507
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.001960
# Epoch: 500 [50%] 	Loss: 0.001928
# Epoch: 750 [75%] 	Loss: 0.001879
# Epoch: 1000 [100%] 	Loss: 0.001801
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.263350
# Epoch   187: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000165
# Epoch: 500 [50%] 	Loss: 0.000151
# Epoch: 750 [75%] 	Loss: 0.000136
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.030089
# Epoch    40: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.001586
# Epoch: 500 [50%] 	Loss: 0.001497
# Epoch: 750 [75%] 	Loss: 0.000275
# Epoch: 1000 [100%] 	Loss: 0.000105
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.040689
# Epoch    44: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    55: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    66: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    77: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    88: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.009786
# Epoch: 500 [50%] 	Loss: 0.009786
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.025664
# Epoch   157: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000961
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch   637: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [75%] 	Loss: 0.000014
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057868
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    24: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.055087
# Epoch: 500 [50%] 	Loss: 0.055086
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.037037
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000010
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 750 [75%] 	Loss: 0.000002
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.118113
# Epoch   193: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.019549
# Epoch   487: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.019205
# Epoch   506: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   517: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   528: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 750 [75%] 	Loss: 0.019204
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.065871
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    79: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.053530
# Epoch: 500 [50%] 	Loss: 0.053527
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 1014.571911426469 with standard deviation 1791.5114231920609

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF: fourth run (different seed)

# %%
# %matplotlib inline

# Run TCDF and evaluate by comparing the results to the ground truth

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 1111 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.775858
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.050618
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 8]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.314019
# Epoch    82: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   115: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   126: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.028583
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 6]
# Validated causes:  [5]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.766228
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.077857
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 8]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.277456
# Epoch    65: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   109: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.019087
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 6]
# Validated causes:  [5]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.220352
# Epoch    49: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.040635
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 5]
# Validated causes:  [7]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.282981
# Epoch    46: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [50%] 	Loss: 0.000195
# Epoch: 1000 [100%] 	Loss: 0.000118
# Potential causes:  [5]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.332316
# Epoch    22: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.017116
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 1]
# Validated causes:  [5]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.267660
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.003886
# Epoch: 1000 [100%] 	Loss: 0.003438
# Potential causes:  [5, 7, 6]
# Validated causes:  [5]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.363341
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.002343
# Epoch: 1000 [100%] 	Loss: 0.000784
# Potential causes:  [0, 9, 8, 4, 6]
# Validated causes:  [9]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.503400
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.011176
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 6]
# Validated causes:  [9]
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Sb causes Rj with a delay of 29 time steps.
# Sb causes Sj with a delay of 20 time steps.
# Ca causes Sa with a delay of 11 time steps.
# Sb causes Sb with a delay of 21 time steps.
# Sb causes Cj with a delay of 74 time steps.
# Sb causes Ca with a delay of 20 time steps.
# Fc causes Cb with a delay of 3 time steps.
# Fc causes Fc with a delay of 22 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  6
# Total True Positives':  2
# Total False Negatives:  12
# Total Direct False Positives:  6
# Total Direct True Positives:  2
# TPs':  [(4, 7), (8, 9)]
# FPs':  [(1, 5), (3, 5), (5, 5), (6, 5), (7, 5), (9, 9)]
# TPs direct:  [(4, 7), (8, 9)]
# FPs direct:  [(1, 5), (3, 5), (5, 5), (6, 5), (7, 5), (9, 9)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 8), (5, 7), (5, 8), (7, 9)]
# Precision':  0.25
# Recall':  0.14285714285714285
# F1' score:  0.18181818181818182 (includes direct and indirect causal relationships)
# Precision:  0.25
# Recall:  0.14285714285714285
# F1 score:  0.18181818181818182 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --dilation_coefficient 3 --kernel_size 3 --seed 1111 --plot --train_test_split 0.8
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=3, early_stopping=True, epochs=1000, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=500, lr_scheduler=True, optimizer='Adam', plot=True, seed=1111, train_test_split=0.8)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.919129
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   457: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   477: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 500 [50%] 	Loss: 0.000045
# Epoch   500: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   511: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.160017
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.012095
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.859397
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    26: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.047264
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.117181
# Epoch    85: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    96: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   107: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   118: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   129: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.008557
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.077681
# Epoch   114: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   147: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   158: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.005426
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.166243
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    89: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   100: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.006301
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.291812
# Epoch    66: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [50%] 	Loss: 0.003374
# Epoch   778: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [100%] 	Loss: 0.000045
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.159011
# Epoch    57: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [50%] 	Loss: 0.000405
# Epoch: 1000 [100%] 	Loss: 0.000056
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.447919
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    31: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.092284
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.353595
# Epoch    25: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.000650
# Epoch: 1000 [100%] 	Loss: 0.000253
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 969.3990429590103 with standard deviation 1837.4444596846868

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF: fourth run (different seed)

# %%
# %matplotlib inline

# Run TCDF and evaluate by comparing the results to the ground truth

# %run -i "runTCDF.py"  --ground_truth data/EBT_demo_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 25942 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_demo_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=25942, significance=0.9)
#
#  Dataset:  EBT_demo_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.618979
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.075373
# Epoch: 500 [50%] 	Loss: 0.075359
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 9, 6, 7]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.224667
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    69: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    80: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.042967
# Epoch: 500 [50%] 	Loss: 0.042354
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0, 7, 6]
# Validated causes:  [0]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.610440
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.074859
# Epoch: 500 [50%] 	Loss: 0.074853
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0, 6, 7]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.199275
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.003319
# Epoch: 500 [50%] 	Loss: 0.000178
# Epoch: 750 [75%] 	Loss: 0.000104
# Epoch   801: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   812: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   833: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   844: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [100%] 	Loss: 0.000101
# Potential causes:  [9, 1]
# Validated causes:  [1]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.155230
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000699
# Epoch: 500 [50%] 	Loss: 0.000155
# Epoch: 750 [75%] 	Loss: 0.000086
# Epoch   785: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [100%] 	Loss: 0.000082
# Potential causes:  [9, 1]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.199024
# Epoch    30: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.052165
# Epoch: 500 [50%] 	Loss: 0.052128
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 7, 0, 6]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.238157
# Epoch    42: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    75: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    86: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.031182
# Epoch: 500 [50%] 	Loss: 0.031095
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 9, 0]
# Validated causes:  [7]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.189234
# Epoch    38: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000251
# Epoch: 500 [50%] 	Loss: 0.000104
# Epoch: 750 [75%] 	Loss: 0.000032
# Epoch: 1000 [100%] 	Loss: 0.000004
# Potential causes:  [9, 7]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.271817
# Epoch: 250 [25%] 	Loss: 0.000112
# Epoch   273: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   284: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   295: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   306: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   317: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.000139
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 0]
# Validated causes:  [9]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.384118
# Epoch   112: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   123: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   134: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   145: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   156: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.019184
# Epoch: 500 [50%] 	Loss: 0.019175
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 0, 9]
# Validated causes:  []
#
# ===================Results for EBT_demo_dataset.csv ==================================
# Rs causes Rj with a delay of 37 time steps.
# Rj causes Sj with a delay of 44 time steps.
# Ca causes Cj with a delay of 79 time steps.
# Ca causes Ca with a delay of 31 time steps.
# Fc causes Cb with a delay of 4 time steps.
#
# ===================Evaluation for EBT_demo_dataset.csv ===============================
# Total False Positives':  4
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  4
# Total Direct True Positives:  1
# TPs':  [(8, 9)]
# FPs':  [(1, 0), (3, 1), (6, 7), (7, 7)]
# TPs direct:  [(8, 9)]
# FPs direct:  [(1, 0), (3, 1), (6, 7), (7, 7)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9)]
# Precision':  0.2
# Recall':  0.07142857142857142
# F1' score:  0.10526315789473682 (includes direct and indirect causal relationships)
# Precision:  0.2
# Recall:  0.07142857142857142
# F1 score:  0.10526315789473682 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_demo_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --dilation_coefficient 3 --kernel_size 3 --seed 25942 --plot --train_test_split 0.8
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_demo_dataset.csv'], dilation_coefficient=3, early_stopping=True, epochs=1000, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=25942, train_test_split=0.8)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.739712
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.020576
# Epoch: 500 [50%] 	Loss: 0.020284
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.093206
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.011830
# Epoch: 500 [50%] 	Loss: 0.011829
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.689556
# Epoch    31: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.002947
# Epoch   295: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.000884
# Epoch: 750 [75%] 	Loss: 0.000844
# Epoch: 1000 [100%] 	Loss: 0.000802
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.063731
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.003937
# Epoch   291: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.001476
# Epoch: 750 [75%] 	Loss: 0.001414
# Epoch: 1000 [100%] 	Loss: 0.001347
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.035687
# Epoch    27: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.007446
# Epoch: 500 [50%] 	Loss: 0.001074
# Epoch: 750 [75%] 	Loss: 0.000663
# Epoch   849: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [100%] 	Loss: 0.000041
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.100565
# Epoch    33: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.002817
# Epoch: 500 [50%] 	Loss: 0.002816
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.204789
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    83: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.003231
# Epoch: 500 [50%] 	Loss: 0.003014
# Epoch: 750 [75%] 	Loss: 0.002638
# Epoch: 1000 [100%] 	Loss: 0.002212
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.097589
# Epoch    42: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.011264
# Epoch   342: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   354: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   365: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.011254
# Epoch: 750 [75%] 	Loss: 0.011254
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.338953
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    89: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   100: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.102607
# Epoch: 500 [50%] 	Loss: 0.102377
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.254274
# Epoch: 250 [25%] 	Loss: 0.012712
# Epoch   274: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   285: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   296: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   307: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   318: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.052246
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_demo_dataset.csv : 992.0227148859094 with standard deviation 1782.7829513993204

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# There seems to be big differences in performance and loss when changing the seed, this indicates an unstable pattern and have to find better (hyper)parameters. Or maybe because there is too little data for now?

# %% [markdown]
# ### TCDF with EBT total dynamics
#
# This data represents the tritrophic biomasses including the total dynamics (shift change). The system first is at its equilibrium and remains stable for ~20 years, fishing pressure is introduced and a new equilibrium is to be found (at 70 years it is stable again). Data is split into two 'total dynamics', 0 - 100 years and 20 - 70 years respectively.
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints between year 20 and 70
total_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 70)]
total_ebt_2 = ebt[(ebt['Time (year)'] >= 0) & (ebt['Time (year)'] <= 100)]


# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(total_ebt[['Rs', 'Rj', 'Ra',
                                             'Sj', 'Sa', 'Sb',
                                             'Cj', 'Ca', 'Cb',
                                             'Fc']])
ebt_scaled_2 = scaler.fit_transform(total_ebt_2[['Rs', 'Rj', 'Ra',
                                             'Sj', 'Sa', 'Sb',
                                             'Cj', 'Ca', 'Cb',
                                             'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))
# Out:
#             Rs        Rj        Ra        Sj        Sa        Sb        Cj  \
# 0      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 1      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 2      1.00000  0.018127  0.646078  0.441177  0.000017  0.459337  0.879586
# 3      1.00000  0.018127  0.646079  0.441177  0.000017  0.459337  0.879586
# 4      1.00000  0.018127  0.646079  0.441177  0.000017  0.459337  0.879586
# ...        ...       ...       ...       ...       ...       ...       ...
# 18236  0.00003  0.999801  0.999999  0.000081  0.999837  0.000260  0.000056
# 18237  0.00003  0.999815  0.999999  0.000075  0.999849  0.000241  0.000052
# 18238  0.00003  0.999829  0.999999  0.000069  0.999861  0.000222  0.000048
# 18239  0.00003  0.999844  0.999999  0.000063  0.999872  0.000204  0.000044
# 18240  0.00003  0.999858  0.999999  0.000058  0.999884  0.000185  0.000040
#
#                  Ca        Cb        Fc
# 0      2.027708e-01  1.000000  0.000000
# 1      2.027707e-01  0.999999  0.000068
# 2      2.027705e-01  0.999997  0.000137
# 3      2.027703e-01  0.999993  0.000205
# 4      2.027699e-01  0.999987  0.000274
# ...             ...       ...       ...
# 18236  3.579564e-07  0.000043  0.000000
# 18237  3.559397e-07  0.000043  0.000000
# 18238  3.539230e-07  0.000043  0.000000
# 18239  3.519088e-07  0.000043  0.000000
# 18240  3.498946e-07  0.000043  0.000000
#
# [18241 rows x 10 columns]
#              Rs        Rj        Ra            Sj        Sa            Sb  \
# 0      0.999640  0.017874  0.646314  4.437391e-01  0.000014  4.672258e-01
# 1      0.999641  0.017874  0.646314  4.437384e-01  0.000014  4.672257e-01
# 2      0.999642  0.017874  0.646314  4.437376e-01  0.000014  4.672255e-01
# 3      0.999642  0.017873  0.646313  4.437369e-01  0.000014  4.672253e-01
# 4      0.999643  0.017873  0.646313  4.437361e-01  0.000014  4.672251e-01
# ...         ...       ...       ...           ...       ...           ...
# 36486  0.000066  1.000000  1.000000  4.452738e-10  1.000000  9.053616e-10
# 36487  0.000066  1.000000  1.000000  4.091706e-10  1.000000  8.397362e-10
# 36488  0.000066  1.000000  1.000000  3.730672e-10  1.000000  7.754502e-10
# 36489  0.000066  1.000000  1.000000  3.489984e-10  1.000000  7.098249e-10
# 36490  0.000066  1.000000  1.000000  3.128952e-10  1.000000  6.455388e-10
#
#                  Cj            Ca            Cb   Fc
# 0      8.801519e-01  2.027305e-01  9.985097e-01  0.0
# 1      8.801518e-01  2.027309e-01  9.985112e-01  0.0
# 2      8.801517e-01  2.027313e-01  9.985126e-01  0.0
# 3      8.801516e-01  2.027317e-01  9.985140e-01  0.0
# 4      8.801515e-01  2.027321e-01  9.985154e-01  0.0
# ...             ...           ...           ...  ...
# 36486  3.735778e-10  8.290317e-11  1.568844e-07  0.0
# 36487  3.467977e-10  7.696076e-11  1.568010e-07  0.0
# 36488  3.200283e-10  7.102085e-11  1.567177e-07  0.0
# 36489  2.932697e-10  6.508596e-11  1.566344e-07  0.0
# 36490  2.665326e-10  5.915356e-11  1.565511e-07  0.0
#
# [36491 rows x 10 columns]

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(ebt_scaled_1, [20,70])

# %%
# Visualize scaled data 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

# Plot scaled data 
visualise_scaled(ebt_scaled_2, [0,100])

# %%
# Create file path for new file
EBTScaled_path_1 = os.path.join(TCDFdata_path, 'EBT_20_70_dataset.csv')
EBTScaled_path_2 = os.path.join(TCDFdata_path, 'EBT_0_100_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path_1, index = False)
ebt_scaled_2.to_csv(EBTScaled_path_2, index = False)

# %% [markdown]
# #### TCDF 20-70 years: first run (in triplicate)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.097749
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.101089
# Epoch: 500 [50%] 	Loss: 0.100987
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 3]
# Validated causes:  [2, 3]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.103229
# Epoch    36: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.001364
# Epoch: 500 [50%] 	Loss: 0.001300
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.256328
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.007220
# Epoch: 500 [50%] 	Loss: 0.006965
# Epoch: 750 [75%] 	Loss: 0.005808
# Epoch: 1000 [100%] 	Loss: 0.000435
# Potential causes:  [0, 6, 3, 7]
# Validated causes:  [7]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.180754
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   166: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.000574
# Epoch: 500 [50%] 	Loss: 0.000380
# Epoch: 750 [75%] 	Loss: 0.000287
# Epoch: 1000 [100%] 	Loss: 0.000196
# Potential causes:  [3, 9]
# Validated causes:  [3]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.109766
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.050206
# Epoch: 500 [50%] 	Loss: 0.049924
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.235092
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.004494
# Epoch   417: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.004247
# Epoch: 750 [75%] 	Loss: 0.004215
# Epoch: 1000 [100%] 	Loss: 0.004182
# Potential causes:  [3, 9]
# Validated causes:  [3]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.290115
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.002559
# Epoch   375: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [50%] 	Loss: 0.000817
# Epoch: 750 [75%] 	Loss: 0.000791
# Epoch: 1000 [100%] 	Loss: 0.000765
# Potential causes:  [4, 3, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.058108
# Epoch    37: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.000223
# Epoch: 500 [50%] 	Loss: 0.000070
# Epoch: 750 [75%] 	Loss: 0.000028
# Epoch: 1000 [100%] 	Loss: 0.000020
# Potential causes:  [7, 3, 6]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.085460
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    31: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.044288
# Epoch: 500 [50%] 	Loss: 0.044273
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 9, 7]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.119236
# Epoch    65: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    87: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    98: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   109: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.109037
# Epoch: 500 [50%] 	Loss: 0.109008
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 3]
# Validated causes:  []
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Ra causes Rs with a delay of 36 time steps.
# Sj causes Rs with a delay of 29 time steps.
# Sa causes Rj with a delay of 72 time steps.
# Ca causes Ra with a delay of 22 time steps.
# Sj causes Sj with a delay of 3 time steps.
# Sa causes Sa with a delay of 73 time steps.
# Sj causes Sb with a delay of 2 time steps.
# Sa causes Cj with a delay of 54 time steps.
# Ca causes Ca with a delay of 26 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  8
# Total Direct True Positives:  1
# TPs':  [(0, 3)]
# FPs':  [(0, 2), (1, 4), (2, 7), (3, 3), (4, 4), (5, 3), (6, 4), (7, 7)]
# TPs direct:  [(0, 3)]
# FPs direct:  [(0, 2), (1, 4), (2, 7), (3, 3), (4, 4), (5, 3), (6, 4), (7, 7)]
# FNs:  [(0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.1111111111111111
# Recall':  0.07142857142857142
# F1' score:  0.08695652173913043 (includes direct and indirect causal relationships)
# Precision:  0.1111111111111111
# Recall:  0.07142857142857142
# F1 score:  0.08695652173913043 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 2371 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=2371, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.110100
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.005852
# Epoch   356: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   376: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   399: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   410: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [50%] 	Loss: 0.005628
# Epoch: 750 [75%] 	Loss: 0.005627
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 2, 6]
# Validated causes:  [8, 6]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.106262
# Epoch    54: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    76: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [25%] 	Loss: 0.000567
# Epoch: 500 [50%] 	Loss: 0.000548
# Epoch: 750 [75%] 	Loss: 0.000534
# Epoch: 1000 [100%] 	Loss: 0.000519
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.356278
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.015059
# Epoch: 500 [50%] 	Loss: 0.007412
# Epoch   721: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [75%] 	Loss: 0.000695
# Epoch: 1000 [100%] 	Loss: 0.000584
# Potential causes:  [0, 2, 3]
# Validated causes:  [2, 3]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.252919
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    83: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   112: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   178: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   190: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.014025
# Epoch: 500 [50%] 	Loss: 0.014025
# INFO: Early stopping at epoch 500
# Potential causes:  [6, 0, 3, 2]
# Validated causes:  [6]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.116404
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    89: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   100: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.000069
# Epoch: 500 [50%] 	Loss: 0.000066
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 2]
# Validated causes:  [4]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.324007
# Epoch   104: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   115: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   126: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   137: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   148: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.017264
# Epoch: 500 [50%] 	Loss: 0.017261
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 2, 0, 3]
# Validated causes:  [9]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.383266
# Epoch    74: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000488
# Epoch: 500 [50%] 	Loss: 0.000329
# Epoch: 750 [75%] 	Loss: 0.000225
# Epoch: 1000 [100%] 	Loss: 0.000160
# Potential causes:  [3, 6, 0, 2, 7]
# Validated causes:  [6]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.062464
# Epoch    50: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.000172
# Epoch: 500 [50%] 	Loss: 0.000118
# Epoch: 750 [75%] 	Loss: 0.000079
# Epoch: 1000 [100%] 	Loss: 0.000056
# Potential causes:  [7, 6]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.054114
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    26: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.047794
# Epoch: 500 [50%] 	Loss: 0.047516
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 0, 8, 7, 9]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.152911
# Epoch    25: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.011761
# Epoch: 500 [50%] 	Loss: 0.000570
# Epoch   560: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [75%] 	Loss: 0.000471
# Epoch: 1000 [100%] 	Loss: 0.000455
# Potential causes:  [6, 0, 9, 2]
# Validated causes:  [9]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Cb causes Rs with a delay of 35 time steps.
# Cj causes Rs with a delay of 42 time steps.
# Sa causes Rj with a delay of 3 time steps.
# Ra causes Ra with a delay of 69 time steps.
# Sj causes Ra with a delay of 24 time steps.
# Cj causes Sj with a delay of 42 time steps.
# Sa causes Sa with a delay of 4 time steps.
# Fc causes Sb with a delay of 23 time steps.
# Cj causes Cj with a delay of 53 time steps.
# Ca causes Ca with a delay of 32 time steps.
# Fc causes Fc with a delay of 24 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  7
# Total True Positives':  4
# Total False Negatives:  13
# Total Direct False Positives:  10
# Total Direct True Positives:  1
# TPs':  [(0, 8), (0, 6), (3, 6), (5, 9)]
# FPs':  [(1, 4), (2, 2), (2, 3), (4, 4), (6, 6), (7, 7), (9, 9)]
# TPs direct:  [(3, 6)]
# FPs direct:  [(0, 8), (0, 6), (1, 4), (2, 2), (2, 3), (4, 4), (5, 9), (6, 6), (7, 7), (9, 9)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.36363636363636365
# Recall':  0.23529411764705882
# F1' score:  0.2857142857142857 (includes direct and indirect causal relationships)
# Precision:  0.09090909090909091
# Recall:  0.07142857142857142
# F1 score:  0.08 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --significance 0.9 --dilation_coefficient 3 --kernel_size 3 --seed 1084 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=3, early_stopping=True, epochs=1000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=1084, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.387469
# Epoch    18: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    29: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.097886
# Epoch: 500 [50%] 	Loss: 0.097870
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 7]
# Validated causes:  []
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.344639
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    27: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    38: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    49: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.101873
# Epoch: 500 [50%] 	Loss: 0.101872
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 4, 7]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.996455
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.068521
# Epoch: 500 [50%] 	Loss: 0.068475
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 4, 7]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.778113
# Epoch: 250 [25%] 	Loss: 0.003303
# Epoch   388: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [50%] 	Loss: 0.002198
# Epoch: 750 [75%] 	Loss: 0.001638
# Epoch: 1000 [100%] 	Loss: 0.000911
# Potential causes:  [4, 5, 2, 7]
# Validated causes:  [4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.369707
# Epoch    21: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    32: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    43: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    54: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    65: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.109184
# Epoch: 500 [50%] 	Loss: 0.109174
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 4, 7]
# Validated causes:  []
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.918586
# Epoch    19: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.000271
# Epoch: 500 [50%] 	Loss: 0.000124
# Epoch   542: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   553: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   574: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   585: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 750 [75%] 	Loss: 0.000118
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 4]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.995544
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   125: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   136: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.004275
# Epoch: 500 [50%] 	Loss: 0.004226
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 4]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.306563
# Epoch: 250 [25%] 	Loss: 0.000477
# Epoch   335: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [50%] 	Loss: 0.000388
# Epoch: 750 [75%] 	Loss: 0.000363
# Epoch: 1000 [100%] 	Loss: 0.000337
# Potential causes:  [7]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.150288
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    31: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.044208
# Epoch: 500 [50%] 	Loss: 0.044204
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 7]
# Validated causes:  []
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.518425
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.012991
# Epoch: 500 [50%] 	Loss: 0.012696
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 1, 4, 2]
# Validated causes:  [9]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Sa causes Sj with a delay of 29 time steps.
# Sb causes Sb with a delay of 61 time steps.
# Sa causes Cj with a delay of 65 time steps.
# Ca causes Ca with a delay of 2 time steps.
# Fc causes Fc with a delay of 72 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  5
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  5
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(3, 4), (5, 5), (6, 4), (7, 7), (9, 9)]
# TPs direct:  []
# FPs direct:  [(3, 4), (5, 5), (6, 4), (7, 7), (9, 9)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_20_70_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 1000 --log_interval 250 --dilation_coefficient 3 --kernel_size 3 --seed 5467 --plot --train_test_split 0.5
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_20_70_dataset.csv'], dilation_coefficient=3, early_stopping=True, epochs=1000, hidden_layers=3, kernel_size=3, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.5)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.135261
# Epoch    16: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   185: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.005050
# Epoch: 500 [50%] 	Loss: 0.004590
# Epoch: 750 [75%] 	Loss: 0.004215
# Epoch: 1000 [100%] 	Loss: 0.003936
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.058924
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    47: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.000529
# Epoch: 500 [50%] 	Loss: 0.000529
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.076650
# Epoch    21: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    83: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.031765
# Epoch: 500 [50%] 	Loss: 0.031757
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.232358
# Epoch    22: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [25%] 	Loss: 0.002132
# Epoch: 500 [50%] 	Loss: 0.001006
# Epoch   626: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [75%] 	Loss: 0.000075
# Epoch: 1000 [100%] 	Loss: 0.000058
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.060089
# Epoch    32: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    60: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    71: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    82: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.000891
# Epoch: 500 [50%] 	Loss: 0.000891
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.197345
# Epoch    24: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    85: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [25%] 	Loss: 0.000680
# Epoch: 500 [50%] 	Loss: 0.000644
# Epoch: 750 [75%] 	Loss: 0.000631
# Epoch: 1000 [100%] 	Loss: 0.000622
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.443603
# Epoch    26: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    70: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.001523
# Epoch: 500 [50%] 	Loss: 0.001507
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.058821
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    50: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    61: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    72: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.032155
# Epoch: 500 [50%] 	Loss: 0.032150
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.088048
# Epoch    20: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    31: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    42: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    53: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    64: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.073441
# Epoch: 500 [50%] 	Loss: 0.073440
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.033158
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    35: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    46: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [25%] 	Loss: 0.032502
# Epoch: 500 [50%] 	Loss: 0.032499
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_20_70_dataset.csv : 847922.6898250707 with standard deviation 2511868.104649326

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF 20-70 years: second run (decreased hidden layers by 1, incremented dilation coefficient and kernel size by 1)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 250 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.107181
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.003185
# Epoch: 500 [25%] 	Loss: 0.003183
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.104555
# Epoch   195: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   206: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   217: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   228: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   239: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.000460
# Epoch: 500 [25%] 	Loss: 0.000459
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 9]
# Validated causes:  []
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.341133
# Epoch   197: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   208: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   219: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   230: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   241: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.000306
# Epoch: 500 [25%] 	Loss: 0.000305
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [2]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.241640
# Epoch   156: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   167: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   178: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   189: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   200: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.000469
# Epoch: 500 [25%] 	Loss: 0.000469
# INFO: Early stopping at epoch 500
# Potential causes:  [4]
# Validated causes:  [4]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.114193
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.043440
# Epoch: 500 [25%] 	Loss: 0.043235
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 7, 9]
# Validated causes:  [1]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.310394
# Epoch    75: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000244
# Epoch: 500 [25%] 	Loss: 0.000081
# Epoch: 750 [38%] 	Loss: 0.000043
# Epoch: 1000 [50%] 	Loss: 0.000023
# Epoch: 1250 [62%] 	Loss: 0.000018
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.369104
# Epoch: 250 [12%] 	Loss: 0.000408
# Epoch   291: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   302: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   313: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   324: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   335: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [25%] 	Loss: 0.000414
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5]
# Validated causes:  [4]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.060603
# Epoch    35: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000783
# Epoch: 500 [25%] 	Loss: 0.000408
# Epoch: 750 [38%] 	Loss: 0.000290
# Epoch: 1000 [50%] 	Loss: 0.000221
# Epoch  1101: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1250 [62%] 	Loss: 0.000195
# Epoch: 1500 [75%] 	Loss: 0.000188
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 8, 2, 4]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.057252
# Epoch    28: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000874
# Epoch: 500 [25%] 	Loss: 0.000107
# Epoch: 750 [38%] 	Loss: 0.000074
# Epoch: 1000 [50%] 	Loss: 0.000060
# Epoch: 1250 [62%] 	Loss: 0.000049
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 9]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.146941
# Epoch    29: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    40: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.065689
# Epoch: 500 [25%] 	Loss: 0.065613
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 0, 2]
# Validated causes:  [4]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Sa causes Rs with a delay of 0 time steps.
# Ra causes Ra with a delay of 51 time steps.
# Sa causes Sj with a delay of 0 time steps.
# Rj causes Sa with a delay of 4 time steps.
# Sb causes Sb with a delay of 1 time steps.
# Sa causes Cj with a delay of 0 time steps.
# Ca causes Ca with a delay of 2 time steps.
# Cb causes Cb with a delay of 5 time steps.
# Sa causes Fc with a delay of 0 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  8
# Total True Positives':  1
# Total False Negatives:  13
# Total Direct False Positives:  8
# Total Direct True Positives:  1
# TPs':  [(0, 4)]
# FPs':  [(2, 2), (3, 4), (4, 1), (5, 5), (6, 4), (7, 7), (8, 8), (9, 4)]
# TPs direct:  [(0, 4)]
# FPs direct:  [(2, 2), (3, 4), (4, 1), (5, 5), (6, 4), (7, 7), (8, 8), (9, 4)]
# FNs:  [(0, 3), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.1111111111111111
# Recall':  0.07142857142857142
# F1' score:  0.08695652173913043 (includes direct and indirect causal relationships)
# Precision:  0.1111111111111111
# Recall:  0.07142857142857142
# F1 score:  0.08695652173913043 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 250 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 9238 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=9238, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.119256
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.002226
# Epoch: 500 [25%] 	Loss: 0.001573
# Epoch   676: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   696: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   719: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   730: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 750 [38%] 	Loss: 0.000921
# Epoch: 1000 [50%] 	Loss: 0.000920
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 2, 8]
# Validated causes:  [3, 2]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.112119
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    26: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    37: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    48: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    59: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.098921
# Epoch: 500 [25%] 	Loss: 0.098842
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 6, 4, 0]
# Validated causes:  [1]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.395393
# Epoch   115: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.007907
# Epoch: 500 [25%] 	Loss: 0.007774
# Epoch: 750 [38%] 	Loss: 0.005550
# Epoch   859: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.003053
# Epoch: 1250 [62%] 	Loss: 0.002615
# Epoch: 1500 [75%] 	Loss: 0.002332
# Epoch: 1750 [88%] 	Loss: 0.002236
# Epoch: 2000 [100%] 	Loss: 0.002174
# Potential causes:  [9, 4, 3]
# Validated causes:  [9, 3]
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.282606
# Epoch    51: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    84: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    95: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.053333
# Epoch: 500 [25%] 	Loss: 0.053265
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 6, 9, 2, 1]
# Validated causes:  [7]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.123493
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    28: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [12%] 	Loss: 0.095020
# Epoch: 500 [25%] 	Loss: 0.086359
# Epoch: 750 [38%] 	Loss: 0.069392
# Epoch: 1000 [50%] 	Loss: 0.040907
# Epoch: 1250 [62%] 	Loss: 0.011420
# Epoch: 1500 [75%] 	Loss: 0.001254
# Epoch: 1750 [88%] 	Loss: 0.000609
# Epoch: 2000 [100%] 	Loss: 0.000593
# Potential causes:  [1, 4, 0, 6]
# Validated causes:  [1]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.359424
# Epoch    47: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    58: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [12%] 	Loss: 0.000282
# Epoch: 500 [25%] 	Loss: 0.000194
# Epoch: 750 [38%] 	Loss: 0.000151
# Epoch: 1000 [50%] 	Loss: 0.000127
# Epoch: 1250 [62%] 	Loss: 0.000111
# Epoch: 1500 [75%] 	Loss: 0.000100
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 1, 5, 6, 7]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.420167
# Epoch    56: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.003041
# Epoch: 500 [25%] 	Loss: 0.001564
# Epoch: 750 [38%] 	Loss: 0.001025
# Epoch: 1000 [50%] 	Loss: 0.000639
# Epoch: 1250 [62%] 	Loss: 0.000433
# Epoch: 1500 [75%] 	Loss: 0.000342
# Epoch: 1750 [88%] 	Loss: 0.000290
# Epoch  1986: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 2000 [100%] 	Loss: 0.000245
# Potential causes:  [7, 1]
# Validated causes:  [1]
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.068878
# Epoch    15: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000343
# Epoch: 500 [25%] 	Loss: 0.000124
# Epoch: 750 [38%] 	Loss: 0.000081
# Epoch: 1000 [50%] 	Loss: 0.000069
# Epoch: 1250 [62%] 	Loss: 0.000063
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 3]
# Validated causes:  [2]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.048246
# Epoch    55: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000152
# Epoch: 500 [25%] 	Loss: 0.000049
# Epoch: 750 [38%] 	Loss: 0.000023
# Epoch: 1000 [50%] 	Loss: 0.000015
# Epoch  1198: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 7, 8]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.169359
# Epoch: 250 [12%] 	Loss: 0.001096
# Epoch   296: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 500 [25%] 	Loss: 0.000884
# Epoch: 750 [38%] 	Loss: 0.000789
# Epoch: 1000 [50%] 	Loss: 0.000689
# Epoch: 1250 [62%] 	Loss: 0.000597
# Epoch: 1500 [75%] 	Loss: 0.000518
# Epoch: 1750 [88%] 	Loss: 0.000449
# Epoch: 2000 [100%] 	Loss: 0.000384
# Potential causes:  [1, 9]
# Validated causes:  [9]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Sj causes Rs with a delay of 59 time steps.
# Ra causes Rs with a delay of 3 time steps.
# Rj causes Rj with a delay of 2 time steps.
# Fc causes Ra with a delay of 10 time steps.
# Sj causes Ra with a delay of 53 time steps.
# Ca causes Sj with a delay of 49 time steps.
# Rj causes Sa with a delay of 1 time steps.
# Sb causes Sb with a delay of 22 time steps.
# Rj causes Cj with a delay of 1 time steps.
# Ra causes Ca with a delay of 51 time steps.
# Cb causes Cb with a delay of 51 time steps.
# Fc causes Fc with a delay of 1 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  9
# Total True Positives':  3
# Total False Negatives:  12
# Total Direct False Positives:  10
# Total Direct True Positives:  2
# TPs':  [(0, 3), (2, 9), (3, 7)]
# FPs':  [(0, 2), (1, 1), (2, 3), (4, 1), (5, 5), (6, 1), (7, 2), (8, 8), (9, 9)]
# TPs direct:  [(0, 3), (3, 7)]
# FPs direct:  [(0, 2), (1, 1), (2, 9), (2, 3), (4, 1), (5, 5), (6, 1), (7, 2), (8, 8), (9, 9)]
# FNs:  [(0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.25
# Recall':  0.2
# F1' score:  0.22222222222222224 (includes direct and indirect causal relationships)
# Precision:  0.16666666666666666
# Recall:  0.14285714285714285
# F1 score:  0.15384615384615383 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 250 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 157 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=157, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.431503
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000827
# Epoch: 500 [25%] 	Loss: 0.000115
# Epoch   552: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   572: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   583: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   605: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 750 [38%] 	Loss: 0.000100
# Epoch: 1000 [50%] 	Loss: 0.000100
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0, 2]
# Validated causes:  [0]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.385109
# Epoch    46: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    68: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    79: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.070240
# Epoch: 500 [25%] 	Loss: 0.070128
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [1]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.074077
# Epoch   113: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000393
# Epoch: 500 [25%] 	Loss: 0.000321
# Epoch: 750 [38%] 	Loss: 0.000282
# Epoch: 1000 [50%] 	Loss: 0.000255
# Epoch: 1250 [62%] 	Loss: 0.000232
# Epoch: 1500 [75%] 	Loss: 0.000206
# Epoch  1695: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1750 [88%] 	Loss: 0.000184
# INFO: Early stopping at epoch 500
# Potential causes:  [7, 0]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.845068
# Epoch   100: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000902
# Epoch: 500 [25%] 	Loss: 0.000229
# Epoch   601: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 750 [38%] 	Loss: 0.000078
# Epoch: 1000 [50%] 	Loss: 0.000063
# Epoch: 1250 [62%] 	Loss: 0.000051
# INFO: Early stopping at epoch 500
# Potential causes:  [1, 7]
# Validated causes:  []
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.411559
# Epoch    70: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    81: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    92: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   103: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   114: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.000997
# Epoch: 500 [25%] 	Loss: 0.000974
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 1]
# Validated causes:  [1]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.991964
# Epoch   199: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   210: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   221: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   232: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   243: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.001818
# Epoch: 500 [25%] 	Loss: 0.001815
# INFO: Early stopping at epoch 500
# Potential causes:  [9, 3]
# Validated causes:  []
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.070547
# Epoch    12: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    23: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    34: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.146106
# Epoch: 500 [25%] 	Loss: 0.145401
# INFO: Early stopping at epoch 500
# Potential causes:  [2, 5, 3, 7]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.347528
# Epoch    17: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000408
# Epoch   484: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 500 [25%] 	Loss: 0.000254
# Epoch: 750 [38%] 	Loss: 0.000243
# Epoch: 1000 [50%] 	Loss: 0.000231
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 7, 5, 4, 9]
# Validated causes:  [7]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.177571
# Epoch: 250 [12%] 	Loss: 0.000125
# Epoch: 500 [25%] 	Loss: 0.000082
# Epoch: 750 [38%] 	Loss: 0.000026
# Epoch   831: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   842: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   853: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   864: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   875: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.000022
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.570623
# Epoch   135: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   146: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   157: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   168: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   179: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.008125
# Epoch: 500 [25%] 	Loss: 0.008122
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 7, 3]
# Validated causes:  [5]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Rs causes Rs with a delay of 1 time steps.
# Rj causes Rj with a delay of 7 time steps.
# Rj causes Sa with a delay of 6 time steps.
# Ca causes Ca with a delay of 17 time steps.
# Cb causes Cb with a delay of 1 time steps.
# Sb causes Fc with a delay of 15 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  6
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  6
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(0, 0), (1, 1), (4, 1), (7, 7), (8, 8), (9, 5)]
# TPs direct:  []
# FPs direct:  [(0, 0), (1, 1), (4, 1), (7, 7), (8, 8), (9, 5)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_20_70_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 250 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 4019 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=2000, ground_truth={'data/EBT_20_70_dataset.csv': 'data/EBT_demo_groundtruth.csv'}, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=250, lr_scheduler=True, optimizer='Adam', plot=True, seed=4019, significance=0.9)
#
#  Dataset:  EBT_20_70_dataset.csv
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.187672
# Epoch   113: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000119
# Epoch: 500 [25%] 	Loss: 0.000106
# Epoch: 750 [38%] 	Loss: 0.000092
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 3]
# Validated causes:  [0]
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.166576
# Epoch    40: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    51: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    62: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    84: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.056158
# Epoch: 500 [25%] 	Loss: 0.056010
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 5, 2, 8]
# Validated causes:  [4]
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.593966
# Epoch    77: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    93: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   104: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [12%] 	Loss: 0.000582
# Epoch: 500 [25%] 	Loss: 0.000556
# Epoch: 750 [38%] 	Loss: 0.000526
# Epoch: 1000 [50%] 	Loss: 0.000492
# Epoch: 1250 [62%] 	Loss: 0.000456
# Epoch: 1500 [75%] 	Loss: 0.000420
# Epoch: 1750 [88%] 	Loss: 0.000386
# Epoch: 2000 [100%] 	Loss: 0.000353
# Potential causes:  [4, 2]
# Validated causes:  []
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.439881
# Epoch    68: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    90: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [12%] 	Loss: 0.000149
# Epoch: 500 [25%] 	Loss: 0.000147
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 0, 4, 8, 5]
# Validated causes:  [3]
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.183305
# Epoch   208: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   219: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   238: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 250 [12%] 	Loss: 0.000042
# Epoch   249: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   260: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [25%] 	Loss: 0.000039
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 8]
# Validated causes:  [4]
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.541594
# Epoch    41: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000873
# Epoch: 500 [25%] 	Loss: 0.000067
# Epoch: 750 [38%] 	Loss: 0.000030
# Epoch: 1000 [50%] 	Loss: 0.000021
# Epoch  1221: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  1232: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 1250 [62%] 	Loss: 0.000016
# Epoch  1251: reducing learning rate of group 0 to 1.0000e-05.
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 3]
# Validated causes:  [5]
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.608679
# Epoch   203: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   214: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   234: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   245: reducing learning rate of group 0 to 1.0000e-05.
# Epoch: 250 [12%] 	Loss: 0.002056
# Epoch   256: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 500 [25%] 	Loss: 0.002053
# INFO: Early stopping at epoch 500
# Potential causes:  [3, 4, 0, 8, 5]
# Validated causes:  []
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.125339
# Epoch    86: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    97: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   108: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   119: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   130: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 250 [12%] 	Loss: 0.006471
# Epoch: 500 [25%] 	Loss: 0.006465
# INFO: Early stopping at epoch 500
# Potential causes:  [0, 3]
# Validated causes:  [0]
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.051693
# Epoch    21: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 250 [12%] 	Loss: 0.000833
# Epoch: 500 [25%] 	Loss: 0.000120
# Epoch   706: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   717: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   737: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   748: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 750 [38%] 	Loss: 0.000090
# Epoch: 1000 [50%] 	Loss: 0.000090
# INFO: Early stopping at epoch 500
# Potential causes:  [8, 0, 5, 2, 4]
# Validated causes:  [8]
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.269374
# Epoch    13: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    57: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 250 [12%] 	Loss: 0.074017
# Epoch: 500 [25%] 	Loss: 0.063375
# Epoch: 750 [38%] 	Loss: 0.023986
# Epoch: 1000 [50%] 	Loss: 0.019710
# Epoch: 1250 [62%] 	Loss: 0.016469
# Epoch: 1500 [75%] 	Loss: 0.015228
# Epoch: 1750 [88%] 	Loss: 0.012520
# Epoch: 2000 [100%] 	Loss: 0.010429
# Potential causes:  [5, 4, 6, 3, 8]
# Validated causes:  [5, 6]
#
# ===================Results for EBT_20_70_dataset.csv ==================================
# Rs causes Rs with a delay of 33 time steps.
# Sa causes Rj with a delay of 36 time steps.
# Sj causes Sj with a delay of 56 time steps.
# Sa causes Sa with a delay of 37 time steps.
# Sb causes Sb with a delay of 42 time steps.
# Rs causes Ca with a delay of 32 time steps.
# Cb causes Cb with a delay of 41 time steps.
# Sb causes Fc with a delay of 41 time steps.
# Cj causes Fc with a delay of 62 time steps.
#
# ===================Evaluation for EBT_20_70_dataset.csv ===============================
# Total False Positives':  9
# Total True Positives':  0
# Total False Negatives:  14
# Total Direct False Positives:  9
# Total Direct True Positives:  0
# TPs':  []
# FPs':  [(0, 0), (1, 4), (3, 3), (4, 4), (5, 5), (7, 0), (8, 8), (9, 5), (9, 6)]
# TPs direct:  []
# FPs direct:  [(0, 0), (1, 4), (3, 3), (4, 4), (5, 5), (7, 0), (8, 8), (9, 5), (9, 6)]
# FNs:  [(0, 3), (0, 4), (0, 5), (1, 6), (2, 8), (3, 6), (3, 7), (3, 8), (4, 7), (4, 8), (5, 7), (5, 8), (7, 9), (8, 9)]
# Precision':  0.0
# Recall':  0.0
# F1' score:  0.0 (includes direct and indirect causal relationships)
# Precision:  0.0
# Recall:  0.0
# F1 score:  0.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  0.0 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_20_70_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 4019 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/EBT_20_70_dataset.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=2, kernel_size=4, learning_rate=0.1, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=4019, train_test_split=0.8)
#
#  Analysis started for target:  Rs
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.234597
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    25: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000364
# Epoch: 2000 [100%] 	Loss: 0.000141
#
#  Analysis started for target:  Rj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.021186
# Epoch    22: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   550: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.000277
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ra
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.490759
# Epoch   106: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000423
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.547406
# Epoch    30: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    41: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    52: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    63: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    74: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sa
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.029075
# Epoch    22: reducing learning rate of group 0 to 1.0000e-02.
# Epoch: 1000 [50%] 	Loss: 0.000218
# Epoch  1142: reducing learning rate of group 0 to 1.0000e-03.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Sb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.661613
# Epoch    34: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    45: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    56: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    67: reducing learning rate of group 0 to 1.0000e-05.
# Epoch    78: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Cj
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.759171
# Epoch    62: reducing learning rate of group 0 to 1.0000e-02.
# Epoch    73: reducing learning rate of group 0 to 1.0000e-03.
# Epoch    84: reducing learning rate of group 0 to 1.0000e-04.
# Epoch    95: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   106: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Ca
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.156680
# Epoch    14: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   593: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.007169
# Epoch: 2000 [100%] 	Loss: 0.005450
#
#  Analysis started for target:  Cb
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.064617
# Epoch    22: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   707: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   737: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   760: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   771: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.000110
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  Fc
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.336733
# Epoch   197: reducing learning rate of group 0 to 1.0000e-02.
# Epoch   208: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   219: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   230: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   241: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/EBT_20_70_dataset.csv : 2591971.7194792153 with standard deviation 5214135.649248018

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF 0-100 years: first run

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_0_100_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 2000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF 0-100 years: second run (1 extra hidden layer, different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected total dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_0_100_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 2000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# ### TCDF with EBT equilibrium dynamics
#
# This data represents the tritrophic biomasses before the introduced fishing pressure on cod. The system first finds it equilibrium and remains stable for ~20 years. Therefore, no relations should be found by the machine learning model.
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints for each equilibrium state (i.e. between year 0 and 20 & 70 and 100)
first_eq_ebt = ebt[(ebt['Time (year)'] >= 0) & (ebt['Time (year)'] <= 20)]
second_eq_ebt = ebt[(ebt['Time (year)'] >= 70) & (ebt['Time (year)'] <= 100)]

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(first_eq_ebt[['Rs', 'Rj', 'Ra',
                                                  'Sj', 'Sa', 'Sb',
                                                  'Cj', 'Ca', 'Cb',
                                                  'Fc']])
ebt_scaled_2 = scaler.fit_transform(second_eq_ebt[['Rs', 'Rj', 'Ra',
                                                   'Sj', 'Sa', 'Sb',
                                                   'Cj', 'Ca', 'Cb',
                                                   'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))

# %%
# Visualize scaled data first equilibrium
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_1, [0,20])

# %%
# Visualize scaled data second equilibrium
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_2, [70,100])

# %%
# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_first_eq_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path, index = False)

# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_second_eq_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_2.to_csv(EBTScaled_path, index = False)

# %% [markdown]
# #### TCDF first equilibrium: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 37519 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF first equilibrium: second run (different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 1111 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second equilibrium: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 34321 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 34321 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second equilibrium: second run (different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_eq_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 1238 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_eq_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 4000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 1238 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# ### TCDF with EBT transient dynamics
#
# This data represents the tritrophic biomasses during the introduced fishing pressure on cod. At 20 years Fc increases and is put to a halt on 40 years. Therefore I split the transient dynamics into two separate transient phases: 20-40 years (fishing pressure increases linearly) and 40-70 years (searching for a new equilibrium).
#
# #### Data cleaning

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints for each transient state (i.e. between year 20 and 60 & 60 and 70)
first_trans_ebt = ebt[(ebt['Time (year)'] >= 20) & (ebt['Time (year)'] <= 60)]
second_trans_ebt = ebt[(ebt['Time (year)'] >= 60) & (ebt['Time (year)'] <= 70)]

# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled_1 = scaler.fit_transform(first_trans_ebt[['Rs', 'Rj', 'Ra',
                                                  'Sj', 'Sa', 'Sb',
                                                  'Cj', 'Ca', 'Cb',
                                                  'Fc']])
ebt_scaled_2 = scaler.fit_transform(second_trans_ebt[['Rs', 'Rj', 'Ra',
                                                   'Sj', 'Sa', 'Sb',
                                                   'Cj', 'Ca', 'Cb',
                                                   'Fc']])

# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled_1 = pd.DataFrame(ebt_scaled_1, columns = labels)
ebt_scaled_2 = pd.DataFrame(ebt_scaled_2, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled_1.head(-10))
display(ebt_scaled_2.head(-10))

# %%
# Visualize scaled data first transient
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_1, [20,60])

# %%
# Visualize scaled data second transient
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.lines as lines

visualise_scaled(ebt_scaled_2, [60,70])

# %%
# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_first_trans_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_1.to_csv(EBTScaled_path, index = False)

# Create file path for new file
EBTScaled_path = os.path.join(TCDFdata_path, 'EBT_second_trans_dataset.csv')

# Write clean dataframe demo_ebt to a new .csv file
ebt_scaled_2.to_csv(EBTScaled_path, index = False)

# %% [markdown]
# #### TCDF first transient: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_first_trans_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF first transient: second run (1 less hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 24310 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF first transient: third run (1 more hidden layer, different seed)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_first_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 568943 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %% [markdown]
# #### TCDF second transient: first run

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --significance 0.9 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_trans_dataset.csv --learning_rate 0.1 --hidden_layers 3 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# #### TCDF second transient: second run (1 less hidden layer)

# %%
# %matplotlib inline

# Run TCDF with the selected equilibrium dataset of EBT data

# %run -i "runTCDF.py"  --ground_truth data/EBT_second_trans_dataset.csv=data/EBT_demo_groundtruth.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --significance 0.95 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/EBT_second_trans_dataset.csv --learning_rate 0.1 --hidden_layers 2 --epochs 5000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 2369 --plot

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot training losses
plot_performance(alllosses)

# %%
# %matplotlib inline
# Set figure size 
plt.rcParams['figure.figsize'] = [25, 10]

# Plot accuracy (MASE values)
plot_performance(accuracy)

# %% [markdown]
# ## Adding white noise (Additive White Gaussian Noise)
#
# Training the model with additive noise might be helpful in avoiding overfitting of the model. Data in this section is augmented by adding noise with additive white Gaussian noise.

# %%
# Adding noise using target SNR

# Set a target SNR
target_snr = 0.001
# Calculate signal power and convert to dB 
average_ca = np.mean(ebt['Ca'])

# Calculate noise according to [2] then convert to watts
noise = abs(average_ca - target_snr)

# Generate an sample of white noise
mean_noise = 0
noise_volts = np.random.normal(mean_noise, np.sqrt(noise), len(ebt['Ca']))
# Noise up the original signal
ca_noise = ebt['Ca'] + noise_volts

plt.plot(np.arange(len(ca_noise)), ca_noise)
plt.plot(np.arange(len(ebt['Ca'])), ebt['Ca'])
ca_noise

# %%
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, HTML

# Select information of datapoints 
total_ebt = ebt[(ebt['Time (year)'] >= 0) & (ebt['Time (year)'] <= 100)]


# Normalize data with min-max normalization
scaler = MinMaxScaler()
ebt_scaled = scaler.fit_transform(total_ebt[['Rs', 'Rj', 'Ra',
                                             'Sj', 'Sa', 'Sb',
                                             'Cj', 'Ca', 'Cb',
                                             'Fc']])


# Write scaled data to DataFrame
labels = ['Rs', 'Rj', 'Ra',
          'Sj', 'Sa', 'Sb',
          'Cj', 'Ca', 'Cb',
          'Fc']
ebt_scaled = pd.DataFrame(ebt_scaled, columns = labels)

# Check the scaled DataFrame
display(ebt_scaled.head(-10))

# %%
# Adding noise using target SNR

# Set a target SNR
target_snr = 1e-1000
# Calculate signal power and convert to dB 
average_ca = np.mean(ebt_scaled['Cj'])

# Calculate noise according to [2] then convert to watts
noise = abs(average_ca - target_snr)

# Generate an sample of white noise
mean_noise = 0
noise_volts = np.random.normal(mean_noise, np.sqrt(noise), len(ebt_scaled['Cj']))
# Noise up the original signal
ca_noise = ebt_scaled['Cj'] + noise_volts

plt.plot(np.arange(len(ca_noise)), ca_noise)
plt.plot(np.arange(len(ebt_scaled['Cj'])), ebt_scaled['Cj'])
ca_noise
