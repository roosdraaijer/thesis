# %% [markdown]
# # Results for TCDF

# %%
import pandas as pd
import numpy as np

# %%
# Calculate mean scores for accuracy
def scores(values):
    mean = np.sum(values) / len(values)
    sd = (np.sum((values - mean)**2)) / (len(values) - 1)
    
    return mean, sd

# %%
# Create dictionary with raw data
# {(Signal-to-noise ratio, hidden layers, dataset, transformation, resolution)} 
# : 
# {(Timeseries length, Precision, Recall, F1, F1', MASE)}
       
# 36500 resolution    
    # min-max transformation
        # SNR 1:0
            # 2 hidden layers
data = {('1:0', 2, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 60', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '60 - 70', 'min-max', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '0 - 20', 'min-max', 36500)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '70 - 100', 'min-max', 36500): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),  
    # power transformation
        # SNR 1:0
            # 2 hidden layers
        ('1:0', 2, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 70', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 60', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '60 - 70', 'power', 36500) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '0 - 20', 'power', 36500)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '70 - 100', 'power', 36500): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
# 3650 resolution    
    # min-max transformation
        # SNR 1:0
            # 2 hidden layers
        ('1:0', 2, '0 - 100', 'min-max', 3650) : ({'Timeseries length': 3641},
                                                   {"""Precision'""": (0.125, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.06666666666666667, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.08695652173913045, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (192702.74168683524, 15085.020041694781, 152501.23626169498)}),
        ('1:0', 2, '20 - 70', 'min-max', 3650) : ({'Timeseries length': 1816},
                                                   {"""Precision'""": (0.16666666666666666, 0.4166666666666667, 0.0)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.29411764705882354, 0.0)}, 
                                                   {"""F1'""" : (0.15384615384615383, 0.3448275862068966, 0.0)},
                                                   {'F1' : (0.15384615384615383, 0.15384615384615383, 0.0)},
                                                   {'MASE' : (195690.40462297105, 92952.04656329172, 289896.49493838893)}),
        ('1:0', 2, '20 - 60', 'min-max', 3650) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.3333333333333333, 0.0, 0.6666666666666666)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.0, 0.13333333333333333)}, 
                                                   {"""F1'""" : (0.2, 0.0, 0.2222222222222222)},
                                                   {'F1' : (0.2, 0.0, 0.11764705882352941)},
                                                   {'MASE' : (942.2323353839716, 1021.8535189544986, 1240.0056624890672)}),
        ('1:0', 2, '60 - 70', 'min-max', 3650) : ({'Timeseries length': 1451},
                                                   {"""Precision'""": (0.1111111111111111, 0.3333333333333333, 0.0)},
                                                   {"""Recall'""" : (0.07142857142857142, 0.07142857142857142, 0.0)}, 
                                                   {"""F1'""" : (0.08695652173913043, 0.11764705882352941, 0.0)},
                                                   {'F1' : (0.08695652173913043, 0.11764705882352941, 0.0)},
                                                   {'MASE' : (478271.26250306115, 526075.1907085832, 400987.7514262265)}),
        ('1:0', 2, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': 721},
                                                   {"""Precision'""": (0.6666666666666666, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.23529411764705882, 0.0, 0.0)},
                                                   {'F1' : (0.23529411764705882, 0.0, 0.0)},
                                                   {'MASE' : (25427.21459989105, 28460.945329664617, 34632.16664370162)}),
        ('1:0', 2, '70 - 100', 'min-max', 3650): ({'Timeseries length': 1086},
                                                   {"""Precision'""": (0.0, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (501168.8044327052, 565981.1049331187, 627044.9164277369)}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'min-max', 3650) : ({'Timeseries length': 3641},
                                                   {"""Precision'""": (0.0, 0.16666666666666666, 0.16666666666666666)},
                                                   {"""Recall'""" : (0.0, 0.13333333333333333, 0.06666666666666667)}, 
                                                   {"""F1'""" : (0.0, 0.14814814814814814, 0.09523809523809522)},
                                                   {'F1' : (0.0, 0.07692307692307691, 0.0)},
                                                   {'MASE' : (167398.65703482772, 216940.9834632168, 11080.496755200667)}),
        ('1:0', 3, '20 - 70', 'min-max', 3650) : ({'Timeseries length': 1816},
                                                   {"""Precision'""": (0.0, 0.125, 0.2)},
                                                   {"""Recall'""" : (0.0, 0.06666666666666667, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.0, 0.08695652173913045, 0.10526315789473682)},
                                                   {'F1' : (0.0, 0.0, 0.10526315789473682)},
                                                   {'MASE' : (75663.61070171543, 185127.49611052513, 41774.339326606394)}),
        ('1:0', 3, '20 - 60', 'min-max', 3650) : ({'Timeseries length': 1451},
                                                   {"""Precision'""": (0.09090909090909091, 0.25, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.06666666666666667, 0.06666666666666667, 0.06666666666666667)}, 
                                                   {"""F1'""" : (0.07692307692307691, 0.10526315789473685, 0.1111111111111111)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (161003.2596029775, 443715.5051484977, 692529.855868696)}),
        ('1:0', 3, '60 - 70', 'min-max', 3650) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.0, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (1422.330273297725, 1329.7294201270795, 1437.1270257759545)}),
        ('1:0', 3, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': 721},
                                                   {"""Precision'""": (0.0, 1.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.07142857142857142, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.13333333333333333, 0.0)},
                                                   {'F1' : (0.0, 0.13333333333333333, 0.0)},
                                                   {'MASE' : (38597.77710885786, 32396.091233292012, 32861.070853084035)}),
        ('1:0', 3, '70 - 100', 'min-max', 3650): ({'Timeseries length': 1086},
                                                   {"""Precision'""": (0.0, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (981914.6260844984, 822726.3424402699, 709171.5037634094)}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'min-max', 3650) : ({'Timeseries length': 3641},
                                                     {"""Precision'""": (0.0, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (12.760178230297345, 9.39690123438104, 9.37647199459259)}),
        ('1:0.1', 2, '20 - 70', 'min-max', 3650) : ({'Timeseries length': 1816},
                                                     {"""Precision'""": (0.125, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.09090909090909091, 0.0, 0.0)},
                                                     {'F1' : (0.09090909090909091, 0.0, 0.0)},
                                                     {'MASE' : (6.256267570500619, 5.91751369584896, 6.807365299549484)}),
        ('1:0.1', 2, '20 - 60', 'min-max', 3650) : ({'Timeseries length': 1451},
                                                     {"""Precision'""": (0.14285714285714285, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.09523809523809523, 0.0, 0.0)},
                                                     {'F1' : (0.09523809523809523, 0.0, 0.0)},
                                                     {'MASE' : (3.259767578510656, 3.97431480192403, 3.226961153449655)}),
        ('1:0.1', 2, '60 - 70', 'min-max', 3650) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.2, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.14285714285714285, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.16666666666666666, 0.0, 0.0)},
                                                     {'F1' : (0.16666666666666666, 0.0, 0.0)},
                                                     {'MASE' : (2.0675817401037198, 1.7395215066072764, 2.3801401029553455)}),
        ('1:0.1', 2, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': 721},
                                                     {"""Precision'""": (0.0, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (0.7029071769866179, 0.7099796125893169, 0.7210034860371277)}),
        ('1:0.1', 2, '70 - 100', 'min-max', 3650): ({'Timeseries length': 1086},
                                                     {"""Precision'""": (0.0, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (0.7163549435037244, 0.7299470352426848, 0.7165785497863332)}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'min-max', 3650) : ({'Timeseries length': 3641},
                                                     {"""Precision'""": (0.2, 0.2857142857142857, 0.3333333333333333)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.13333333333333333, 0.06666666666666667)}, 
                                                     {"""F1'""" : (0.10526315789473682, 0.18181818181818182, 0.1111111111111111)},
                                                     {'F1' : (0.10526315789473682, 0.09523809523809523, 0.0)},
                                                     {'MASE' : (11.602197180490045, 9.583645783481433, 9.287501172960528)}),
        ('1:0.1', 3, '20 - 70', 'min-max', 3650) : ({'Timeseries length': 1816},
                                                     {"""Precision'""": (0.6, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.1875, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.2857142857142857, 0.0, 0.0)},
                                                     {'F1' : (0.10526315789473682, 0.0, 0.0)},
                                                     {'MASE' : (11.594232396331652, 7.262946471837177, 6.790361309678387)}),
        ('1:0.1', 3, '20 - 60', 'min-max', 3650) : ({'Timeseries length': 1451},
                                                     {"""Precision'""": (0.2, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.10526315789473682, 0.0, 0.0)},
                                                     {'F1' : (0.10526315789473682, 0.0, 0.0)},
                                                     {'MASE' : (3.9070261884601165, 3.665853612515735, 4.503204163353071)}),
        ('1:0.1', 3, '60 - 70', 'min-max', 3650) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.0, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (2.5223758704163175, 2.083053681442063, 2.3790573300313502)}),
        ('1:0.1', 3, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': 721},
                                                     {"""Precision'""": (0.5, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.06666666666666667, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.11764705882352941, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (0.7261410182319518, 0.7436150805770083, 0.7119971513250068)}),
        ('1:0.1', 3, '70 - 100', 'min-max', 3650): ({'Timeseries length': 1086},
                                                     {"""Precision'""": (0.0, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.0)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (0.7237984066471026, 0.7215943503731792, 0.735545550885772)}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 60', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '60 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '70 - 100', 'min-max', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 60', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '60 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '70 - 100', 'min-max', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 60', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '60 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '70 - 100', 'min-max', 3650): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 60', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '60 - 70', 'min-max', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '0 - 20', 'min-max', 3650)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '70 - 100', 'min-max', 3650): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}), 
    # power transformation
        # SNR 1:0
            # 2 hidden layers
        ('1:0', 2, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 2, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        ('1:0.1', 3, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                     {"""Precision'""": ()},
                                                     {"""Recall'""" : ()}, 
                                                     {"""F1'""" : ()},
                                                     {'F1' : ()},
                                                     {'MASE' : ()}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 70', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 60', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '60 - 70', 'power', 3650) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '0 - 20', 'power', 3650)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '70 - 100', 'power', 3650): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
# 365 resolution    
    # min-max transformation
        # SNR 1:0
            # 2 hidden layers
        ('1:0', 2, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356 },
                                                   {"""Precision'""": (0.0909090909090909, 0.0, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.06666666666666667, 0.0, 0.26666666666666666)}, 
                                                   {"""F1'""" : (0.07692307692307691, 0.0, 0.2962962962962963)},
                                                   {'F1' : (0.0, 0.0, 0.23076923076923075)},
                                                   {'MASE' : (15331.619596362598, 6746.25742765997, 36284.512497606884)}),
        ('1:0', 2, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.0, 0.1, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.06666666666666667, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.08, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (9322.20853882544, 11158.766212459846, 8848.60813446272)}),
        ('1:0', 2, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.0, 1.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.13333333333333333, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.23529411764705882, 0.0)},
                                                   {'F1' : (0.0, 0.125, 0.0)},
                                                   {'MASE' : (134291.74498656875, 108750.15887347046, 126238.58074091056)}),
        ('1:0', 2, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.0, 0.0, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.11764705882352941)},
                                                   {'F1' : (0.0, 0.0, 0.11764705882352941)},
                                                   {'MASE' : (156.74984770371572, 164.65563576733118, 190.39820910047138)}),
        ('1:0', 2, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                   {"""Precision'""": (0.0, 0.5, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.07142857142857142, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.125, 0.0)},
                                                   {'F1' : (0.0, 0.125, 0.0)},
                                                   {'MASE' : (2202.595727288113, 5173.929426728651, 3864.5726134022757)}),
        ('1:0', 2, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                   {"""Precision'""": (0.0, 0.0, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.11764705882352941)},
                                                   {'F1' : (0.0, 0.0, 0.11764705882352941)},
                                                   {'MASE' : (100425.6478940445, 131127.95601208886, 151382.4150838536)}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.25, 0.0, 0.6)},
                                                   {"""Recall'""" : (0.13333333333333333, 0.0, 0.1875)}, 
                                                   {"""F1'""" : (0.1739130434782609, 0.0, 0.2857142857142857)},
                                                   {'F1' : (0.09090909090909091, 0.0, 0.10526315789473682)},
                                                   {'MASE' : (12410.022077389105, 40428.69742397231, 63264.12627713318)}),
        ('1:0', 3, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.16666666666666666, 0.4, 0.2) },
                                                   {"""Recall'""" : (0.13333333333333333, 0.25, 0.06666666666666667)}, 
                                                   {"""F1'""" : (0.14814814814814814, 0.3076923076923077, 0.1)},
                                                   {'F1' : (0.07692307692307691, 0.16666666666666666, 0.0)},
                                                   {'MASE' : (9086.202987147935, 10736.479419611673, 9770.506629303636)}),
        ('1:0', 3, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.3333333333333333, 0.0, 1.0)},
                                                   {"""Recall'""" : (0.2, 0.0, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.25, 0.0, 0.13333333333333333)},
                                                   {'F1' : (0.17391304347826086, 0.0, 0.13333333333333333)},
                                                   {'MASE' : (109733.49915898373, 108686.38556811462, 108565.41255336367)}),
        ('1:0', 3, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.0, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (166.86844442626838, 168.76500366841623, 172.0865363890935)}),
        ('1:0', 3, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                   {"""Precision'""": (0.16666666666666666, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.07142857142857142, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.1, 0.0, 0.0)},
                                                   {'F1' : (0.1, 0.0, 0.0)},
                                                   {'MASE' : (3837.1046536874624, 4521.608261536361, 3475.8967775418523)}),
        ('1:0', 3, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                   {"""Precision'""": (0.0, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (86776.38737732492, 72566.24368421288, 110535.48564948176)}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.0, 0.0, 0.3)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.2)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.24)},
                                                     {'F1' : (0.0, 0.0, 0.16666666666666666)},
                                                     {'MASE' : (10.926212730876788, 11.664648769144367, 10.704044341630176)}),
        ('1:0.1', 2, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                     {"""Precision'""": (0.2, 0.07692307692307693, 0.25)},
                                                     {"""Recall'""" : (0.06666666666666667, 0.06666666666666667, 0.06666666666666667)}, 
                                                     {"""F1'""" : (0.1, 0.07142857142857144, 0.10526315789473685)},
                                                     {'F1' : (0.0, 0.0, 0.0)},
                                                     {'MASE' : (7.469812125548065, 7.627861046549063, 7.137561318748595)}),
        ('1:0.1', 2, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                     {"""Precision'""": (0.1111111111111111, 1.0, 0.125)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.13333333333333333, 0.07142857142857142)}, 
                                                     {"""F1'""" : (0.08695652173913043, 0.23529411764705882, 0.09090909090909091)},
                                                     {'F1' : (0.08695652173913043, 0.125, 0.09090909090909091)},
                                                     {'MASE' : (5.918655829003451, 5.575284356701472, 6.69002525728922)}),
        ('1:0.1', 2, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                     {"""Precision'""": (0.19047619047619047, 0.2, 0.16666666666666666)},
                                                     {"""Recall'""" : (0.26666666666666666, 0.06666666666666667, 0.2)}, 
                                                     {"""F1'""" : (0.2222222222222222, 0.1, 0.1818181818181818)},
                                                     {'F1' : (0.17142857142857143, 0.0, 0.125)},
                                                     {'MASE' : (3.4895159931508895, 3.2176974115110726, 3.409030896213376)}),
        ('1:0.1', 2, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                     {"""Precision'""": (0.0, 0.3333333333333333, 0.16666666666666666)},
                                                     {"""Recall'""" : (0.0, 0.07142857142857142, 0.2)}, 
                                                     {"""F1'""" : (0.0, 0.11764705882352941, 0.1818181818181818)},
                                                     {'F1' : (0.0, 0.11764705882352941, 0.125)},
                                                     {'MASE' : (1.0934710965994643, 1.4088895895946325, 1.3184139058303157)}),
        ('1:0.1', 2, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                     {"""Precision'""": (0.5, 0.18518518518518517, 0.0)},
                                                     {"""Recall'""" : (0.07142857142857142, 0.29411764705882354, 0.0)}, 
                                                     {"""F1'""" : (0.125, 0.22727272727272727, 0.0)},
                                                     {'F1' : (0.125, 0.0975609756097561, 0.0)},
                                                     {'MASE' : (0.8272615883367713, 0.9295564886099242, 0.8753646779133841)}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.5, 0.18181818181818182, 0.16666666666666666)},
                                                     {"""Recall'""" : (0.23529411764705882, 0.14285714285714285, 0.06666666666666667)}, 
                                                     {"""F1'""" : (0.31999999999999995, 0.16, 0.09523809523809522)},
                                                     {'F1' : (0.09090909090909091, 0.16, 0.0)},
                                                     {'MASE' : (10.531897261999948, 9.144509888276911, 21.526901970110437)}),
        ('1:0.1', 3, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                     {"""Precision'""": (0.0, 0.18181818181818182, 0.6666666666666666)},
                                                     {"""Recall'""" : (0.0, 0.14285714285714285, 0.13333333333333333)}, 
                                                     {"""F1'""" : (0.0, 0.16, 0.2222222222222222)},
                                                     {'F1' : (0.0, 0.16, 0.11764705882352941)},
                                                     {'MASE' : (7.542034592206456, 7.851019870173292, 8.152049492606182)}),
        ('1:0.1', 3, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                     {"""Precision'""": (0.3333333333333333, 0.25, 0.3333333333333333)},
                                                     {"""Recall'""" : (0.13333333333333333, 0.07142857142857142, 0.07142857142857142)}, 
                                                     {"""F1'""" : (0.19047619047619044, 0.11111111111111112, 0.11764705882352941)},
                                                     {'F1' : (0.1, 0.11111111111111112, 0.11764705882352941)},
                                                     {'MASE' : (5.90161323741327, 6.14870948850286, 6.630612871241996)}),
        ('1:0.1', 3, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                     {"""Precision'""": (0.14285714285714285, 0.0, 0.0)},
                                                     {"""Recall'""" : (0.13333333333333333, 0.0, 0.0)}, 
                                                     {"""F1'""" : (0.1379310344827586, 0.0, 0.0)},
                                                     {'F1' : (0.07142857142857142, 0.0, 0.0)},
                                                     {'MASE' : (3.368800561221178, 3.5008505942045565, 3.4902519155899987)}),
        ('1:0.1', 3, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                     {"""Precision'""": (0.11764705882352941, 0.2, 0.2727272727272727)},
                                                     {"""Recall'""" : (0.14285714285714285, 0.07142857142857142, 0.21428571428571427)}, 
                                                     {"""F1'""" : (0.12903225806451615, 0.10526315789473682, 0.23999999999999996)},
                                                     {'F1' : (0.12903225806451615, 0.10526315789473682, 0.23999999999999996)},
                                                     {'MASE' : (1.244963893214885, 1.3251015417799845, 1.4182508369268256)}),
        ('1:0.1', 3, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                     {"""Precision'""": (0.0, 0.0, 0.5)},
                                                     {"""Recall'""" : (0.0, 0.0, 0.3125)}, 
                                                     {"""F1'""" : (0.0, 0.0, 0.38461538461538464)},
                                                     {'F1' : (0.0, 0.0, 0.25)},
                                                     {'MASE' : (0.9351250760612911, 1.030784425586076, 0.938169063723492)}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.0, 0.0, 0.375)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.2)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.26086956521739135)},
                                                   {'F1' : (0.0, 0.0, 0.18181818181818182)},
                                                   {'MASE' : (3.7918201072872897, 3.3748135816011646, 3.727918567696409)}),
        ('1:1', 2, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.08333333333333333, 0.16666666666666666, 0.0)},
                                                   {"""Recall'""" : (0.06666666666666667, 0.06666666666666667, 0.0)}, 
                                                   {"""F1'""" : (0.07407407407407407, 0.09523809523809522, 0.0)},
                                                   {'F1' : (0.0, 0.0, 0.0)},
                                                   {'MASE' : (2.973358987493672, 3.44702951635182, 2.8679256488852487)}),
        ('1:1', 2, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.16666666666666666, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.07142857142857142, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.1, 0.0, 0.0)},
                                                   {'F1' : (0.1, 0.0, 0.0)},
                                                   {'MASE' : (2.489393184982455, 2.7889403858776665, 2.6936259334769637)}),
        ('1:1', 2, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.09090909090909091, 0.14285714285714285, 0.23076923076923078)},
                                                   {"""Recall'""" : (0.125, 0.07142857142857142, 0.21428571428571427)}, 
                                                   {"""F1'""" : (0.10526315789473685, 0.09523809523809523, 0.22222222222222224)},
                                                   {'F1' : (0.0, 0.09523809523809523, 0.22222222222222224)},
                                                   {'MASE' : (2.530720871088761, 2.6687985665462612, 2.5725638778003415)}),
        ('1:1', 2, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                   {"""Precision'""": (0.0, 0.5714285714285714, 0.2962962962962963)},
                                                   {"""Recall'""" : (0.0, 0.2857142857142857, 0.4444444444444444)}, 
                                                   {"""F1'""" : (0.0, 0.38095238095238093, 0.3555555555555555)},
                                                   {'F1' : (0.0, 0.38095238095238093, 0.1951219512195122)},
                                                   {'MASE' : (0.8780381694359018, 0.9843672549221575, 1.0883957214287618)}),
        ('1:1', 2, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                   {"""Precision'""": (0.25, 0.21428571428571427, 0.09090909090909091)},
                                                   {"""Recall'""" : (0.125, 0.4, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.16666666666666666, 0.27906976744186046, 0.08)},
                                                   {'F1' : (0.0, 0.2380952380952381, 0.08 )},
                                                   {'MASE' : (0.8644667327875494, 0.9461498995572842, 0.7730100884602679)}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.5, 0.0, 0.0)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.0, 0.0)}, 
                                                   {"""F1'""" : (0.22222222222222224, 0.0, 0.0)},
                                                   {'F1' : (0.22222222222222224, 0.0, 0.0)},
                                                   {'MASE' : (3.2733684613132636, 3.8884000349110095, 8.513880868667284)}),
        ('1:1', 3, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.16666666666666666, 0.25, 0.25)},
                                                   {"""Recall'""" : (0.07142857142857142, 0.13333333333333333, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.1, 0.1739130434782609, 0.11111111111111112)},
                                                   {'F1' : (0.1, 0.09090909090909091, 0.11111111111111112)},
                                                   {'MASE' : (3.0623421283075216, 2.998622298762843, 2.9066138229166296)}),
        ('1:1', 3, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.13333333333333333, 0.5, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.14285714285714285, 0.06666666666666667)}, 
                                                   {"""F1'""" : (0.1379310344827586, 0.22222222222222224, 0.1111111111111111)},
                                                   {'F1' : (0.1379310344827586, 0.22222222222222224, 0.0)},
                                                   {'MASE' : (2.5375275854551194, 2.705460138762721, 2.6254741000431556)}),
        ('1:1', 3, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.13333333333333333, 0.2, 0.25)},
                                                   {"""Recall'""" : (0.13333333333333333, 0.1875, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.13333333333333333, 0.19354838709677422, 0.11111111111111112)},
                                                   {'F1' : (0.0689655172413793, 0.0689655172413793, 0.11111111111111112)},
                                                   {'MASE' : (2.307687497445718, 3.0001480306501316, 2.3657962676313256)}),
        ('1:1', 3, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                   {"""Precision'""": (0.3333333333333333, 0.5, 0.0)},
                                                   {"""Recall'""" : (0.375, 0.3333333333333333, 0.0)}, 
                                                   {"""F1'""" : (0.35294117647058826, 0.4, 0.0)},
                                                   {'F1' : (0.25, 0.3333333333333333, 0.0)},
                                                   {'MASE' : (1.4188137408212314, 1.0286594096841761, 0.9632434196442452)}),
        ('1:1', 3, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                   {"""Precision'""": (0.0, 0.0, 0.35294117647058826)},
                                                   {"""Recall'""" : (0.0, 0.0, 0.4)}, 
                                                   {"""F1'""" : (0.0, 0.0, 0.37500000000000006)},
                                                   {'F1' : (0.0, 0.0, 0.3225806451612903)},
                                                   {'MASE' : (0.8846256269793213, 1.1488987498645933, 1.024278467084994)}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                    {"""Precision'""": (0.0, 0.0, 0.2222222222222222)},
                                                    {"""Recall'""" : (0.0, 0.0, 0.14285714285714285)}, 
                                                    {"""F1'""" : (0.0, 0.0, 0.17391304347826086)},
                                                    {'F1' : (0.0, 0.0, 0.17391304347826086)},
                                                    {'MASE' : (3.635082268660207, 3.2575850216063325, 3.5318878155079068)}),
        ('1:10', 2, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                    {"""Precision'""": (0.18181818181818182, 0.14285714285714285, 0.0)},
                                                    {"""Recall'""" : (0.13333333333333333, 0.07142857142857142, 0.0)}, 
                                                    {"""F1'""" : (0.15384615384615383, 0.09523809523809523, 0.0)},
                                                    {'F1' : (0.08, 0.09523809523809523, 0.0)},
                                                    {'MASE' : (2.6980754644247953, 2.492526098843605, 3.170480118001619)}),
        ('1:10', 2, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                    {"""Precision'""": (0.2, 0.5, 0.0)},
                                                    {"""Recall'""" : (0.07142857142857142, 0.07142857142857142, 0.0)}, 
                                                    {"""F1'""" : (0.10526315789473682, 0.125, 0.0)},
                                                    {'F1' : (0.10526315789473682, 0.125, 0.0)},
                                                    {'MASE' : (2.4721380188892743, 1.8676725285430809, 2.826787167333548)}),
        ('1:10', 2, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                    {"""Precision'""": (0.20833333333333334, 0.2, 0.11764705882352941)},
                                                    {"""Recall'""" : (0.3333333333333333, 0.125, 0.14285714285714285)}, 
                                                    {"""F1'""" : (0.25641025641025644, 0.15384615384615385, 0.12903225806451615)},
                                                    {'F1' : (0.2105263157894737, 0.0, 0.12903225806451615)},
                                                    {'MASE' : (1.581384452446772, 1.5271602172717302, 1.5485079470677623)}),
        ('1:10', 2, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                    {"""Precision'""": (0.0, 0.2727272727272727, 0.14814814814814814)},
                                                    {"""Recall'""" : (0.0, 0.21428571428571427, 0.26666666666666666)}, 
                                                    {"""F1'""" : (0.0, 0.23999999999999996, 0.19047619047619047)},
                                                    {'F1' : (0.0, 0.23999999999999996, 0.14634146341463417)},
                                                    {'MASE' : (0.8472782661161503, 0.9635668046389491, 1.361018496451629)}),
        ('1:10', 2, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                    {"""Precision'""": (0.0, 0.32, 0.125)},
                                                    {"""Recall'""" : (0.0, 0.4444444444444444, 0.07142857142857142)}, 
                                                    {"""F1'""" : (0.0, 0.37209302325581395, 0.09090909090909091)},
                                                    {'F1' : (0.0, 0.20512820512820512, 0.09090909090909091)},
                                                    {'MASE' : (0.8508052948734619, 0.924246516842311, 0.7843107756935386)}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'min-max', 365) : ({'Timeseries length': 356},
                                                    {"""Precision'""": (0.0, 0.09090909090909091, 0.25)},
                                                    {"""Recall'""" : (0.0, 0.06666666666666667, 0.06666666666666667)}, 
                                                    {"""F1'""" : (0.0, 0.07692307692307691, 0.10526315789473685)},
                                                    {'F1' : (0.0, 0.0, 0.0)},
                                                    {'MASE' : (3.7569702859472414, 3.3348422752677793, 3.3916507438834573)}),
        ('1:10', 3, '20 - 70', 'min-max', 365) : ({'Timeseries length': 173},
                                                    {"""Precision'""": (0.5, 0.25, 0.0)},
                                                    {"""Recall'""" : (0.07142857142857142, 0.13333333333333333, 0.0)}, 
                                                    {"""F1'""" : (0.125, 0.1739130434782609, 0.0)},
                                                    {'F1' : (0.125, 0.09090909090909091, 0.0)},
                                                    {'MASE' : (2.633581568144087, 2.4882472622977727, 2.485236339377235)}),
        ('1:10', 3, '20 - 60', 'min-max', 365) : ({'Timeseries length': 137},
                                                    {"""Precision'""": (0.25, 0.0, 0.0)},
                                                    {"""Recall'""" : (0.14285714285714285, 0.0, 0.0)}, 
                                                    {"""F1'""" : (0.18181818181818182, 0.0, 0.0)},
                                                    {'F1' : (0.18181818181818182, 0.0, 0.0)},
                                                    {'MASE' : (2.3754390706744424, 2.911919535382547, 2.8282817852957813)}),
        ('1:10', 3, '60 - 70', 'min-max', 365) : ({'Timeseries length': 27},
                                                    {"""Precision'""": (0.23076923076923078, 0.21052631578947367, 0.2222222222222222)},
                                                    {"""Recall'""" : (0.1875, 0.25, 0.13333333333333333)}, 
                                                    {"""F1'""" : (0.20689655172413793, 0.22857142857142856, 0.16666666666666669)},
                                                    {'F1' : (0.07407407407407408, 0.12121212121212122, 0.08695652173913043)},
                                                    {'MASE' : (1.494360192024528, 1.5512123724588565, 1.3479306056656344)}),
        ('1:10', 3, '0 - 20', 'min-max', 365)  : ({'Timeseries length': 64},
                                                    {"""Precision'""": (0.0, 0.42857142857142855, 0.5)},
                                                    {"""Recall'""" : (0.0, 0.21428571428571427, 0.35714285714285715)}, 
                                                    {"""F1'""" : (0.0, 0.2857142857142857, 0.41666666666666663)},
                                                    {'F1' : (0.0, 0.2857142857142857, 0.41666666666666663)},
                                                    {'MASE' : (0.8932674260740496, 0.9794081941623695, 0.9968323039226277)}),
        ('1:10', 3, '70 - 100', 'min-max', 365): ({'Timeseries length': 100},
                                                    {"""Precision'""": (0.0, 0.3333333333333333, 0.3)},
                                                    {"""Recall'""" : (0.0, 0.06666666666666667, 0.42857142857142855)}, 
                                                    {"""F1'""" : (0.0, 0.1111111111111111, 0.3529411764705882)},
                                                    {'F1' : (0.0, 0.0, 0.3529411764705882)},
                                                    {'MASE' : (0.9481635731373419, 1.2058210770955797, 1.2130152956338545)}), 
    # power transformation
        # SNR 1:0
            # 2 hidden layers
        ('1:0', 2, '0 - 100', 'power', 365) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.15384615384615385, 0.06666666666666667, 0.13333333333333333)},
                                                   {"""Recall'""" : (0.13333333333333333, 0.07142857142857142, 0.14285714285714285)}, 
                                                   {"""F1'""" : (0.14285714285714288, 0.0689655172413793, 0.1379310344827586)},
                                                   {'F1' : (0.07407407407407408, 0.0689655172413793, 0.1379310344827586)},
                                                   {'MASE' : (4742.53731043374, 4129.790786483348, 5379.376019427141)}),
        ('1:0', 2, '20 - 70', 'power', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.18181818181818182, 0.1, 0.2)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.07142857142857142, 0.14285714285714285)}, 
                                                   {"""F1'""" : (0.16, 0.08333333333333333, 0.16666666666666666)},
                                                   {'F1' : (0.16, 0.08333333333333333, 0.16666666666666666)},
                                                   {'MASE' : (2180.4049091291936, 2079.542983124178, 1998.4250992679924)}),
        ('1:0', 2, '20 - 60', 'power', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.3076923076923077, 0.23076923076923078, 0.3333333333333333)},
                                                   {"""Recall'""" : (0.2857142857142857, 0.21428571428571427, 0.375)}, 
                                                   {"""F1'""" : (0.29629629629629634, 0.22222222222222224, 0.35294117647058826)},
                                                   {'F1' : (0.29629629629629634, 0.22222222222222224, 0.25)},
                                                   {'MASE' : (23477.938250728188, 21726.7866565839, 26251.003635077628)}),
        ('1:0', 2, '60 - 70', 'power', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.0, 0.25, 0.125)},
                                                   {"""Recall'""" : (0.0, 0.07142857142857142, 0.07142857142857142)}, 
                                                   {"""F1'""" : (0.0, 0.11111111111111112, 0.09090909090909091)},
                                                   {'F1' : (0.0, 0.11111111111111112, 0.09090909090909091)},
                                                   {'MASE' : (208.15003692820287, 161.08180745294663)}),
        ('1:0', 2, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 2, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:0', 3, '0 - 100', 'power', 365) : ({'Timeseries length': 356},
                                                   {"""Precision'""": (0.25, 0.21428571428571427, 0.1)},
                                                   {"""Recall'""" : (0.2, 0.21428571428571427, 0.06666666666666667)}, 
                                                   {"""F1'""" : (0.22222222222222224, 0.21428571428571427, 0.08)},
                                                   {'F1' : (0.15384615384615383, 0.21428571428571427, 0.0)},
                                                   {'MASE' : (5086.178380027992, 2201.1318973600437, 3857.8017384871673)}),
        ('1:0', 3, '20 - 70', 'power', 365) : ({'Timeseries length': 173},
                                                   {"""Precision'""": (0.2727272727272727, 0.23076923076923078, 0.36363636363636365)},
                                                   {"""Recall'""" : (0.2, 0.1875, 0.26666666666666666)}, 
                                                   {"""F1'""" : (0.23076923076923075, 0.20689655172413793, 0.30769230769230765)},
                                                   {'F1' : (0.16, 0.07407407407407408, 0.23999999999999996)},
                                                   {'MASE' : (2747.7373283902525, 1763.8056181212069, 2513.6356445610145)}),
        ('1:0', 3, '20 - 60', 'power', 365) : ({'Timeseries length': 137},
                                                   {"""Precision'""": (0.08333333333333333, 0.25, 0.18181818181818182)},
                                                   {"""Recall'""" : (0.07142857142857142, 0.21428571428571427, 0.13333333333333333)}, 
                                                   {"""F1'""" : (0.07692307692307691, 0.23076923076923075, 0.15384615384615383)},
                                                   {'F1' : (0.07692307692307691, 0.23076923076923075, 0.08)},
                                                   {'MASE' : (23074.638514584767, 26405.077681801988, 22385.802886666006)}),
        ('1:0', 3, '60 - 70', 'power', 365) : ({'Timeseries length': 27},
                                                   {"""Precision'""": (0.5, 0.0625, 0.2)},
                                                   {"""Recall'""" : (0.14285714285714285, 0.07142857142857142, 0.14285714285714285)}, 
                                                   {"""F1'""" : (0.22222222222222224, 0.06666666666666667, 0.16666666666666666)},
                                                   {'F1' : (0.22222222222222224, 0.06666666666666667, 0.16666666666666666)},
                                                   {'MASE' : (153.95713052443767, 180.19243501148804, 159.78206932432238)}),
        ('1:0', 3, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:0', 3, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:0.1
            # 2 hidden layers
        ('1:0.1', 2, '0 - 100', 'power', 365) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.17391304347826086, 0.04, 0.15)},
                                                     {"""Recall'""" : (0.25, 0.07142857142857142, 0.2)}, 
                                                     {"""F1'""" : (0.20512820512820512, 0.05128205128205128, 0.17142857142857143)},
                                                     {'F1' : (0.1081081081081081, 0.05128205128205128, 0.11764705882352941)},
                                                     {'MASE' : (3.880987666245363, 4.161617703148148, 3.6912818590053944)}),
        ('1:0.1', 2, '20 - 70', 'power', 365) : ({'Timeseries length': 173},
                                                     {"""Precision'""": (0.19047619047619047, 0.16666666666666666, 0.125)},
                                                     {"""Recall'""" : (0.25, 0.23529411764705882, 0.2857142857142857)}, 
                                                     {"""F1'""" : (0.2162162162162162, 0.1951219512195121, 0.17391304347826086)},
                                                     {'F1' : (0.11428571428571427, 0.052631578947368425, 0.17391304347826086)},
                                                     {'MASE' : (3.001909158454738, 3.1608786781998837, 3.0027599428602123)}),
        ('1:0.1', 2, '20 - 60', 'power', 365) : ({'Timeseries length': 137},
                                                     {"""Precision'""": (0.2916666666666667, 0.1935483870967742, 0.21212121212121213)},
                                                     {"""Recall'""" : (0.4375, 0.375, 0.4117647058823529)}, 
                                                     {"""F1'""" : (0.35000000000000003, 0.25531914893617014, 0.27999999999999997)},
                                                     {'F1' : (0.2631578947368421, 0.17777777777777778, 0.1702127659574468)},
                                                     {'MASE' : (3.304005106884476, 2.5719261620625224, 2.200469450506842)}),
        ('1:0.1', 2, '60 - 70', 'power', 365) : ({'Timeseries length': 27},
                                                     {"""Precision'""": (0.19230769230769232, 0.26666666666666666, 0.25)},
                                                     {"""Recall'""" : (0.3125, 0.5, 0.3888888888888889)}, 
                                                     {"""F1'""" : (0.2380952380952381, 0.3478260869565218, 0.30434782608695654)},
                                                     {'F1' : (0.15, 0.27272727272727276, 0.14285714285714285)},
                                                     {'MASE' : (1.2842738022032525, 1.3611203505909297, 1.285084813669937)}),
        ('1:0.1', 2, '0 - 20', 'power', 365)  : ({'Timeseries length': 64},
                                                     {"""Precision'""": (0.24242424242424243, 0.1111111111111111, 0.21621621621621623)},
                                                     {"""Recall'""" : (0.4444444444444444, 0.2, 0.5)}, 
                                                     {"""F1'""" : (0.3137254901960784, 0.14285714285714285, 0.3018867924528302)},
                                                     {'F1' : (0.1702127659574468, 0.0975609756097561, 0.23529411764705885)},
                                                     {'MASE' : (1.3035458684397159, 1.1307959107422898, 1.5585603539763564)}),
        ('1:0.1', 2, '70 - 100', 'power', 365): ({'Timeseries length': 100},
                                                     {"""Precision'""": (0.11627906976744186, 0.2, 0.3333333333333333)},
                                                     {"""Recall'""" : (0.3125, 0.3333333333333333, 0.5882352941176471)}, 
                                                     {"""F1'""" : (0.16949152542372883, 0.25, 0.42553191489361697)},
                                                     {'F1' : (0.10526315789473685, 0.09090909090909091, 0.3181818181818182)},
                                                     {'MASE' : (1.1932129766970223, 1.1788228512206629, 1.1098495513299134)}),
            # 3 hidden layers
        ('1:0.1', 3, '0 - 100', 'power', 365) : ({'Timeseries length': 356},
                                                     {"""Precision'""": (0.2916666666666667, 0.13793103448275862, 0.0625)},
                                                     {"""Recall'""" : (0.4375, 0.2857142857142857, 0.06666666666666667)}, 
                                                     {"""F1'""" : (0.35000000000000003, 0.18604651162790697, 0.06451612903225808)},
                                                     {'F1' : (0.2631578947368421, 0.18604651162790697, 0.0)},
                                                     {'MASE' : (3.391517233503457, 3.2623640877845665, 3.1921873168888664)}),
        ('1:0.1', 3, '20 - 70', 'power', 365) : ({'Timeseries length': 173},
                                                     {"""Precision'""": (0.19230769230769232, 0.2692307692307692, 0.23809523809523808)},
                                                     {"""Recall'""" : (0.3125, 0.4375, 0.3125)}, 
                                                     {"""F1'""" : (0.2380952380952381, 0.33333333333333337, 0.27027027027027023)},
                                                     {'F1' : (0.15, 0.25, 0.17142857142857143)},
                                                     {'MASE' : (2.490087942596393, 3.150056091608869, 2.690141397394401)}),
        ('1:0.1', 3, '20 - 60', 'power', 365) : ({'Timeseries length': 137},
                                                     {"""Precision'""": (0.21875, 0.1935483870967742, 0.25)},
                                                     {"""Recall'""" : (0.4666666666666667, 0.4, 0.4375)}, 
                                                     {"""F1'""" : (0.2978723404255319, 0.26086956521739135, 0.3181818181818182)},
                                                     {'F1' : (0.26086956521739124, 0.2222222222222222, 0.2380952380952381)},
                                                     {'MASE' : (2.2393332799118193, 2.432650813297085, 2.442407435845835)}),
        ('1:0.1', 3, '60 - 70', 'power', 365) : ({'Timeseries length': 27},
                                                     {"""Precision'""": (0.12, 0.23076923076923078, 0.23529411764705882)},
                                                     {"""Recall'""" : (0.1875, 0.3333333333333333, 0.42105263157894735)}, 
                                                     {"""F1'""" : (0.14634146341463414, 0.27272727272727276, 0.3018867924528302)},
                                                     {'F1' : (0.05128205128205128, 0.1, 0.125)},
                                                     {'MASE' : (1.4385414724253862, 1.4649205314089262, 1.3628484198487627)}),
        ('1:0.1', 3, '0 - 20', 'power', 365)  : ({'Timeseries length': 64},
                                                     {"""Precision'""": (0.16, 0.17142857142857143, 0.1)},
                                                     {"""Recall'""" : (0.26666666666666666, 0.375, 0.2)}, 
                                                     {"""F1'""" : (0.2, 0.23529411764705876, 0.13333333333333333)},
                                                     {'F1' : (0.15384615384615383, 0.16326530612244897, 0.09090909090909091)},
                                                     {'MASE' : (1.4937478331944247, 1.2531008908657504, 1.1401374842284633)}),
        ('1:0.1', 3, '70 - 100', 'power', 365): ({'Timeseries length': 100},
                                                     {"""Precision'""": (0.27586206896551724, 0.16666666666666666, 0.23076923076923078)},
                                                     {"""Recall'""" : (0.47058823529411764, 0.29411764705882354, 0.4)}, 
                                                     {"""F1'""" : (0.34782608695652173, 0.21276595744680848, 0.29268292682926833)},
                                                     {'F1' : (0.23255813953488377, 0.09090909090909091, 0.25)},
                                                     {'MASE' : (1.3416258820427909, 1.2063045650679514, 1.110569243167205)}),
        # SNR 1:1
            # 2 hidden layers
        ('1:1', 2, '0 - 100', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 70', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '20 - 60', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '60 - 70', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 2, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
            # 3 hidden layers
        ('1:1', 3, '0 - 100', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 70', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '20 - 60', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '60 - 70', 'power', 365) : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        ('1:1', 3, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                   {"""Precision'""": ()},
                                                   {"""Recall'""" : ()}, 
                                                   {"""F1'""" : ()},
                                                   {'F1' : ()},
                                                   {'MASE' : ()}),
        # SNR 1:10
            # 2 hidden layers
        ('1:10', 2, '0 - 100', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 70', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '20 - 60', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '60 - 70', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 2, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
            # 3 hidden layers
        ('1:10', 3, '0 - 100', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 70', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '20 - 60', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '60 - 70', 'power', 365) : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '0 - 20', 'power', 365)  : ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),
        ('1:10', 3, '70 - 100', 'power', 365): ({'Timeseries length': },
                                                    {"""Precision'""": ()},
                                                    {"""Recall'""" : ()}, 
                                                    {"""F1'""" : ()},
                                                    {'F1' : ()},
                                                    {'MASE' : ()}),

        # Finance data
        # 0 hidden layers
        ('Finance', 0, '20_1_3') : ({'Timeseries length': 4001},
                                    {"""Precision'""": (0.8095238095238095, 0.7727272727272727, 0.8333333333333334)},
                                    {"""Recall'""" : (0.7727272727272727, 0.7083333333333334, 0.8695652173913043)},
                                    {"""F1'""" : (0.7906976744186046, 0.7391304347826088, 0.851063829787234)},
                                    {'MASE' : (0.38419081834860785, 0.3841944175406256, 0.3823578654816441)}),
        ('Finance', 0, '20_1A') : ({'Timeseries length': 4001},
                                   {"""Precision'""": (0.8666666666666667, 0.7428571428571429, 0.7857142857142857)},
                                   {"""Recall'""" : (0.9629629629629629, 0.9285714285714286, 0.8461538461538461)},
                                   {"""F1'""" : (0.912280701754386, 0.8253968253968255, 0.8148148148148148)},
                                   {'MASE' : (0.3802521664818332, 0.3761993158910408, 0.37420338330150665)}),
        ('Finance', 0, '20_1B') : ({'Timeseries length': 4001},
                                   {"""Precision'""": (0.7037037037037037, 0.6857142857142857, 0.7419354838709677)},
                                   {"""Recall'""" : (0.8260869565217391, 0.9230769230769231, 0.8518518518518519)},
                                   {"""F1'""" : (0.76, 0.7868852459016394, 0.7931034482758621)},
                                   {'MASE' : (0.3807044278342889, 0.379251090861257, 0.3801577299006786)}),
        ('Finance', 0, '20_1C') : ({'Timeseries length': 4001},
                                   {"""Precision'""": (0.5945945945945946, 0.7, 0.6571428571428571)},
                                   {"""Recall'""" : (0.8461538461538461, 0.6363636363636364, 0.92)},
                                   {"""F1'""" : (0.6984126984126985, 0.6666666666666666, 0.7666666666666667)},
                                   {'MASE' : (0.3770652146617613, 0.3756921487994929, 0.37895386758013183)}),
        ('Finance', 0, '20_1D') : ({'Timeseries length': 4001},
                                   {"""Precision'""": (0.6388888888888888, 0.6595744680851063, 0.6190476190476191)},
                                   {"""Recall'""" : (0.8214285714285714, 1.0, 0.8387096774193549)},
                                   {"""F1'""" : (0.7187499999999999, 0.7948717948717948, 0.7123287671232876)},
                                   {'MASE' : (0.38550603455917626, 0.38500649255439257, 0.38430264193661834)}),
        ('Finance', 0, '20_1E') : ({'Timeseries length': 4001},
                                   {"""Precision'""": (0.7586206896551724, 1.0, 0.8461538461538461)},
                                   {"""Recall'""" : (0.8461538461538461, 0.8846153846153846, 0.88)},
                                   {"""F1'""" : (0.8, 0.9387755102040816, 0.8627450980392156)},
                                   {'MASE' : (0.3840903539561875, 0.38719252719595265, 0.38239978162947336)}),
        ('Finance', 0, '40_1') : ({'Timeseries length': 4001}, 
                                  {"""Precision'""": ()}, 
                                  {"""Recall'""" : ()},
                                  {"""F1'""" : ()},
                                  {'MASE' : ()}),
        ('Finance', 0, '40_1_3') : ({'Timeseries length': 4001},
                                    {"""Precision'""": ()}, 
                                    {"""Recall'""" : ()}, 
                                    {"""F1'""" : ()},
                                    {'MASE' : ()}),
        ('Finance', 0, 'manyinputs') : ({'Timeseries length': 4001}, 
                                        {"""Precision'""": ()}, 
                                        {"""Recall'""" : ()},
                                        {"""F1'""" : ()},
                                        {'MASE' : ()}),
        # 1 hidden layer
        ('Finance', 1, '20_1_3') : ({'Timeseries length': 4001}, 
                                    {"""Precision'""": (0.8636363636363636, 0.8461538461538461, 0.8947368421052632)}, 
                                    {"""Recall'""" : (0.8636363636363636, 0.9166666666666666, 0.7727272727272727)},
                                    {"""F1'""" : (0.8636363636363636, 0.8799999999999999, 0.8292682926829269)},
                                    {'MASE' : (0.3843724044411927, 0.38526101128855084, 0.3840657981368969)}),
        ('Finance', 1, '20_1A') : ({'Timeseries length': 4001}, 
                                   {"""Precision'""": (0.9130434782608695, 0.7647058823529411, 0.78125)}, 
                                   {"""Recall'""" : (0.875, 0.9629629629629629, 0.9259259259259259)}, 
                                   {"""F1'""" : (0.8936170212765957, 0.8524590163934426, 0.847457627118644)},
                                   {'MASE' : (0.3805660432860368, 0.3796892508630761, 0.37830516419245946)}),
        ('Finance', 1, '20_1B') : ({'Timeseries length': 4001}, 
                                   {"""Precision'""": (0.6774193548387096, 0.7647058823529411, 0.7096774193548387)}, 
                                   {"""Recall'""" : (0.75, 0.8387096774193549, 0.8461538461538461)}, 
                                   {"""F1'""" : (0.7118644067796611, 0.7999999999999999, 0.7719298245614036)},
                                   {'MASE' : (0.38127316018669793, 0.3828386696728191, 0.38211899728692234)}),
        ('Finance', 1, '20_1C') : ({'Timeseries length': 4001}, 
                                   {"""Precision'""": (0.6875, 0.6129032258064516, 0.72)}, 
                                   {"""Recall'""" : (0.8461538461538461, 0.8636363636363636, 0.72)}, 
                                   {"""F1'""" : (0.7586206896551724, 0.7169811320754716, 0.72)},
                                   {'MASE' : (0.3766798336654162, 0.377654796256051, 0.3792718777742649)}),
        ('Finance', 1, '20_1D') : ({'Timeseries length': 4001}, 
                                   {"""Precision'""": (0.6666666666666666, 0.6764705882352942, 0.7333333333333333)}, 
                                   {"""Recall'""" : (0.8666666666666667, 0.8518518518518519, 0.8148148148148148)}, 
                                   {"""F1'""" : (0.7536231884057971, 0.7540983606557378, 0.7719298245614035)},
                                   {'MASE' : (0.38640554660290066, 0.3875007719612516, 0.38685918266770764)}),
        ('Finance', 1, '20_1E') : ({'Timeseries length': 4001}, 
                                   {"""Precision'""": (0.8148148148148148, 0.9130434782608695, 0.7142857142857143)}, 
                                   {"""Recall'""" : (0.8461538461538461, 0.8076923076923077, 0.8333333333333334)}, 
                                   {"""F1'""" : (0.830188679245283, 0.8571428571428572, 0.7692307692307692)},
                                   {'MASE' : (0.38665156573539244, 0.3842840381828626, 0.38501738187331724)}),
        ('Finance', 1, '40_1') : ({'Timeseries length': 4001}, 
                                  {"""Precision'""": (0.7608695652173914, 0.7317073170731707, 0.7454545454545455)}, 
                                  {"""Recall'""" : (0.7, 0.6122448979591837, 0.82)},
                                  {"""F1'""" : (0.7291666666666667, 0.6666666666666666, 0.780952380952381)},
                                  {'MASE' : (0.3753394496182698, 0.37637851711362896, 0.3787543829706878)}),
        ('Finance', 1, '40_1_3') : ({'Timeseries length': 4001}, 
                                    {"""Precision'""": ()}, 
                                    {"""Recall'""" : ()}, 
                                    {"""F1'""" : ()},
                                    {'MASE' : ()}),
        ('Finance', 1, 'manyinputs') : ({'Timeseries length': 4001}, 
                                        {"""Precision'""": ()},
                                        {"""F1'""" : ()}, 
                                        {'MASE' : ()}),
       }

# Put results into DataFrame
results = pd.DataFrame(data)
# Out:
#   File "<ipython-input-1-a8588d2d7c34>", line 11
#     data = {('1:0', 2, '0 - 100', 'min-max', 36500) : ({'Timeseries length': },
#                                                                              ^
# SyntaxError: invalid syntax

# %%
data = {('Deterministic', 2, '0 - 100') : ({'Timeseries length': 36491}, 
                                           {'Precision': (0.0, 0.0, 0.125)}, 
                                           {'Recall' : (0.0, 0.0, 0.06666666666666667)}, 
                                           {'F1' : (0.0, 0.0, 0.08695652173913045)},
                                           {'MASE' : (199212.2396452416, 45768.524607902786, 1235977.2023501839)}),
       ('Deterministic', 2, '20 - 70')  : ({'Timeseries length': 18241}, 
                                           {'Precision': (0.1111111111111111, 0.25, 0.0)}, 
                                           {'Recall' : (0.07142857142857142, 0.2, 0.0)}, 
                                           {'F1' : (0.08695652173913043, 0.22222222222222224, 0.0)},
                                           {'MASE' : (2550842.6459470633, 860198.0671672176, 22105.801199804446)})}
    
df = pd.DataFrame.from_dict(data, orient='index', columns = ['Timeseries length', 'Precision', 'Recall', 'F1', 'MASE'])

# %%
def summarize(data):
    all_datasets = list(data.keys())
    datasetname = all_datasets[1]
    datasetdata = list(data[datasetname])
    
    for key in dataset:
        dataset = list(data[timeseries])
        timeseries = list(data.keys())[0]
        precision = list(data.keys())[1]
        recall = list(data.keys())[2]
        f1 = list(data.keys())[3]
        mase = list(data.keys())[4]
# Out:
#                                         Timeseries length  \
# (Deterministic, 2, 0 - 100)  {'Timeseries length': 36491}
# (Deterministic, 2, 20 - 70)  {'Timeseries length': 18241}
#
#                                                                   Precision  \
# (Deterministic, 2, 0 - 100)                {'Precision': (0.0, 0.0, 0.125)}
# (Deterministic, 2, 20 - 70)  {'Precision': (0.1111111111111111, 0.25, 0.0)}
#
#                                                                   Recall  \
# (Deterministic, 2, 0 - 100)  {'Recall': (0.0, 0.0, 0.06666666666666667)}
# (Deterministic, 2, 20 - 70)  {'Recall': (0.07142857142857142, 0.2, 0.0)}
#
#                                                                             F1  \
# (Deterministic, 2, 0 - 100)            {'F1': (0.0, 0.0, 0.08695652173913045)}
# (Deterministic, 2, 20 - 70)  {'F1': (0.08695652173913043, 0.222222222222222...
#
#                                                                           MASE
# (Deterministic, 2, 0 - 100)  {'MASE': (199212.2396452416, 45768.52460790278...
# (Deterministic, 2, 20 - 70)  {'MASE': (2550842.6459470633, 860198.067167217...

# %%
key = list(data.keys())[1]
dataset = list(data[key])

precision = list(dataset[1].values())[0]
scores(precision)
# Out:
# (0.12037037037037036, 0.015689300411522635)

# %%
timeseries = list(data.keys())[0]

# %%
list(data[timeseries])
# Out:
# [{'Timeseries length': 36491},
#  {'Precision': (0.0, 0.0, 0.125)},
#  {'Recall': (0.0, 0.0, 0.06666666666666667)},
#  {'F1': (0.0, 0.0, 0.08695652173913045)},
#  {'MASE': (199212.2396452416, 45768.524607902786, 1235977.2023501839)}]

# %%
dataset
# Out:
# [{'Timeseries length': 18241},
#  {'Precision': (0.1111111111111111, 0.25, 0.0)},
#  {'Recall': (0.07142857142857142, 0.2, 0.0)},
#  {'F1': (0.08695652173913043, 0.22222222222222224, 0.0)},
#  {'MASE': (2550842.6459470633, 860198.0671672176, 22105.801199804446)}]

# %%
list(data.keys())[1]
# Out:
# ('Deterministic', 2, '20 - 70')
