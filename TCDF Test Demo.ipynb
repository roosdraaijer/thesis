# %%
import os

# Create universally (i.e. across various operating systems) recognized paths

notebook_path = os.path.abspath('TCDF Test Demo.ipynb')                  # Jupyter notebook path
TCDF_path = os.path.join(os.path.dirname(notebook_path), 'TCDF')       # TCDF folder path
TCDFdata_path = os.path.join(TCDF_path, 'data')                        # TCDF/data folder path
file_path = os.path.join(TCDFdata_path, 'random-rels_20_1_3_returns30007000_header.csv')

# %%
file_path
# Out:
# '/Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/GitHub/thesis/TCDF/data/random-rels_20_1_3_returns30007000_header.csv'

# %%
# Define needed directory
directory = TCDF_path

# Check current working directory
current_directory = os.getcwd()

# Change working directory to perform TCDF
if current_directory != directory:
    os.chdir(TCDF_path)

# Check new current working directory
os.getcwd()
# Out:
# '/Users/apple/Desktop/MSc Thesis 1/MSc Thesis/Coding/GitHub/thesis/TCDF'

# %%
# Install conda- and pip packages in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} git
# !{sys.executable} -m pip install torchvision
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (0.9.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.19.2)
# Requirement already satisfied: pillow>=4.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (8.0.1)
# Requirement already satisfied: torch==1.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.8.1)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch==1.8.1->torchvision) (3.7.4.3)

# %%
# %matplotlib inline

# Run TCDF with a provided dataset of Finance (see https://github.com/M-Nauta/TCDF)

# %run -i "runTCDF.py"  --ground_truth data/random-rels_20_1_3_returns30007000_header.csv=data/random-rels_20_1_3.csv --learning_rate 0.01 --hidden_layers 1 --epochs 5000 --log_interval 1000 --significance 0.8 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/random-rels_20_1_3_returns30007000_header.csv': 'data/random-rels_20_1_3.csv'}, hidden_layers=1, kernel_size=4, learning_rate=0.01, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.8)
#
#  Dataset:  random-rels_20_1_3_returns30007000_header.csv
#
#  Analysis started for target:  S0
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.994392
# Epoch   168: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.176978
# Epoch  1598: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1612: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1623: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.169906
# Epoch: 3000 [60%] 	Loss: 0.169900
# Epoch: 4000 [80%] 	Loss: 0.169890
# Epoch: 5000 [100%] 	Loss: 0.169876
# Potential causes:  [5, 4, 10, 11, 8, 7, 1, 18]
# Validated causes:  []
#
#  Analysis started for target:  S1
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.801597
# Epoch   322: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.140902
# Epoch  1892: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1904: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1915: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.137027
# Epoch: 3000 [60%] 	Loss: 0.137024
# Epoch: 4000 [80%] 	Loss: 0.137019
# Epoch: 5000 [100%] 	Loss: 0.137012
# Potential causes:  [17, 7]
# Validated causes:  [17]
#
#  Analysis started for target:  S2
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.730492
# Epoch   378: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.100915
# Epoch: 2000 [40%] 	Loss: 0.099156
# Epoch  2497: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2510: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2521: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.098491
# Epoch: 4000 [80%] 	Loss: 0.098489
# INFO: Early stopping at epoch 500
# Potential causes:  [19, 3]
# Validated causes:  [19]
#
#  Analysis started for target:  S3
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.811904
# Epoch   292: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.140856
# Epoch  1796: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1811: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1831: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.128217
# Epoch: 3000 [60%] 	Loss: 0.128211
# Epoch: 4000 [80%] 	Loss: 0.128201
# Epoch: 5000 [100%] 	Loss: 0.128187
# Potential causes:  [14, 24, 19, 18]
# Validated causes:  [14, 24, 19]
#
#  Analysis started for target:  S4
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.443778
# Epoch   297: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.073069
# Epoch: 2000 [40%] 	Loss: 0.071513
# Epoch  2224: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2236: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2247: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.071060
# Epoch: 4000 [80%] 	Loss: 0.071058
# Epoch: 5000 [100%] 	Loss: 0.071055
# Potential causes:  [11, 7]
# Validated causes:  []
#
#  Analysis started for target:  S5
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.233236
# Epoch   306: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.207826
# Epoch  1682: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1696: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1707: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.198017
# Epoch: 3000 [60%] 	Loss: 0.198009
# Epoch: 4000 [80%] 	Loss: 0.197998
# Epoch: 5000 [100%] 	Loss: 0.197982
# Potential causes:  [13, 7, 10, 1, 24, 3, 14, 18, 17, 4, 8]
# Validated causes:  [13]
#
#  Analysis started for target:  S6
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.799911
# Epoch   229: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.131638
# Epoch  1828: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1842: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1853: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.125697
# Epoch: 3000 [60%] 	Loss: 0.125692
# Epoch: 4000 [80%] 	Loss: 0.125685
# Epoch: 5000 [100%] 	Loss: 0.125675
# Potential causes:  [7, 17]
# Validated causes:  []
#
#  Analysis started for target:  S7
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.752651
# Epoch   278: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.140165
# Epoch  1612: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1624: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1635: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.134062
# Epoch: 3000 [60%] 	Loss: 0.134053
# Epoch: 4000 [80%] 	Loss: 0.134041
# Epoch: 5000 [100%] 	Loss: 0.134023
# Potential causes:  [17, 3]
# Validated causes:  [17, 3]
#
#  Analysis started for target:  S8
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.488547
# Epoch   367: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.083116
# Epoch: 2000 [40%] 	Loss: 0.080452
# Epoch  2244: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2256: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2267: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.080166
# Epoch: 4000 [80%] 	Loss: 0.080164
# Epoch: 5000 [100%] 	Loss: 0.080161
# Potential causes:  [4, 18, 11, 5, 17, 1, 3]
# Validated causes:  []
#
#  Analysis started for target:  S9
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.632177
# Epoch   332: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   352: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   373: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   384: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.113433
# Epoch: 2000 [40%] 	Loss: 0.113427
# Epoch: 3000 [60%] 	Loss: 0.113419
# Epoch: 4000 [80%] 	Loss: 0.113407
# Epoch: 5000 [100%] 	Loss: 0.113392
# Potential causes:  [4, 18]
# Validated causes:  []
#
#  Analysis started for target:  S10
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.080019
# Epoch   209: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.138292
# Epoch  1571: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1585: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1596: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.131603
# Epoch: 3000 [60%] 	Loss: 0.131595
# Epoch: 4000 [80%] 	Loss: 0.131583
# Epoch: 5000 [100%] 	Loss: 0.131567
# Potential causes:  [5, 11, 4]
# Validated causes:  []
#
#  Analysis started for target:  S11
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.677305
# Epoch   237: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.085760
# Epoch: 2000 [40%] 	Loss: 0.082852
# Epoch  2056: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2070: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2081: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.082738
# Epoch: 4000 [80%] 	Loss: 0.082734
# Epoch: 5000 [100%] 	Loss: 0.082730
# Potential causes:  [4, 18]
# Validated causes:  []
#
#  Analysis started for target:  S12
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.792790
# Epoch   315: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.136413
# Epoch: 2000 [40%] 	Loss: 0.129947
# Epoch  2478: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2503: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2514: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.128041
# Epoch: 4000 [80%] 	Loss: 0.128037
# Epoch: 5000 [100%] 	Loss: 0.128030
# Potential causes:  [22, 24, 5]
# Validated causes:  [22, 24, 5]
#
#  Analysis started for target:  S13
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.991033
# Epoch   429: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   440: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   451: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   462: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.231454
# Epoch: 2000 [40%] 	Loss: 0.231410
# Epoch: 3000 [60%] 	Loss: 0.231356
# Epoch: 4000 [80%] 	Loss: 0.231298
# Epoch: 5000 [100%] 	Loss: 0.231240
# Potential causes:  [24, 3, 7]
# Validated causes:  [24, 3]
#
#  Analysis started for target:  S14
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.687742
# Epoch   372: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   397: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   408: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   420: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.154587
# INFO: Early stopping at epoch 500
# Potential causes:  [4, 22, 19, 24, 18, 8]
# Validated causes:  []
#
#  Analysis started for target:  S15
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.270711
# Epoch   318: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.158918
# Epoch: 2000 [40%] 	Loss: 0.151489
# Epoch  2526: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2551: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2562: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.148944
# Epoch: 4000 [80%] 	Loss: 0.148938
# Epoch: 5000 [100%] 	Loss: 0.148928
# Potential causes:  [17, 7, 14, 1, 5]
# Validated causes:  [17, 14]
#
#  Analysis started for target:  S16
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.846272
# Epoch   342: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.128637
# Epoch: 2000 [40%] 	Loss: 0.125943
# Epoch  2515: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2528: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2539: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.125139
# Epoch: 4000 [80%] 	Loss: 0.125137
# Epoch: 5000 [100%] 	Loss: 0.125134
# Potential causes:  [10, 11, 6, 4, 5, 1, 20, 18, 19]
# Validated causes:  [10]
#
#  Analysis started for target:  S17
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.763105
# Epoch   216: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.152627
# Epoch: 2000 [40%] 	Loss: 0.143571
# Epoch  2178: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2203: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2214: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.142110
# Epoch: 4000 [80%] 	Loss: 0.142099
# Epoch: 5000 [100%] 	Loss: 0.142085
# Potential causes:  [7, 1]
# Validated causes:  [7]
#
#  Analysis started for target:  S18
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.645782
# Epoch   275: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.117702
# Epoch  1788: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1801: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1812: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.114527
# Epoch: 3000 [60%] 	Loss: 0.114525
# Epoch: 4000 [80%] 	Loss: 0.114521
# Epoch: 5000 [100%] 	Loss: 0.114515
# Potential causes:  [11, 22, 19]
# Validated causes:  []
#
#  Analysis started for target:  S19
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.866512
# Epoch   207: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.210158
# Epoch  1732: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1747: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1758: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.205088
# Epoch: 3000 [60%] 	Loss: 0.205083
# Epoch: 4000 [80%] 	Loss: 0.205077
# Epoch: 5000 [100%] 	Loss: 0.205068
# Potential causes:  [24, 4, 5, 18]
# Validated causes:  []
#
#  Analysis started for target:  S20
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.312464
# Epoch   320: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   340: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   363: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   374: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.157518
# Epoch: 2000 [40%] 	Loss: 0.157494
# Epoch: 3000 [60%] 	Loss: 0.157457
# Epoch: 4000 [80%] 	Loss: 0.157407
# Epoch: 5000 [100%] 	Loss: 0.157343
# Potential causes:  [5, 11, 22, 10, 12, 21, 19, 18]
# Validated causes:  [5, 21]
#
#  Analysis started for target:  S21
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.982356
# Epoch   475: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.118196
# Epoch: 2000 [40%] 	Loss: 0.115236
# Epoch  2562: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2576: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2587: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.114238
# Epoch: 4000 [80%] 	Loss: 0.114236
# INFO: Early stopping at epoch 500
# Potential causes:  [5, 20, 4, 19, 18, 11, 22, 24, 12]
# Validated causes:  [20]
#
#  Analysis started for target:  S22
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.912228
# Epoch   294: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.145633
# Epoch: 2000 [40%] 	Loss: 0.142368
# Epoch  2090: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2104: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2115: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.142129
# Epoch: 4000 [80%] 	Loss: 0.142125
# Epoch: 5000 [100%] 	Loss: 0.142121
# Potential causes:  [18, 21, 19, 1, 4, 24]
# Validated causes:  []
#
#  Analysis started for target:  S23
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.994824
# Epoch   263: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.156989
# Epoch: 2000 [40%] 	Loss: 0.150014
# Epoch  2152: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2177: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2188: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.149116
# Epoch: 4000 [80%] 	Loss: 0.149107
# Epoch: 5000 [100%] 	Loss: 0.149095
# Potential causes:  [8, 9, 18, 19, 11, 4, 5, 21]
# Validated causes:  [8, 9]
#
#  Analysis started for target:  S24
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.058181
# Epoch   483: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.260697
# Epoch: 2000 [40%] 	Loss: 0.256403
# Epoch  2818: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2831: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2842: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.252641
# Epoch: 4000 [80%] 	Loss: 0.252638
# Epoch: 5000 [100%] 	Loss: 0.252633
# Potential causes:  [5, 19, 18]
# Validated causes:  []
#
# ===================Results for random-rels_20_1_3_returns30007000_header.csv ==================================
# S17 causes S1 with a delay of 3 time steps.
# S19 causes S2 with a delay of 1 time steps.
# S14 causes S3 with a delay of 1 time steps.
# S24 causes S3 with a delay of 1 time steps.
# S19 causes S3 with a delay of 1 time steps.
# S13 causes S5 with a delay of 1 time steps.
# S17 causes S7 with a delay of 3 time steps.
# S3 causes S7 with a delay of 3 time steps.
# S22 causes S12 with a delay of 3 time steps.
# S24 causes S12 with a delay of 3 time steps.
# S5 causes S12 with a delay of 5 time steps.
# S24 causes S13 with a delay of 1 time steps.
# S3 causes S13 with a delay of 0 time steps.
# S17 causes S15 with a delay of 3 time steps.
# S14 causes S15 with a delay of 3 time steps.
# S10 causes S16 with a delay of 3 time steps.
# S7 causes S17 with a delay of 1 time steps.
# S5 causes S20 with a delay of 2 time steps.
# S21 causes S20 with a delay of 0 time steps.
# S20 causes S21 with a delay of 0 time steps.
# S8 causes S23 with a delay of 2 time steps.
# S9 causes S23 with a delay of 1 time steps.
#
# ===================Evaluation for random-rels_20_1_3_returns30007000_header.csv ===============================
# Total False Positives':  4
# Total True Positives':  18
# Total False Negatives:  4
# Total Direct False Positives:  6
# Total Direct True Positives:  16
# TPs':  [(1, 17), (2, 19), (3, 14), (3, 24), (5, 13), (7, 17), (7, 3), (12, 22), (12, 24), (13, 24), (13, 3), (15, 17), (15, 14), (16, 10), (17, 7), (20, 5), (23, 8), (23, 9)]
# FPs':  [(3, 19), (12, 5), (20, 21), (21, 20)]
# TPs direct:  [(1, 17), (2, 19), (3, 14), (3, 24), (5, 13), (7, 17), (7, 3), (12, 22), (13, 24), (15, 17), (15, 14), (16, 10), (17, 7), (20, 5), (23, 8), (23, 9)]
# FPs direct:  [(3, 19), (12, 24), (12, 5), (13, 3), (20, 21), (21, 20)]
# FNs:  [(6, 7), (12, 13), (13, 15), (13, 7)]
# Precision':  0.8181818181818182
# Recall':  0.8181818181818182
# F1' score:  0.8181818181818182 (includes direct and indirect causal relationships)
# Precision:  0.7272727272727273
# Recall:  0.8
# F1 score:  0.761904761904762 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  94.44444444444444 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/random-rels_20_1_3_returns30007000_header.csv --learning_rate 0.01 --hidden_layers 1 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/random-rels_20_1_3_returns30007000_header.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=1, kernel_size=4, learning_rate=0.01, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.5)
#
#  Analysis started for target:  S0
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.994711
# Epoch   363: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   383: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   405: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   416: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.170598
# Epoch: 2000 [100%] 	Loss: 0.170589
#
#  Analysis started for target:  S1
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.797498
# Epoch   268: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.131963
# Epoch: 2000 [100%] 	Loss: 0.124809
#
#  Analysis started for target:  S2
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.722729
# Epoch   268: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.103848
# Epoch: 2000 [100%] 	Loss: 0.095627
#
#  Analysis started for target:  S3
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.833568
# Epoch   280: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.153527
# Epoch  1942: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [100%] 	Loss: 0.124863
#
#  Analysis started for target:  S4
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.461365
# Epoch   269: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.071892
# Epoch: 2000 [100%] 	Loss: 0.069655
#
#  Analysis started for target:  S5
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.184118
# Epoch   279: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.203382
# Epoch  1842: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1856: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1867: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.191409
#
#  Analysis started for target:  S6
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.808310
# Epoch   258: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.131618
# Epoch: 2000 [100%] 	Loss: 0.123235
#
#  Analysis started for target:  S7
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.763700
# Epoch   253: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   273: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   296: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   307: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.150397
# Epoch: 2000 [100%] 	Loss: 0.150373
#
#  Analysis started for target:  S8
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.495454
# Epoch   299: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.081440
# Epoch: 2000 [100%] 	Loss: 0.078692
#
#  Analysis started for target:  S9
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.628997
# Epoch   325: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.109271
# Epoch: 2000 [100%] 	Loss: 0.105448
#
#  Analysis started for target:  S10
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.017130
# Epoch   310: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.131796
# Epoch  1751: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1766: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1777: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.125819
#
#  Analysis started for target:  S11
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.650741
# Epoch   209: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.084573
# Epoch  1845: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1865: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1876: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.081697
#
#  Analysis started for target:  S12
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.779105
# Epoch   243: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.123517
# Epoch  1955: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1980: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1991: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.116304
#
#  Analysis started for target:  S13
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.010394
# Epoch   165: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.238098
# Epoch  1670: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1685: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1696: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.222962
#
#  Analysis started for target:  S14
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.676752
# Epoch   352: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.151355
# Epoch: 2000 [100%] 	Loss: 0.146611
#
#  Analysis started for target:  S15
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.208929
# Epoch   161: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.162533
# Epoch  1615: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1630: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1650: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.150931
#
#  Analysis started for target:  S16
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.783471
# Epoch   278: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.133938
# Epoch: 2000 [100%] 	Loss: 0.127540
#
#  Analysis started for target:  S17
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.723146
# Epoch   333: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.142376
# Epoch: 2000 [100%] 	Loss: 0.137077
#
#  Analysis started for target:  S18
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.588152
# Epoch   203: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.111565
# Epoch  1635: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1649: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1660: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.107814
#
#  Analysis started for target:  S19
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.775107
# Epoch   245: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.201881
# Epoch  1612: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1627: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1638: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.196103
#
#  Analysis started for target:  S20
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.124540
# Epoch   285: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.154750
# Epoch: 2000 [100%] 	Loss: 0.145188
#
#  Analysis started for target:  S21
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.813502
# Epoch   303: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.116030
# Epoch: 2000 [100%] 	Loss: 0.109492
#
#  Analysis started for target:  S22
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.764949
# Epoch   272: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.136165
# Epoch  1985: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1999: reducing learning rate of group 0 to 1.0000e-05.
# Epoch: 2000 [100%] 	Loss: 0.131114
#
#  Analysis started for target:  S23
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.840103
# Epoch   295: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.153991
# Epoch: 2000 [100%] 	Loss: 0.143573
#
#  Analysis started for target:  S24
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.889832
# Epoch   288: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.242246
# Epoch  1648: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1663: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1674: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.235130
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/random-rels_20_1_3_returns30007000_header.csv : 0.3865862700348429 with standard deviation 0.04916746064798649

# %%
# %matplotlib inline

# Run TCDF with a provided dataset of Finance (see https://github.com/M-Nauta/TCDF)

# %run -i "runTCDF.py"  --ground_truth data/random-rels_40_1_returns30007000_header.csv=data/random-rels_40_1.csv --learning_rate 0.01 --hidden_layers 1 --epochs 5000 --log_interval 1000 --significance 0.8 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=None, dilation_coefficient=4, early_stopping=True, epochs=5000, ground_truth={'data/random-rels_40_1_returns30007000_header.csv': 'data/random-rels_40_1.csv'}, hidden_layers=1, kernel_size=4, learning_rate=0.01, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, significance=0.8)
#
#  Dataset:  random-rels_40_1_returns30007000_header.csv
#
#  Analysis started for target:  S0
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.994391
# Epoch   251: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.179911
# Epoch  1758: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1773: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1784: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.174313
# Epoch: 3000 [60%] 	Loss: 0.174307
# Epoch: 4000 [80%] 	Loss: 0.174297
# Epoch: 5000 [100%] 	Loss: 0.174283
# Potential causes:  [4, 5, 10, 11, 7, 1]
# Validated causes:  []
#
#  Analysis started for target:  S1
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.768560
# Epoch   272: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   300: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   318: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   329: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [20%] 	Loss: 0.144615
# Epoch: 2000 [40%] 	Loss: 0.144580
# Epoch: 3000 [60%] 	Loss: 0.144530
# Epoch: 4000 [80%] 	Loss: 0.144467
# Epoch: 5000 [100%] 	Loss: 0.144391
# Potential causes:  [11, 4, 5]
# Validated causes:  [11, 4]
#
#  Analysis started for target:  S2
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.637690
# Epoch   298: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.105161
# Epoch  1866: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1880: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1902: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.101663
# Epoch: 3000 [60%] 	Loss: 0.101660
# Epoch: 4000 [80%] 	Loss: 0.101655
# Epoch: 5000 [100%] 	Loss: 0.101649
# Potential causes:  [7, 10, 11, 4, 22, 0]
# Validated causes:  [7, 10]
#
#  Analysis started for target:  S3
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.783710
# Epoch   338: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.142606
# Epoch  1990: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [40%] 	Loss: 0.127588
# Epoch  2010: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2021: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.127568
# Epoch: 4000 [80%] 	Loss: 0.127558
# Epoch: 5000 [100%] 	Loss: 0.127544
# Potential causes:  [0, 4, 18, 11]
# Validated causes:  [0, 18]
#
#  Analysis started for target:  S4
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.516191
# Epoch   234: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.077239
# Epoch: 2000 [40%] 	Loss: 0.072907
# Epoch  2117: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2132: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2143: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.072475
# Epoch: 4000 [80%] 	Loss: 0.072470
# Epoch: 5000 [100%] 	Loss: 0.072464
# Potential causes:  [11, 10, 12, 7]
# Validated causes:  [11, 10]
#
#  Analysis started for target:  S5
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.334828
# Epoch   371: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.220904
# Epoch  1936: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [40%] 	Loss: 0.195140
# Epoch: 3000 [60%] 	Loss: 0.192951
# Epoch: 4000 [80%] 	Loss: 0.190469
# Epoch: 5000 [100%] 	Loss: 0.187971
# Potential causes:  [4, 18, 12, 3, 11]
# Validated causes:  [4, 18, 12, 3, 11]
#
#  Analysis started for target:  S6
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.716738
# Epoch   242: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.099456
# Epoch  1980: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1995: reducing learning rate of group 0 to 1.0000e-05.
# Epoch: 2000 [40%] 	Loss: 0.096362
# Epoch  2006: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.096358
# Epoch: 4000 [80%] 	Loss: 0.096355
# Epoch: 5000 [100%] 	Loss: 0.096350
# Potential causes:  [11, 7, 10, 1, 4, 18, 12, 5, 17]
# Validated causes:  []
#
#  Analysis started for target:  S7
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.682819
# Epoch   206: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.092140
# Epoch  1868: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1888: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1899: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.089641
# Epoch: 3000 [60%] 	Loss: 0.089637
# Epoch: 4000 [80%] 	Loss: 0.089633
# Epoch: 5000 [100%] 	Loss: 0.089626
# Potential causes:  [11, 10, 4]
# Validated causes:  [10]
#
#  Analysis started for target:  S8
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.854769
# Epoch   367: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   378: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   389: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   400: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
# Potential causes:  [12, 0]
# Validated causes:  [12, 0]
#
#  Analysis started for target:  S9
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.916211
# Epoch   311: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.209286
# Epoch  1660: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [40%] 	Loss: 0.175187
# Epoch: 3000 [60%] 	Loss: 0.171816
# Epoch: 4000 [80%] 	Loss: 0.168299
# Epoch: 5000 [100%] 	Loss: 0.164934
# Potential causes:  [17, 18]
# Validated causes:  [17, 18]
#
#  Analysis started for target:  S10
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.080016
# Epoch   304: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.139743
# Epoch: 2000 [40%] 	Loss: 0.135546
# Epoch  2275: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2289: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2300: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.134224
# Epoch: 4000 [80%] 	Loss: 0.134218
# Epoch: 5000 [100%] 	Loss: 0.134210
# Potential causes:  [5, 20, 11, 17, 1, 6, 4, 12, 18, 19, 24, 0]
# Validated causes:  []
#
#  Analysis started for target:  S11
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.677304
# Epoch   241: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.086834
# Epoch: 2000 [40%] 	Loss: 0.084896
# Epoch  2021: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2035: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2046: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.084864
# Epoch: 4000 [80%] 	Loss: 0.084862
# Epoch: 5000 [100%] 	Loss: 0.084858
# Potential causes:  [7, 4, 1, 6, 18, 12]
# Validated causes:  []
#
#  Analysis started for target:  S12
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.544236
# Epoch   207: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.093964
# Epoch: 2000 [40%] 	Loss: 0.091961
# Epoch  2090: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2104: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2115: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.091804
# Epoch: 4000 [80%] 	Loss: 0.091801
# Epoch: 5000 [100%] 	Loss: 0.091797
# Potential causes:  [7, 4, 11, 5, 18, 19, 6]
# Validated causes:  []
#
#  Analysis started for target:  S13
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.639835
# Epoch   290: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.151503
# Epoch  1593: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1608: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1619: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.143551
# Epoch: 3000 [60%] 	Loss: 0.143538
# Epoch: 4000 [80%] 	Loss: 0.143521
# Epoch: 5000 [100%] 	Loss: 0.143498
# Potential causes:  [3, 18]
# Validated causes:  [3, 18]
#
#  Analysis started for target:  S14
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.787679
# Epoch   201: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.190103
# Epoch  1548: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1573: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1584: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.185618
# Epoch: 3000 [60%] 	Loss: 0.185608
# Epoch: 4000 [80%] 	Loss: 0.185593
# Epoch: 5000 [100%] 	Loss: 0.185575
# Potential causes:  [12, 4, 9, 17, 11, 19, 18, 21, 13, 22]
# Validated causes:  [9]
#
#  Analysis started for target:  S15
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.213331
# Epoch   365: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.152027
# Epoch: 2000 [40%] 	Loss: 0.144031
# Epoch  2651: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2666: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2686: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.138580
# Epoch: 4000 [80%] 	Loss: 0.138571
# Epoch: 5000 [100%] 	Loss: 0.138558
# Potential causes:  [6, 12]
# Validated causes:  [6]
#
#  Analysis started for target:  S16
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.045393
# Epoch   307: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.184525
# Epoch  1684: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1699: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1721: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.169755
# Epoch: 3000 [60%] 	Loss: 0.169737
# Epoch: 4000 [80%] 	Loss: 0.169712
# Epoch: 5000 [100%] 	Loss: 0.169678
# Potential causes:  [18, 5, 12, 6, 11, 4, 19, 3]
# Validated causes:  [18, 5, 6]
#
#  Analysis started for target:  S17
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.758424
# Epoch   344: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.119318
# Epoch: 2000 [40%] 	Loss: 0.117121
# Epoch  2455: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2467: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2478: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.116429
# Epoch: 4000 [80%] 	Loss: 0.116427
# INFO: Early stopping at epoch 500
# Potential causes:  [12, 4]
# Validated causes:  [12]
#
#  Analysis started for target:  S18
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.855171
# Epoch   281: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.176923
# Epoch  1723: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1748: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1768: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.166646
# Epoch: 3000 [60%] 	Loss: 0.166628
# Epoch: 4000 [80%] 	Loss: 0.166603
# Epoch: 5000 [100%] 	Loss: 0.166571
# Potential causes:  [3, 12]
# Validated causes:  [3]
#
#  Analysis started for target:  S19
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.400642
# Epoch   325: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.341480
# Epoch  1774: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1789: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1811: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.309532
# Epoch: 3000 [60%] 	Loss: 0.309513
# Epoch: 4000 [80%] 	Loss: 0.309484
# Epoch: 5000 [100%] 	Loss: 0.309445
# Potential causes:  [11, 22, 12, 18, 5, 4]
# Validated causes:  [11, 22, 12, 5]
#
#  Analysis started for target:  S20
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.301375
# Epoch   363: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.120380
# Epoch: 2000 [40%] 	Loss: 0.113159
# Epoch  2668: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2697: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2708: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.110222
# Epoch: 4000 [80%] 	Loss: 0.110217
# Epoch: 5000 [100%] 	Loss: 0.110209
# Potential causes:  [17, 12]
# Validated causes:  [17, 12]
#
#  Analysis started for target:  S21
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.298713
# Epoch   350: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.160475
# Epoch: 2000 [40%] 	Loss: 0.148279
# Epoch  2201: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  2216: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2227: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.146557
# Epoch: 4000 [80%] 	Loss: 0.146545
# Epoch: 5000 [100%] 	Loss: 0.146530
# Potential causes:  [12, 17]
# Validated causes:  [12, 17]
#
#  Analysis started for target:  S22
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.036210
# Epoch   251: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.158480
# Epoch  1748: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1762: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1773: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.153254
# Epoch: 3000 [60%] 	Loss: 0.153248
# Epoch: 4000 [80%] 	Loss: 0.153239
# Epoch: 5000 [100%] 	Loss: 0.153226
# Potential causes:  [12, 10, 17]
# Validated causes:  [10]
#
#  Analysis started for target:  S23
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.014204
# Epoch   308: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.161493
# Epoch  1997: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [40%] 	Loss: 0.150916
# Epoch  2022: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  2033: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 3000 [60%] 	Loss: 0.150824
# Epoch: 4000 [80%] 	Loss: 0.150813
# Epoch: 5000 [100%] 	Loss: 0.150798
# Potential causes:  [12, 18, 21, 19]
# Validated causes:  [12, 21]
#
#  Analysis started for target:  S24
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.382421
# Epoch   299: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [20%] 	Loss: 0.330847
# Epoch  1623: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1648: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1659: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [40%] 	Loss: 0.307472
# Epoch: 3000 [60%] 	Loss: 0.307446
# Epoch: 4000 [80%] 	Loss: 0.307409
# Epoch: 5000 [100%] 	Loss: 0.307358
# Potential causes:  [2, 12, 21, 17, 8, 18, 19]
# Validated causes:  [2, 12, 21, 8]
#
# ===================Results for random-rels_40_1_returns30007000_header.csv ==================================
# S11 causes S1 with a delay of 2 time steps.
# S4 causes S1 with a delay of 1 time steps.
# S7 causes S2 with a delay of 0 time steps.
# S10 causes S2 with a delay of 1 time steps.
# S0 causes S3 with a delay of 1 time steps.
# S18 causes S3 with a delay of 0 time steps.
# S11 causes S4 with a delay of 1 time steps.
# S10 causes S4 with a delay of 1 time steps.
# S4 causes S5 with a delay of 1 time steps.
# S18 causes S5 with a delay of 1 time steps.
# S12 causes S5 with a delay of 2 time steps.
# S3 causes S5 with a delay of 1 time steps.
# S11 causes S5 with a delay of 2 time steps.
# S10 causes S7 with a delay of 1 time steps.
# S12 causes S8 with a delay of 2 time steps.
# S0 causes S8 with a delay of 1 time steps.
# S17 causes S9 with a delay of 2 time steps.
# S18 causes S9 with a delay of 2 time steps.
# S3 causes S13 with a delay of 1 time steps.
# S18 causes S13 with a delay of 1 time steps.
# S9 causes S14 with a delay of 1 time steps.
# S6 causes S15 with a delay of 1 time steps.
# S18 causes S16 with a delay of 1 time steps.
# S5 causes S16 with a delay of 1 time steps.
# S6 causes S16 with a delay of 1 time steps.
# S12 causes S17 with a delay of 1 time steps.
# S3 causes S18 with a delay of 0 time steps.
# S11 causes S19 with a delay of 3 time steps.
# S22 causes S19 with a delay of 1 time steps.
# S12 causes S19 with a delay of 1 time steps.
# S5 causes S19 with a delay of 1 time steps.
# S17 causes S20 with a delay of 1 time steps.
# S12 causes S20 with a delay of 2 time steps.
# S12 causes S21 with a delay of 3 time steps.
# S17 causes S21 with a delay of 2 time steps.
# S10 causes S22 with a delay of 1 time steps.
# S12 causes S23 with a delay of 1 time steps.
# S21 causes S23 with a delay of 1 time steps.
# S2 causes S24 with a delay of 1 time steps.
# S12 causes S24 with a delay of 3 time steps.
# S21 causes S24 with a delay of 1 time steps.
# S8 causes S24 with a delay of 0 time steps.
#
# ===================Evaluation for random-rels_40_1_returns30007000_header.csv ===============================
# Total False Positives':  10
# Total True Positives':  32
# Total False Negatives:  17
# Total Direct False Positives:  19
# Total Direct True Positives:  23
# TPs':  [(1, 11), (1, 4), (2, 10), (3, 0), (3, 18), (4, 11), (5, 4), (5, 18), (5, 11), (7, 10), (8, 12), (8, 0), (9, 17), (13, 3), (14, 9), (15, 6), (16, 18), (16, 5), (16, 6), (17, 12), (19, 22), (19, 12), (19, 5), (20, 17), (20, 12), (21, 17), (22, 10), (23, 12), (23, 21), (24, 2), (24, 12), (24, 21)]
# FPs':  [(2, 7), (4, 10), (5, 12), (5, 3), (9, 18), (13, 18), (18, 3), (19, 11), (21, 12), (24, 8)]
# TPs direct:  [(1, 4), (2, 10), (3, 0), (4, 11), (5, 4), (5, 18), (7, 10), (8, 0), (13, 3), (14, 9), (15, 6), (16, 18), (16, 5), (16, 6), (17, 12), (19, 22), (19, 12), (19, 5), (20, 17), (22, 10), (23, 12), (23, 21), (24, 2)]
# FPs direct:  [(1, 11), (2, 7), (3, 18), (4, 10), (5, 12), (5, 3), (5, 11), (8, 12), (9, 17), (9, 18), (13, 18), (18, 3), (19, 11), (20, 12), (21, 12), (21, 17), (24, 12), (24, 21), (24, 8)]
# FNs:  [(3, 21), (3, 16), (5, 8), (8, 23), (8, 21), (9, 13), (9, 20), (9, 9), (15, 21), (18, 16), (18, 21), (19, 19), (21, 20), (21, 2), (21, 0), (24, 23), (24, 15)]
# Precision':  0.7619047619047619
# Recall':  0.6530612244897959
# F1' score:  0.7032967032967032 (includes direct and indirect causal relationships)
# Precision:  0.5476190476190477
# Recall:  0.575
# F1 score:  0.5609756097560975 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  87.87878787878788 %
# ==================================================================================

# %%
# Run TCDF for predictive accuracy

# %run -i "evaluate_predictions_TCDF.py" --data data/random-rels_40_1_returns30007000_header.csv --learning_rate 0.01 --hidden_layers 1 --epochs 2000 --log_interval 1000 --dilation_coefficient 4 --kernel_size 4 --seed 5467 --plot
# Out:
# Arguments: Namespace(cuda=False, data=['data/random-rels_40_1_returns30007000_header.csv'], dilation_coefficient=4, early_stopping=True, epochs=2000, hidden_layers=1, kernel_size=4, learning_rate=0.01, log_interval=1000, lr_scheduler=True, optimizer='Adam', plot=True, seed=5467, train_test_split=0.5)
#
#  Analysis started for target:  S0
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.994713
# Epoch   417: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.165965
# Epoch: 2000 [100%] 	Loss: 0.162152
#
#  Analysis started for target:  S1
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.771571
# Epoch   323: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.127258
# Epoch: 2000 [100%] 	Loss: 0.119686
#
#  Analysis started for target:  S2
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.642785
# Epoch   309: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.105716
# Epoch  1902: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1922: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1933: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.099162
#
#  Analysis started for target:  S3
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.794255
# Epoch   346: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.139244
# Epoch  1895: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1907: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1925: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.124750
#
#  Analysis started for target:  S4
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.540556
# Epoch   237: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.078788
# Epoch: 2000 [100%] 	Loss: 0.074379
#
#  Analysis started for target:  S5
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.303568
# Epoch   314: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.214212
# Epoch: 2000 [100%] 	Loss: 0.180671
#
#  Analysis started for target:  S6
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.711146
# Epoch   217: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.099725
# Epoch  1667: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1681: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1692: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.096774
#
#  Analysis started for target:  S7
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.671748
# Epoch   217: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.093559
# Epoch  1785: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1799: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1820: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.090018
#
#  Analysis started for target:  S8
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.865847
# Epoch   247: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.132886
# Epoch  1521: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 2000 [100%] 	Loss: 0.117062
#
#  Analysis started for target:  S9
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.901278
# Epoch   355: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   366: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   377: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   388: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  S10
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.017131
# Epoch   288: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.135538
# Epoch: 2000 [100%] 	Loss: 0.128133
#
#  Analysis started for target:  S11
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.650743
# Epoch   245: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.087207
# Epoch: 2000 [100%] 	Loss: 0.084439
#
#  Analysis started for target:  S12
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.532653
# Epoch   292: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   312: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   334: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   345: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.087152
# Epoch: 2000 [100%] 	Loss: 0.087148
#
#  Analysis started for target:  S13
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.617260
# Epoch   343: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.150255
# Epoch  1841: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1856: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1867: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.138433
#
#  Analysis started for target:  S14
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.770100
# Epoch   315: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.190876
# Epoch: 2000 [100%] 	Loss: 0.181050
#
#  Analysis started for target:  S15
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.142503
# Epoch   282: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.155613
# Epoch: 2000 [100%] 	Loss: 0.137224
#
#  Analysis started for target:  S16
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.980855
# Epoch   354: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   365: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   376: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   387: reducing learning rate of group 0 to 1.0000e-06.
# INFO: Early stopping at epoch 500
#
#  Analysis started for target:  S17
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.694292
# Epoch   231: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.120625
# Epoch: 2000 [100%] 	Loss: 0.115812
#
#  Analysis started for target:  S18
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.777168
# Epoch   283: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.165043
# Epoch  1849: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1874: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1885: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.153960
#
#  Analysis started for target:  S19
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.225769
# Epoch   476: reducing learning rate of group 0 to 1.0000e-03.
# Epoch   491: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   502: reducing learning rate of group 0 to 1.0000e-05.
# Epoch   552: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 1000 [50%] 	Loss: 0.321745
# Epoch: 2000 [100%] 	Loss: 0.321579
#
#  Analysis started for target:  S20
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.119322
# Epoch   359: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.129218
# Epoch: 2000 [100%] 	Loss: 0.113280
#
#  Analysis started for target:  S21
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.121332
# Epoch   341: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.154164
# Epoch: 2000 [100%] 	Loss: 0.139768
#
#  Analysis started for target:  S22
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.873699
# Epoch   356: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.148413
# Epoch: 2000 [100%] 	Loss: 0.142809
#
#  Analysis started for target:  S23
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 0.843402
# Epoch   330: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.154007
# Epoch  1887: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  1902: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  1923: reducing learning rate of group 0 to 1.0000e-06.
# Epoch: 2000 [100%] 	Loss: 0.141594
#
#  Analysis started for target:  S24
# INFO: Initializing learning rate scheduler
# INFO: Initializing early stopping
# Epoch:  1 [0%] 	Loss: 1.242380
# Epoch   359: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 1000 [50%] 	Loss: 0.313292
# Epoch: 2000 [100%] 	Loss: 0.288611
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/random-rels_40_1_returns30007000_header.csv : 0.3807443382212533 with standard deviation 0.05316757912958965
